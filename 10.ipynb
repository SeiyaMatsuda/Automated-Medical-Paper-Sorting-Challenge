# %% [markdown]
# 1. データの読み込み

# %%
import math
import random
import time
import warnings
import numpy as np
import pandas as pd
import torch
import torch.nn as nn
import os
import transformers as T
from pathlib import Path
from sklearn.metrics import fbeta_score
from sklearn.model_selection import StratifiedKFold
from torch.utils.data import DataLoader, Dataset
from sklearn.linear_model import LogisticRegression
from tqdm.notebook import tqdm
import matplotlib.pyplot as plt
import string
from nltk.corpus import stopwords
from sklearn.pipeline import Pipeline
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.feature_extraction.text import CountVectorizer
from sklearn.metrics import fbeta_score
from sklearn.preprocessing import MinMaxScaler,StandardScaler
from imblearn.under_sampling import RandomUnderSampler
from sklearn.decomposition import TruncatedSVD
from sklearn.pipeline import Pipeline
import tqdm
from sklearn.feature_selection import SelectKBest, chi2
from scipy.optimize import minimize_scalar
from sklearn import naive_bayes

# %%
warnings.filterwarnings("ignore")

# %%
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
print(device)
# Out:
# cuda

# %%
def seed_torch(seed=42):
    random.seed(seed)
    os.environ["PYTHONHASHSEED"] = str(seed)
    np.random.seed(seed)
    torch.manual_seed(seed)
    torch.cuda.manual_seed(seed)
    torch.cuda.manual_seed_all(seed)
    torch.backends.cudnn.deterministic = True

seed = 471
seed_torch(seed)

# %%
DATA_DIR = './dataset/data4'

# %%
def text_process(mess):
    STOPWORDS = stopwords.words('english') + ['u', 'ü', 'ur', 'im', 'dont', 'doin', 'ure']
    nopunc = [char for char in mess if char not in string.punctuation]
    nopunc = ''.join(nopunc)
    return ' '.join([word.lower() for word in nopunc.split() if word.lower() not in STOPWORDS])
#データの読み込み
df_train = pd.read_csv(DATA_DIR  +"/train.csv", index_col=0).fillna(" ")
df_test = pd.read_csv(DATA_DIR + "/test.csv", index_col=0).fillna(" ")
sub = pd.read_csv(DATA_DIR + "/sample_submit.csv", index_col=0)
df_train.title = train.text.apply(text_process)
df_test.title = test.text.apply(text_process)

# %%
from scipy.misc import derivative

def original_init_score(y):
    y = y.mean()
    return np.log(y/(1-y))

class focal_loss:
    def __init__(self, alpha, gamma, balance=False):
        self.alpha = alpha
        self.gamma = gamma
        self.balance = balance
        
    def focal_loss_objective(self, y_pred, trn_data):
        y_true = trn_data.get_label()
        def fl(x,t):
            p = 1/(1+np.exp(-x))
            if self.balance:
                return -(t*(1-p)**self.gamma * np.log(p) * self.alpha + p ** self.gamma * (1-t) * np.log(1-p) * (1-self.alpha)) 
            else:
                return -(t*(1-p)**self.gamma * np.log(p) + p ** self.gamma * (1-t) * np.log(1-p))
        partial_fl = lambda x: fl(x, y_true)
        grad = derivative(partial_fl, y_pred, n=1, dx=1e-6)
        hess = derivative(partial_fl, y_pred, n=2, dx=1e-6)
        return grad, hess
    def original_binary_logloss_metric(self, y_pred, trn_data):
        y_train = trn_data.get_label()
        pred = 1/(1+np.exp(-y_pred))
        loss = -(y_train * np.log(pred) + (1-y_train)*np.log(1-pred))    
        return 'original_binary_logloss', np.mean(loss), False

# %%
sub_prob = []
for fold in tqdm.tqdm(range(5), total=5):
#     sub = np.zeros()
    train = df_train[df_train.fold!=fold]
    val = df_train[df_train.fold==fold]
    X_train, y_train = train.loc[:, 'text'], train.loc[:, 'judgement']
    X_val, y_val = val.loc[:, 'text'], val.loc[:, 'judgement']
    X_test = df_test.loc[:, 'text']
    rus = RandomUnderSampler(random_state=71)
    pipline = Pipeline([('tfidf', TfidfVectorizer()), ('svd', TruncatedSVD(n_components=500, random_state=0)), 
            ('sc',MinMaxScaler())])
    X_train = pipline.fit_transform(X_train)
    X_val = pipline.transform(X_val)
    X_test = pipline.transform(X_test)
    X_train, y_train = rus.fit_resample(X_train,y_train)
    max_score = 0
    columns_num = X_train.shape[1]
    for k in range(columns_num):
        select_num = columns_num-k
        select = SelectKBest(score_func = chi2, k=select_num)
        X_tr_ = select.fit_transform(X_train, y_train)
        X_val_ = select.transform(X_val)
        X_tes_ = select.transform(X_test)
        print(X_tr_.shape)
        model = LogisticRegression()
        model.fit(X_tr_, y_train)
        prob = model.predict_proba(X_val_)[:,1]
        def calc_thres(x:float):
            predict =  np.where(prob < x, 0, 1)
            return -fbeta_score(y_val, predict, beta=7)
        thres = minimize_scalar(calc_thres, method='Bounded', bounds=(0.01, 0.99))
        score = -thres.fun
        print(score,max_score)
        if score < max_score:
            break
        else:
            max_score = score
            X_tes_fix = X_tes_
            model_fix = model
    prediction = model_fix.predict_proba(X_tes_fix)[:,1]
    test_prob =  np.where(prediction < thres.x, 0, 1)
    sub_prob.append(test_prob)
    print('fold{}::{}::{}'.format(fold, thres.x, -thres.fun))
# Out:
#   0%|                                                                                                                                                                                        | 0/5 [00:00<?, ?it/s]
# (1012, 500)
# 0.8585265629586147 0
# (1012, 499)
#  20%|███████████████████████████████████▏                                                                                                                                            | 1/5 [00:24<01:38, 24.61s/it]
# 0.8566865108174821 0.8585265629586147
# fold0::0.40123557940930576::0.8566865108174821
# (1012, 500)
# 0.8629515869533422 0
# (1012, 499)
#  40%|██████████████████████████████████████████████████████████████████████▍                                                                                                         | 2/5 [00:49<01:15, 25.01s/it]
# 0.8633304067895815 0.8629515869533422
# (1012, 498)
# 0.8616912516430553 0.8633304067895815
# fold1::0.42228417588658657::0.8616912516430553
#  40%|██████████████████████████████████████████████████████████████████████▍                                                                                                         | 2/5 [00:58<01:28, 29.39s/it]
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# /tmp/ipykernel_2287384/2789886599.py in <module>
#      10     pipline = Pipeline([('tfidf', TfidfVectorizer()), ('svd', TruncatedSVD(n_components=500, random_state=0)),
#      11             ('sc',MinMaxScaler())])
# ---> 12     X_train = pipline.fit_transform(X_train)
#      13     X_val = pipline.transform(X_val)
#      14     X_test = pipline.transform(X_test)
#
# ~/デスクトップ/Signate/signate_env/lib/python3.9/site-packages/sklearn/pipeline.py in fit_transform(self, X, y, **fit_params)
#     365         """
#     366         fit_params_steps = self._check_fit_params(**fit_params)
# --> 367         Xt = self._fit(X, y, **fit_params_steps)
#     368
#     369         last_step = self._final_estimator
#
# ~/デスクトップ/Signate/signate_env/lib/python3.9/site-packages/sklearn/pipeline.py in _fit(self, X, y, **fit_params_steps)
#     290                 cloned_transformer = clone(transformer)
#     291             # Fit or load from cache the current transformer
# --> 292             X, fitted_transformer = fit_transform_one_cached(
#     293                 cloned_transformer, X, y, None,
#     294                 message_clsname='Pipeline',
#
# ~/デスクトップ/Signate/signate_env/lib/python3.9/site-packages/joblib/memory.py in __call__(self, *args, **kwargs)
#     350
#     351     def __call__(self, *args, **kwargs):
# --> 352         return self.func(*args, **kwargs)
#     353
#     354     def call_and_shelve(self, *args, **kwargs):
#
# ~/デスクトップ/Signate/signate_env/lib/python3.9/site-packages/sklearn/pipeline.py in _fit_transform_one(transformer, X, y, weight, message_clsname, message, **fit_params)
#     738     with _print_elapsed_time(message_clsname, message):
#     739         if hasattr(transformer, 'fit_transform'):
# --> 740             res = transformer.fit_transform(X, y, **fit_params)
#     741         else:
#     742             res = transformer.fit(X, y, **fit_params).transform(X)
#
# ~/デスクトップ/Signate/signate_env/lib/python3.9/site-packages/sklearn/decomposition/_truncated_svd.py in fit_transform(self, X, y)
#     179                 raise ValueError("n_components must be < n_features;"
#     180                                  " got %d >= %d" % (k, n_features))
# --> 181             U, Sigma, VT = randomized_svd(X, self.n_components,
#     182                                           n_iter=self.n_iter,
#     183                                           random_state=random_state)
#
# ~/デスクトップ/Signate/signate_env/lib/python3.9/site-packages/sklearn/utils/validation.py in inner_f(*args, **kwargs)
#      70                           FutureWarning)
#      71         kwargs.update({k: arg for k, arg in zip(sig.parameters, args)})
# ---> 72         return f(**kwargs)
#      73     return inner_f
#      74
#
# ~/デスクトップ/Signate/signate_env/lib/python3.9/site-packages/sklearn/utils/extmath.py in randomized_svd(M, n_components, n_oversamples, n_iter, power_iteration_normalizer, transpose, flip_sign, random_state)
#     347         M = M.T
#     348
# --> 349     Q = randomized_range_finder(
#     350         M, size=n_random, n_iter=n_iter,
#     351         power_iteration_normalizer=power_iteration_normalizer,
#
# ~/デスクトップ/Signate/signate_env/lib/python3.9/site-packages/sklearn/utils/validation.py in inner_f(*args, **kwargs)
#      70                           FutureWarning)
#      71         kwargs.update({k: arg for k, arg in zip(sig.parameters, args)})
# ---> 72         return f(**kwargs)
#      73     return inner_f
#      74
#
# ~/デスクトップ/Signate/signate_env/lib/python3.9/site-packages/sklearn/utils/extmath.py in randomized_range_finder(A, size, n_iter, power_iteration_normalizer, random_state)
#     233         elif power_iteration_normalizer == 'LU':
#     234             Q, _ = linalg.lu(safe_sparse_dot(A, Q), permute_l=True)
# --> 235             Q, _ = linalg.lu(safe_sparse_dot(A.T, Q), permute_l=True)
#     236         elif power_iteration_normalizer == 'QR':
#     237             Q, _ = linalg.qr(safe_sparse_dot(A, Q), mode='economic')
#
# ~/デスクトップ/Signate/signate_env/lib/python3.9/site-packages/sklearn/utils/validation.py in inner_f(*args, **kwargs)
#      70                           FutureWarning)
#      71         kwargs.update({k: arg for k, arg in zip(sig.parameters, args)})
# ---> 72         return f(**kwargs)
#      73     return inner_f
#      74
#
# ~/デスクトップ/Signate/signate_env/lib/python3.9/site-packages/sklearn/utils/extmath.py in safe_sparse_dot(a, b, dense_output)
#     151             ret = np.dot(a, b)
#     152     else:
# --> 153         ret = a @ b
#     154
#     155     if (sparse.issparse(a) and sparse.issparse(b)
#
# ~/デスクトップ/Signate/signate_env/lib/python3.9/site-packages/scipy/sparse/base.py in __matmul__(self, other)
#     558             raise ValueError("Scalar operands are not allowed, "
#     559                              "use '*' instead")
# --> 560         return self.__mul__(other)
#     561
#     562     def __rmatmul__(self, other):
#
# ~/デスクトップ/Signate/signate_env/lib/python3.9/site-packages/scipy/sparse/base.py in __mul__(self, other)
#     469                 return self._mul_vector(other.ravel()).reshape(M, 1)
#     470             elif other.ndim == 2 and other.shape[0] == N:
# --> 471                 return self._mul_multivector(other)
#     472
#     473         if isscalarlike(other):
#
# ~/デスクトップ/Signate/signate_env/lib/python3.9/site-packages/scipy/sparse/compressed.py in _mul_multivector(self, other)
#     487         # csr_matvecs or csc_matvecs
#     488         fn = getattr(_sparsetools, self.format + '_matvecs')
# --> 489         fn(M, N, n_vecs, self.indptr, self.indices, self.data,
#     490            other.ravel(), result.ravel())
#     491
#
# KeyboardInterrupt:

# %%
import optuna.integration.lightgbm as lgb_o
import lightgbm as lgb_o
params = dict(n_estimators=10000,
              metric='binary',
                        num_leaves=31,
                        learning_rate=0.01,
                        colsample_bytree=0.3, 
                        importance_type="gain")

focal = focal_loss(alpha=0.25, gamma=0.2, balance=False)
sub_prob = []
for fold in tqdm.tqdm(range(5), total=5):
#     sub = np.zeros()
    train = df_train[df_train.fold!=fold]
    val = df_train[df_train.fold==fold]
    X_train, y_train = train.loc[:, 'text'], train.loc[:, 'judgement']
    X_val, y_val = val.loc[:, 'text'], val.loc[:, 'judgement']
    X_test = df_test.loc[:, 'text']
    pipline = Pipeline([('tfidf', TfidfVectorizer()), ('svd', TruncatedSVD(n_components=500, random_state=0)), 
            ('sc',MinMaxScaler())])
    X_train = pipline.fit_transform(X_train)
    X_val = pipline.transform(X_val)
    X_test = pipline.transform(X_test)
    rus = RandomUnderSampler(random_state=71)
    X_train, y_train = rus.fit_resample(X_train,y_train)
    lgb_train = lgb_o.Dataset(X_train, y_train)
    lgb_eval = lgb_o.Dataset(X_val, y_val)
    evals_result = {}
                         
    model = lgb_o.train(params,train_set=lgb_train,
                 # 評価データ
                 valid_sets = lgb_eval,
                evals_result=evals_result,
                 early_stopping_rounds=1000)
    prob = model.predict(X_val)
    def calc_thres(x:float):
        predict =  np.where(prob < x, 0, 1)
        return -fbeta_score(y_val, predict, beta=7)
    thres = minimize_scalar(calc_thres, method='Bounded', bounds=(0.01, 0.99))
    score = -thres.fun
    prediction = model.predict(X_test)
    test_prob =  np.where(prediction < thres.x, 0, 1)
    sub_prob.append(test_prob)
    print('fold{}::{}::{}'.format(fold, thres.x, -thres.fun))
# Out:
#   0%|                                                                                                                                                                                        | 0/5 [00:00<?, ?it/s]
# [LightGBM] [Warning] Unknown parameter: importance_type
# [LightGBM] [Warning] Unknown parameter: importance_type
# [LightGBM] [Warning] Auto-choosing col-wise multi-threading, the overhead of testing was 0.004161 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 127500
# [LightGBM] [Info] Number of data points in the train set: 1012, number of used features: 500
# [LightGBM] [Warning] Unknown parameter: importance_type
# [LightGBM] [Info] Start training from score 0.500000
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [1]	valid_0's binary_logloss: 0.688978
# Training until validation scores don't improve for 1000 rounds
# [2]	valid_0's binary_logloss: 0.685783
# [3]	valid_0's binary_logloss: 0.68128
# [4]	valid_0's binary_logloss: 0.678231
# [5]	valid_0's binary_logloss: 0.674769
# [6]	valid_0's binary_logloss: 0.671282
# [7]	valid_0's binary_logloss: 0.668057
# [8]	valid_0's binary_logloss: 0.664195
# [9]	valid_0's binary_logloss: 0.660053
# [10]	valid_0's binary_logloss: 0.656685
# [11]	valid_0's binary_logloss: 0.652368
# [12]	valid_0's binary_logloss: 0.649218
# [13]	valid_0's binary_logloss: 0.646215
# [14]	valid_0's binary_logloss: 0.642912
# [15]	valid_0's binary_logloss: 0.639386
# [16]	valid_0's binary_logloss: 0.636204
# [17]	valid_0's binary_logloss: 0.633382
# [18]	valid_0's binary_logloss: 0.629953
# [19]	valid_0's binary_logloss: 0.625871
# [20]	valid_0's binary_logloss: 0.621914
# [21]	valid_0's binary_logloss: 0.61939
# [22]	valid_0's binary_logloss: 0.617318
# [23]	valid_0's binary_logloss: 0.614795
# [24]	valid_0's binary_logloss: 0.611708
# [25]	valid_0's binary_logloss: 0.609172
# [26]	valid_0's binary_logloss: 0.606265
# [27]	valid_0's binary_logloss: 0.603651
# [28]	valid_0's binary_logloss: 0.600695
# [29]	valid_0's binary_logloss: 0.597682
# [30]	valid_0's binary_logloss: 0.594527
# [31]	valid_0's binary_logloss: 0.591962
# [32]	valid_0's binary_logloss: 0.589698
# [33]	valid_0's binary_logloss: 0.586878
# [34]	valid_0's binary_logloss: 0.584013
# [35]	valid_0's binary_logloss: 0.580668
# [36]	valid_0's binary_logloss: 0.577947
# [37]	valid_0's binary_logloss: 0.57595
# [38]	valid_0's binary_logloss: 0.573481
# [39]	valid_0's binary_logloss: 0.570131
# [40]	valid_0's binary_logloss: 0.567192
# [41]	valid_0's binary_logloss: 0.56465
# [42]	valid_0's binary_logloss: 0.561508
# [43]	valid_0's binary_logloss: 0.559276
# [44]	valid_0's binary_logloss: 0.556942
# [45]	valid_0's binary_logloss: 0.554603
# [46]	valid_0's binary_logloss: 0.552675
# [47]	valid_0's binary_logloss: 0.549542
# [48]	valid_0's binary_logloss: 0.546567
# [49]	valid_0's binary_logloss: 0.544661
# [50]	valid_0's binary_logloss: 0.542343
# [51]	valid_0's binary_logloss: 0.539544
# [52]	valid_0's binary_logloss: 0.537692
# [53]	valid_0's binary_logloss: 0.53528
# [54]	valid_0's binary_logloss: 0.532453
# [55]	valid_0's binary_logloss: 0.529864
# [56]	valid_0's binary_logloss: 0.528304
# [57]	valid_0's binary_logloss: 0.525807
# [58]	valid_0's binary_logloss: 0.524227
# [59]	valid_0's binary_logloss: 0.522445
# [60]	valid_0's binary_logloss: 0.51998
# [61]	valid_0's binary_logloss: 0.517477
# [62]	valid_0's binary_logloss: 0.51597
# [63]	valid_0's binary_logloss: 0.514165
# [64]	valid_0's binary_logloss: 0.512538
# [65]	valid_0's binary_logloss: 0.509988
# [66]	valid_0's binary_logloss: 0.507962
# [67]	valid_0's binary_logloss: 0.505879
# [68]	valid_0's binary_logloss: 0.504535
# [69]	valid_0's binary_logloss: 0.502271
# [70]	valid_0's binary_logloss: 0.499911
# [71]	valid_0's binary_logloss: 0.497648
# [72]	valid_0's binary_logloss: 0.495946
# [73]	valid_0's binary_logloss: 0.493709
# [74]	valid_0's binary_logloss: 0.492364
# [75]	valid_0's binary_logloss: 0.490024
# [76]	valid_0's binary_logloss: 0.488206
# [77]	valid_0's binary_logloss: 0.486185
# [78]	valid_0's binary_logloss: 0.484462
# [79]	valid_0's binary_logloss: 0.483098
# [80]	valid_0's binary_logloss: 0.481478
# [81]	valid_0's binary_logloss: 0.479751
# [82]	valid_0's binary_logloss: 0.478001
# [83]	valid_0's binary_logloss: 0.476139
# [84]	valid_0's binary_logloss: 0.474081
# [85]	valid_0's binary_logloss: 0.471722
# [86]	valid_0's binary_logloss: 0.470105
# [87]	valid_0's binary_logloss: 0.467864
# [88]	valid_0's binary_logloss: 0.466076
# [89]	valid_0's binary_logloss: 0.464423
# [90]	valid_0's binary_logloss: 0.463048
# [91]	valid_0's binary_logloss: 0.461885
# [92]	valid_0's binary_logloss: 0.460163
# [93]	valid_0's binary_logloss: 0.458726
# [94]	valid_0's binary_logloss: 0.457159
# [95]	valid_0's binary_logloss: 0.455594
# [96]	valid_0's binary_logloss: 0.453625
# [97]	valid_0's binary_logloss: 0.452009
# [98]	valid_0's binary_logloss: 0.450632
# [99]	valid_0's binary_logloss: 0.449122
# [100]	valid_0's binary_logloss: 0.448394
# [101]	valid_0's binary_logloss: 0.44706
# [102]	valid_0's binary_logloss: 0.445809
# [103]	valid_0's binary_logloss: 0.44423
# [104]	valid_0's binary_logloss: 0.442576
# [105]	valid_0's binary_logloss: 0.441671
# [106]	valid_0's binary_logloss: 0.440214
# [107]	valid_0's binary_logloss: 0.43918
# [108]	valid_0's binary_logloss: 0.437444
# [109]	valid_0's binary_logloss: 0.435854
# [110]	valid_0's binary_logloss: 0.43488
# [111]	valid_0's binary_logloss: 0.433519
# [112]	valid_0's binary_logloss: 0.432164
# [113]	valid_0's binary_logloss: 0.431052
# [114]	valid_0's binary_logloss: 0.429614
# [115]	valid_0's binary_logloss: 0.428502
# [116]	valid_0's binary_logloss: 0.427571
# [117]	valid_0's binary_logloss: 0.426498
# [118]	valid_0's binary_logloss: 0.425456
# [119]	valid_0's binary_logloss: 0.424205
# [120]	valid_0's binary_logloss: 0.423131
# [121]	valid_0's binary_logloss: 0.422063
# [122]	valid_0's binary_logloss: 0.420866
# [123]	valid_0's binary_logloss: 0.419624
# [124]	valid_0's binary_logloss: 0.418718
# [125]	valid_0's binary_logloss: 0.417906
# [126]	valid_0's binary_logloss: 0.416532
# [127]	valid_0's binary_logloss: 0.415514
# [128]	valid_0's binary_logloss: 0.414162
# [129]	valid_0's binary_logloss: 0.413163
# [130]	valid_0's binary_logloss: 0.412136
# [131]	valid_0's binary_logloss: 0.411452
# [132]	valid_0's binary_logloss: 0.410455
# [133]	valid_0's binary_logloss: 0.409747
# [134]	valid_0's binary_logloss: 0.408813
# [135]	valid_0's binary_logloss: 0.407939
# [136]	valid_0's binary_logloss: 0.407233
# [137]	valid_0's binary_logloss: 0.406062
# [138]	valid_0's binary_logloss: 0.405289
# [139]	valid_0's binary_logloss: 0.404197
# [140]	valid_0's binary_logloss: 0.403398
# [141]	valid_0's binary_logloss: 0.402372
# [142]	valid_0's binary_logloss: 0.40145
# [143]	valid_0's binary_logloss: 0.400562
# [144]	valid_0's binary_logloss: 0.399727
# [145]	valid_0's binary_logloss: 0.398619
# [146]	valid_0's binary_logloss: 0.397681
# [147]	valid_0's binary_logloss: 0.396663
# [148]	valid_0's binary_logloss: 0.395686
# [149]	valid_0's binary_logloss: 0.395019
# [150]	valid_0's binary_logloss: 0.394424
# [151]	valid_0's binary_logloss: 0.393332
# [152]	valid_0's binary_logloss: 0.392482
# [153]	valid_0's binary_logloss: 0.391513
# [154]	valid_0's binary_logloss: 0.390913
# [155]	valid_0's binary_logloss: 0.390117
# [156]	valid_0's binary_logloss: 0.389278
# [157]	valid_0's binary_logloss: 0.388639
# [158]	valid_0's binary_logloss: 0.387726
# [159]	valid_0's binary_logloss: 0.387281
# [160]	valid_0's binary_logloss: 0.386515
# [161]	valid_0's binary_logloss: 0.385433
# [162]	valid_0's binary_logloss: 0.384548
# [163]	valid_0's binary_logloss: 0.38331
# [164]	valid_0's binary_logloss: 0.382512
# [165]	valid_0's binary_logloss: 0.381679
# [166]	valid_0's binary_logloss: 0.38082
# [167]	valid_0's binary_logloss: 0.379986
# [168]	valid_0's binary_logloss: 0.379038
# [169]	valid_0's binary_logloss: 0.378279
# [170]	valid_0's binary_logloss: 0.377646
# [171]	valid_0's binary_logloss: 0.376901
# [172]	valid_0's binary_logloss: 0.376216
# [173]	valid_0's binary_logloss: 0.375722
# [174]	valid_0's binary_logloss: 0.375092
# [175]	valid_0's binary_logloss: 0.374497
# [176]	valid_0's binary_logloss: 0.37367
# [177]	valid_0's binary_logloss: 0.372992
# [178]	valid_0's binary_logloss: 0.372293
# [179]	valid_0's binary_logloss: 0.371582
# [180]	valid_0's binary_logloss: 0.371128
# [181]	valid_0's binary_logloss: 0.370731
# [182]	valid_0's binary_logloss: 0.37029
# [183]	valid_0's binary_logloss: 0.369589
# [184]	valid_0's binary_logloss: 0.368667
# [185]	valid_0's binary_logloss: 0.367946
# [186]	valid_0's binary_logloss: 0.367024
# [187]	valid_0's binary_logloss: 0.366383
# [188]	valid_0's binary_logloss: 0.365591
# [189]	valid_0's binary_logloss: 0.365107
# [190]	valid_0's binary_logloss: 0.364454
# [191]	valid_0's binary_logloss: 0.363871
# [192]	valid_0's binary_logloss: 0.363259
# [193]	valid_0's binary_logloss: 0.362616
# [194]	valid_0's binary_logloss: 0.361764
# [195]	valid_0's binary_logloss: 0.361068
# [196]	valid_0's binary_logloss: 0.360372
# [197]	valid_0's binary_logloss: 0.359832
# [198]	valid_0's binary_logloss: 0.359288
# [199]	valid_0's binary_logloss: 0.358694
# [200]	valid_0's binary_logloss: 0.357949
# [201]	valid_0's binary_logloss: 0.357433
# [202]	valid_0's binary_logloss: 0.356978
# [203]	valid_0's binary_logloss: 0.356488
# [204]	valid_0's binary_logloss: 0.356123
# [205]	valid_0's binary_logloss: 0.355644
# [206]	valid_0's binary_logloss: 0.355172
# [207]	valid_0's binary_logloss: 0.354681
# [208]	valid_0's binary_logloss: 0.354104
# [209]	valid_0's binary_logloss: 0.353588
# [210]	valid_0's binary_logloss: 0.352984
# [211]	valid_0's binary_logloss: 0.352448
# [212]	valid_0's binary_logloss: 0.351924
# [213]	valid_0's binary_logloss: 0.351367
# [214]	valid_0's binary_logloss: 0.350994
# [215]	valid_0's binary_logloss: 0.350346
# [216]	valid_0's binary_logloss: 0.349679
# [217]	valid_0's binary_logloss: 0.349197
# [218]	valid_0's binary_logloss: 0.348811
# [219]	valid_0's binary_logloss: 0.348305
# [220]	valid_0's binary_logloss: 0.347941
# [221]	valid_0's binary_logloss: 0.347502
# [222]	valid_0's binary_logloss: 0.346892
# [223]	valid_0's binary_logloss: 0.346379
# [224]	valid_0's binary_logloss: 0.345758
# [225]	valid_0's binary_logloss: 0.345312
# [226]	valid_0's binary_logloss: 0.344725
# [227]	valid_0's binary_logloss: 0.344225
# [228]	valid_0's binary_logloss: 0.343679
# [229]	valid_0's binary_logloss: 0.343176
# [230]	valid_0's binary_logloss: 0.34264
# [231]	valid_0's binary_logloss: 0.342246
# [232]	valid_0's binary_logloss: 0.341788
# [233]	valid_0's binary_logloss: 0.341332
# [234]	valid_0's binary_logloss: 0.340878
# [235]	valid_0's binary_logloss: 0.340369
# [236]	valid_0's binary_logloss: 0.33999
# [237]	valid_0's binary_logloss: 0.339583
# [238]	valid_0's binary_logloss: 0.339079
# [239]	valid_0's binary_logloss: 0.338734
# [240]	valid_0's binary_logloss: 0.338217
# [241]	valid_0's binary_logloss: 0.337701
# [242]	valid_0's binary_logloss: 0.337224
# [243]	valid_0's binary_logloss: 0.336778
# [244]	valid_0's binary_logloss: 0.336333
# [245]	valid_0's binary_logloss: 0.335985
# [246]	valid_0's binary_logloss: 0.335616
# [247]	valid_0's binary_logloss: 0.335048
# [248]	valid_0's binary_logloss: 0.334676
# [249]	valid_0's binary_logloss: 0.334234
# [250]	valid_0's binary_logloss: 0.333928
# [251]	valid_0's binary_logloss: 0.333573
# [252]	valid_0's binary_logloss: 0.333185
# [253]	valid_0's binary_logloss: 0.33283
# [254]	valid_0's binary_logloss: 0.332229
# [255]	valid_0's binary_logloss: 0.331768
# [256]	valid_0's binary_logloss: 0.331482
# [257]	valid_0's binary_logloss: 0.330978
# [258]	valid_0's binary_logloss: 0.330538
# [259]	valid_0's binary_logloss: 0.33011
# [260]	valid_0's binary_logloss: 0.329825
# [261]	valid_0's binary_logloss: 0.329576
# [262]	valid_0's binary_logloss: 0.329245
# [263]	valid_0's binary_logloss: 0.328859
# [264]	valid_0's binary_logloss: 0.328526
# [265]	valid_0's binary_logloss: 0.328241
# [266]	valid_0's binary_logloss: 0.327991
# [267]	valid_0's binary_logloss: 0.32778
# [268]	valid_0's binary_logloss: 0.327428
# [269]	valid_0's binary_logloss: 0.327192
# [270]	valid_0's binary_logloss: 0.326888
# [271]	valid_0's binary_logloss: 0.326626
# [272]	valid_0's binary_logloss: 0.326256
# [273]	valid_0's binary_logloss: 0.325825
# [274]	valid_0's binary_logloss: 0.325437
# [275]	valid_0's binary_logloss: 0.325043
# [276]	valid_0's binary_logloss: 0.324762
# [277]	valid_0's binary_logloss: 0.324384
# [278]	valid_0's binary_logloss: 0.324037
# [279]	valid_0's binary_logloss: 0.32377
# [280]	valid_0's binary_logloss: 0.323515
# [281]	valid_0's binary_logloss: 0.323304
# [282]	valid_0's binary_logloss: 0.32296
# [283]	valid_0's binary_logloss: 0.322751
# [284]	valid_0's binary_logloss: 0.327443
# [285]	valid_0's binary_logloss: 0.327199
# [286]	valid_0's binary_logloss: 0.326972
# [287]	valid_0's binary_logloss: 0.3267
# [288]	valid_0's binary_logloss: 0.326387
# [289]	valid_0's binary_logloss: 0.326096
# [290]	valid_0's binary_logloss: 0.325819
# [291]	valid_0's binary_logloss: 0.325567
# [292]	valid_0's binary_logloss: 0.32542
# [293]	valid_0's binary_logloss: 0.32501
# [294]	valid_0's binary_logloss: 0.324799
# [295]	valid_0's binary_logloss: 0.324501
# [296]	valid_0's binary_logloss: 0.324136
# [297]	valid_0's binary_logloss: 0.323909
# [298]	valid_0's binary_logloss: 0.323664
# [299]	valid_0's binary_logloss: 0.323409
# [300]	valid_0's binary_logloss: 0.323201
# [301]	valid_0's binary_logloss: 0.323069
# [302]	valid_0's binary_logloss: 0.322794
# [303]	valid_0's binary_logloss: 0.322462
# [304]	valid_0's binary_logloss: 0.322171
# [305]	valid_0's binary_logloss: 0.321816
# [306]	valid_0's binary_logloss: 0.321558
# [307]	valid_0's binary_logloss: 0.321367
# [308]	valid_0's binary_logloss: 0.321148
# [309]	valid_0's binary_logloss: 0.320989
# [310]	valid_0's binary_logloss: 0.320696
# [311]	valid_0's binary_logloss: 0.320443
# [312]	valid_0's binary_logloss: 0.320187
# [313]	valid_0's binary_logloss: 0.319956
# [314]	valid_0's binary_logloss: 0.319695
# [315]	valid_0's binary_logloss: 0.319463
# [316]	valid_0's binary_logloss: 0.319237
# [317]	valid_0's binary_logloss: 0.319073
# [318]	valid_0's binary_logloss: 0.318859
# [319]	valid_0's binary_logloss: 0.318567
# [320]	valid_0's binary_logloss: 0.318376
# [321]	valid_0's binary_logloss: 0.318169
# [322]	valid_0's binary_logloss: 0.317995
# [323]	valid_0's binary_logloss: 0.317754
# [324]	valid_0's binary_logloss: 0.317611
# [325]	valid_0's binary_logloss: 0.317489
# [326]	valid_0's binary_logloss: 0.317258
# [327]	valid_0's binary_logloss: 0.317025
# [328]	valid_0's binary_logloss: 0.316764
# [329]	valid_0's binary_logloss: 0.316474
# [330]	valid_0's binary_logloss: 0.316331
# [331]	valid_0's binary_logloss: 0.316123
# [332]	valid_0's binary_logloss: 0.316013
# [333]	valid_0's binary_logloss: 0.315975
# [334]	valid_0's binary_logloss: 0.315878
# [335]	valid_0's binary_logloss: 0.315685
# [336]	valid_0's binary_logloss: 0.315487
# [337]	valid_0's binary_logloss: 0.315279
# [338]	valid_0's binary_logloss: 0.314988
# [339]	valid_0's binary_logloss: 0.314767
# [340]	valid_0's binary_logloss: 0.314534
# [341]	valid_0's binary_logloss: 0.314383
# [342]	valid_0's binary_logloss: 0.31424
# [343]	valid_0's binary_logloss: 0.314062
# [344]	valid_0's binary_logloss: 0.313758
# [345]	valid_0's binary_logloss: 0.313543
# [346]	valid_0's binary_logloss: 0.313366
# [347]	valid_0's binary_logloss: 0.313248
# [348]	valid_0's binary_logloss: 0.313076
# [349]	valid_0's binary_logloss: 0.31293
# [350]	valid_0's binary_logloss: 0.312761
# [351]	valid_0's binary_logloss: 0.312549
# [352]	valid_0's binary_logloss: 0.312498
# [353]	valid_0's binary_logloss: 0.312298
# [354]	valid_0's binary_logloss: 0.312234
# [355]	valid_0's binary_logloss: 0.312097
# [356]	valid_0's binary_logloss: 0.311826
# [357]	valid_0's binary_logloss: 0.311645
# [358]	valid_0's binary_logloss: 0.311456
# [359]	valid_0's binary_logloss: 0.311317
# [360]	valid_0's binary_logloss: 0.311103
# [361]	valid_0's binary_logloss: 0.31095
# [362]	valid_0's binary_logloss: 0.31083
# [363]	valid_0's binary_logloss: 0.310708
# [364]	valid_0's binary_logloss: 0.310614
# [365]	valid_0's binary_logloss: 0.310389
# [366]	valid_0's binary_logloss: 0.310282
# [367]	valid_0's binary_logloss: 0.310087
# [368]	valid_0's binary_logloss: 0.309905
# [369]	valid_0's binary_logloss: 0.309794
# [370]	valid_0's binary_logloss: 0.309549
# [371]	valid_0's binary_logloss: 0.309465
# [372]	valid_0's binary_logloss: 0.309409
# [373]	valid_0's binary_logloss: 0.309365
# [374]	valid_0's binary_logloss: 0.309181
# [375]	valid_0's binary_logloss: 0.309127
# [376]	valid_0's binary_logloss: 0.309033
# [377]	valid_0's binary_logloss: 0.308797
# [378]	valid_0's binary_logloss: 0.308716
# [379]	valid_0's binary_logloss: 0.308732
# [380]	valid_0's binary_logloss: 0.308528
# [381]	valid_0's binary_logloss: 0.308482
# [382]	valid_0's binary_logloss: 0.308483
# [383]	valid_0's binary_logloss: 0.313068
# [384]	valid_0's binary_logloss: 0.312991
# [385]	valid_0's binary_logloss: 0.312846
# [386]	valid_0's binary_logloss: 0.307743
# [387]	valid_0's binary_logloss: 0.307746
# [388]	valid_0's binary_logloss: 0.307886
# [389]	valid_0's binary_logloss: 0.312432
# [390]	valid_0's binary_logloss: 0.312286
# [391]	valid_0's binary_logloss: 0.312208
# [392]	valid_0's binary_logloss: 0.31205
# [393]	valid_0's binary_logloss: 0.311886
# [394]	valid_0's binary_logloss: 0.311828
# [395]	valid_0's binary_logloss: 0.31171
# [396]	valid_0's binary_logloss: 0.311588
# [397]	valid_0's binary_logloss: 0.31149
# [398]	valid_0's binary_logloss: 0.311412
# [399]	valid_0's binary_logloss: 0.311171
# [400]	valid_0's binary_logloss: 0.311011
# [401]	valid_0's binary_logloss: 0.310912
# [402]	valid_0's binary_logloss: 0.310712
# [403]	valid_0's binary_logloss: 0.310614
# [404]	valid_0's binary_logloss: 0.310598
# [405]	valid_0's binary_logloss: 0.310578
# [406]	valid_0's binary_logloss: 0.310439
# [407]	valid_0's binary_logloss: 0.310377
# [408]	valid_0's binary_logloss: 0.310238
# [409]	valid_0's binary_logloss: 0.310111
# [410]	valid_0's binary_logloss: 0.310074
# [411]	valid_0's binary_logloss: 0.309859
# [412]	valid_0's binary_logloss: 0.309722
# [413]	valid_0's binary_logloss: 0.309604
# [414]	valid_0's binary_logloss: 0.309521
# [415]	valid_0's binary_logloss: 0.309465
# [416]	valid_0's binary_logloss: 0.309498
# [417]	valid_0's binary_logloss: 0.309574
# [418]	valid_0's binary_logloss: 0.309504
# [419]	valid_0's binary_logloss: 0.314287
# [420]	valid_0's binary_logloss: 0.314214
# [421]	valid_0's binary_logloss: 0.314121
# [422]	valid_0's binary_logloss: 0.309375
# [423]	valid_0's binary_logloss: 0.309269
# [424]	valid_0's binary_logloss: 0.313866
# [425]	valid_0's binary_logloss: 0.313817
# [426]	valid_0's binary_logloss: 0.308754
# [427]	valid_0's binary_logloss: 0.308809
# [428]	valid_0's binary_logloss: 0.313559
# [429]	valid_0's binary_logloss: 0.31355
# [430]	valid_0's binary_logloss: 0.313457
# [431]	valid_0's binary_logloss: 0.313353
# [432]	valid_0's binary_logloss: 0.313255
# [433]	valid_0's binary_logloss: 0.313184
# [434]	valid_0's binary_logloss: 0.313113
# [435]	valid_0's binary_logloss: 0.313078
# [436]	valid_0's binary_logloss: 0.312994
# [437]	valid_0's binary_logloss: 0.312958
# [438]	valid_0's binary_logloss: 0.312958
# [439]	valid_0's binary_logloss: 0.312864
# [440]	valid_0's binary_logloss: 0.31278
# [441]	valid_0's binary_logloss: 0.312693
# [442]	valid_0's binary_logloss: 0.312608
# [443]	valid_0's binary_logloss: 0.312465
# [444]	valid_0's binary_logloss: 0.312375
# [445]	valid_0's binary_logloss: 0.312302
# [446]	valid_0's binary_logloss: 0.312255
# [447]	valid_0's binary_logloss: 0.312275
# [448]	valid_0's binary_logloss: 0.312231
# [449]	valid_0's binary_logloss: 0.312181
# [450]	valid_0's binary_logloss: 0.312154
# [451]	valid_0's binary_logloss: 0.31212
# [452]	valid_0's binary_logloss: 0.312119
# [453]	valid_0's binary_logloss: 0.311998
# [454]	valid_0's binary_logloss: 0.311932
# [455]	valid_0's binary_logloss: 0.31191
# [456]	valid_0's binary_logloss: 0.311843
# [457]	valid_0's binary_logloss: 0.311747
# [458]	valid_0's binary_logloss: 0.311615
# [459]	valid_0's binary_logloss: 0.311559
# [460]	valid_0's binary_logloss: 0.311531
# [461]	valid_0's binary_logloss: 0.311436
# [462]	valid_0's binary_logloss: 0.311379
# [463]	valid_0's binary_logloss: 0.311372
# [464]	valid_0's binary_logloss: 0.311302
# [465]	valid_0's binary_logloss: 0.311209
# [466]	valid_0's binary_logloss: 0.311106
# [467]	valid_0's binary_logloss: 0.311082
# [468]	valid_0's binary_logloss: 0.310989
# [469]	valid_0's binary_logloss: 0.310946
# [470]	valid_0's binary_logloss: 0.310941
# [471]	valid_0's binary_logloss: 0.310914
# [472]	valid_0's binary_logloss: 0.310855
# [473]	valid_0's binary_logloss: 0.310799
# [474]	valid_0's binary_logloss: 0.310733
# [475]	valid_0's binary_logloss: 0.310675
# [476]	valid_0's binary_logloss: 0.310661
# [477]	valid_0's binary_logloss: 0.31062
# [478]	valid_0's binary_logloss: 0.310601
# [479]	valid_0's binary_logloss: 0.310514
# [480]	valid_0's binary_logloss: 0.310472
# [481]	valid_0's binary_logloss: 0.310447
# [482]	valid_0's binary_logloss: 0.310343
# [483]	valid_0's binary_logloss: 0.310242
# [484]	valid_0's binary_logloss: 0.310142
# [485]	valid_0's binary_logloss: 0.310106
# [486]	valid_0's binary_logloss: 0.310039
# [487]	valid_0's binary_logloss: 0.30996
# [488]	valid_0's binary_logloss: 0.309974
# [489]	valid_0's binary_logloss: 0.309911
# [490]	valid_0's binary_logloss: 0.309804
# [491]	valid_0's binary_logloss: 0.309799
# [492]	valid_0's binary_logloss: 0.309748
# [493]	valid_0's binary_logloss: 0.309658
# [494]	valid_0's binary_logloss: 0.309686
# [495]	valid_0's binary_logloss: 0.309633
# [496]	valid_0's binary_logloss: 0.309619
# [497]	valid_0's binary_logloss: 0.309562
# [498]	valid_0's binary_logloss: 0.309533
# [499]	valid_0's binary_logloss: 0.309448
# [500]	valid_0's binary_logloss: 0.309382
# [501]	valid_0's binary_logloss: 0.309379
# [502]	valid_0's binary_logloss: 0.309331
# [503]	valid_0's binary_logloss: 0.309281
# [504]	valid_0's binary_logloss: 0.309245
# [505]	valid_0's binary_logloss: 0.309267
# [506]	valid_0's binary_logloss: 0.309248
# [507]	valid_0's binary_logloss: 0.309186
# [508]	valid_0's binary_logloss: 0.309163
# [509]	valid_0's binary_logloss: 0.309126
# [510]	valid_0's binary_logloss: 0.309068
# [511]	valid_0's binary_logloss: 0.309036
# [512]	valid_0's binary_logloss: 0.309023
# [513]	valid_0's binary_logloss: 0.308984
# [514]	valid_0's binary_logloss: 0.308906
# [515]	valid_0's binary_logloss: 0.308918
# [516]	valid_0's binary_logloss: 0.308851
# [517]	valid_0's binary_logloss: 0.308806
# [518]	valid_0's binary_logloss: 0.308768
# [519]	valid_0's binary_logloss: 0.308682
# [520]	valid_0's binary_logloss: 0.308681
# [521]	valid_0's binary_logloss: 0.308631
# [522]	valid_0's binary_logloss: 0.308603
# [523]	valid_0's binary_logloss: 0.308542
# [524]	valid_0's binary_logloss: 0.308524
# [525]	valid_0's binary_logloss: 0.308501
# [526]	valid_0's binary_logloss: 0.308443
# [527]	valid_0's binary_logloss: 0.308442
# [528]	valid_0's binary_logloss: 0.30841
# [529]	valid_0's binary_logloss: 0.308402
# [530]	valid_0's binary_logloss: 0.308388
# [531]	valid_0's binary_logloss: 0.30838
# [532]	valid_0's binary_logloss: 0.308374
# [533]	valid_0's binary_logloss: 0.308367
# [534]	valid_0's binary_logloss: 0.308296
# [535]	valid_0's binary_logloss: 0.308248
# [536]	valid_0's binary_logloss: 0.308169
# [537]	valid_0's binary_logloss: 0.308123
# [538]	valid_0's binary_logloss: 0.30806
# [539]	valid_0's binary_logloss: 0.308034
# [540]	valid_0's binary_logloss: 0.30803
# [541]	valid_0's binary_logloss: 0.307988
# [542]	valid_0's binary_logloss: 0.30797
# [543]	valid_0's binary_logloss: 0.307958
# [544]	valid_0's binary_logloss: 0.307962
# [545]	valid_0's binary_logloss: 0.307926
# [546]	valid_0's binary_logloss: 0.307872
# [547]	valid_0's binary_logloss: 0.307841
# [548]	valid_0's binary_logloss: 0.307842
# [549]	valid_0's binary_logloss: 0.307773
# [550]	valid_0's binary_logloss: 0.307775
# [551]	valid_0's binary_logloss: 0.307776
# [552]	valid_0's binary_logloss: 0.307817
# [553]	valid_0's binary_logloss: 0.307765
# [554]	valid_0's binary_logloss: 0.307745
# [555]	valid_0's binary_logloss: 0.30772
# [556]	valid_0's binary_logloss: 0.307692
# [557]	valid_0's binary_logloss: 0.307693
# [558]	valid_0's binary_logloss: 0.307634
# [559]	valid_0's binary_logloss: 0.307601
# [560]	valid_0's binary_logloss: 0.307556
# [561]	valid_0's binary_logloss: 0.307522
# [562]	valid_0's binary_logloss: 0.30753
# [563]	valid_0's binary_logloss: 0.30749
# [564]	valid_0's binary_logloss: 0.307445
# [565]	valid_0's binary_logloss: 0.307397
# [566]	valid_0's binary_logloss: 0.307365
# [567]	valid_0's binary_logloss: 0.307309
# [568]	valid_0's binary_logloss: 0.307286
# [569]	valid_0's binary_logloss: 0.307231
# [570]	valid_0's binary_logloss: 0.307219
# [571]	valid_0's binary_logloss: 0.307171
# [572]	valid_0's binary_logloss: 0.307112
# [573]	valid_0's binary_logloss: 0.307097
# [574]	valid_0's binary_logloss: 0.307048
# [575]	valid_0's binary_logloss: 0.307019
# [576]	valid_0's binary_logloss: 0.307008
# [577]	valid_0's binary_logloss: 0.307018
# [578]	valid_0's binary_logloss: 0.307013
# [579]	valid_0's binary_logloss: 0.30699
# [580]	valid_0's binary_logloss: 0.306977
# [581]	valid_0's binary_logloss: 0.306987
# [582]	valid_0's binary_logloss: 0.306959
# [583]	valid_0's binary_logloss: 0.306954
# [584]	valid_0's binary_logloss: 0.306916
# [585]	valid_0's binary_logloss: 0.306891
# [586]	valid_0's binary_logloss: 0.306832
# [587]	valid_0's binary_logloss: 0.306823
# [588]	valid_0's binary_logloss: 0.306814
# [589]	valid_0's binary_logloss: 0.306821
# [590]	valid_0's binary_logloss: 0.306809
# [591]	valid_0's binary_logloss: 0.306774
# [592]	valid_0's binary_logloss: 0.30673
# [593]	valid_0's binary_logloss: 0.306666
# [594]	valid_0's binary_logloss: 0.306656
# [595]	valid_0's binary_logloss: 0.306671
# [596]	valid_0's binary_logloss: 0.306716
# [597]	valid_0's binary_logloss: 0.306683
# [598]	valid_0's binary_logloss: 0.306682
# [599]	valid_0's binary_logloss: 0.306625
# [600]	valid_0's binary_logloss: 0.306651
# [601]	valid_0's binary_logloss: 0.30662
# [602]	valid_0's binary_logloss: 0.306648
# [603]	valid_0's binary_logloss: 0.30674
# [604]	valid_0's binary_logloss: 0.306699
# [605]	valid_0's binary_logloss: 0.306645
# [606]	valid_0's binary_logloss: 0.306625
# [607]	valid_0's binary_logloss: 0.306633
# [608]	valid_0's binary_logloss: 0.306525
# [609]	valid_0's binary_logloss: 0.306551
# [610]	valid_0's binary_logloss: 0.306559
# [611]	valid_0's binary_logloss: 0.306559
# [612]	valid_0's binary_logloss: 0.306492
# [613]	valid_0's binary_logloss: 0.30646
# [614]	valid_0's binary_logloss: 0.30637
# [615]	valid_0's binary_logloss: 0.306351
# [616]	valid_0's binary_logloss: 0.30633
# [617]	valid_0's binary_logloss: 0.306336
# [618]	valid_0's binary_logloss: 0.306393
# [619]	valid_0's binary_logloss: 0.306433
# [620]	valid_0's binary_logloss: 0.306406
# [621]	valid_0's binary_logloss: 0.306419
# [622]	valid_0's binary_logloss: 0.306433
# [623]	valid_0's binary_logloss: 0.30642
# [624]	valid_0's binary_logloss: 0.306325
# [625]	valid_0's binary_logloss: 0.306292
# [626]	valid_0's binary_logloss: 0.306336
# [627]	valid_0's binary_logloss: 0.306588
# [628]	valid_0's binary_logloss: 0.311313
# [629]	valid_0's binary_logloss: 0.306886
# [630]	valid_0's binary_logloss: 0.311294
# [631]	valid_0's binary_logloss: 0.311296
# [632]	valid_0's binary_logloss: 0.311286
# [633]	valid_0's binary_logloss: 0.311256
# [634]	valid_0's binary_logloss: 0.311238
# [635]	valid_0's binary_logloss: 0.311229
# [636]	valid_0's binary_logloss: 0.311186
# [637]	valid_0's binary_logloss: 0.311181
# [638]	valid_0's binary_logloss: 0.311178
# [639]	valid_0's binary_logloss: 0.311125
# [640]	valid_0's binary_logloss: 0.311091
# [641]	valid_0's binary_logloss: 0.311051
# [642]	valid_0's binary_logloss: 0.311055
# [643]	valid_0's binary_logloss: 0.311023
# [644]	valid_0's binary_logloss: 0.311014
# [645]	valid_0's binary_logloss: 0.311021
# [646]	valid_0's binary_logloss: 0.311028
# [647]	valid_0's binary_logloss: 0.311036
# [648]	valid_0's binary_logloss: 0.311031
# [649]	valid_0's binary_logloss: 0.311032
# [650]	valid_0's binary_logloss: 0.310998
# [651]	valid_0's binary_logloss: 0.310985
# [652]	valid_0's binary_logloss: 0.310972
# [653]	valid_0's binary_logloss: 0.310948
# [654]	valid_0's binary_logloss: 0.310942
# [655]	valid_0's binary_logloss: 0.310931
# [656]	valid_0's binary_logloss: 0.310916
# [657]	valid_0's binary_logloss: 0.310898
# [658]	valid_0's binary_logloss: 0.310877
# [659]	valid_0's binary_logloss: 0.310859
# [660]	valid_0's binary_logloss: 0.310842
# [661]	valid_0's binary_logloss: 0.310844
# [662]	valid_0's binary_logloss: 0.310838
# [663]	valid_0's binary_logloss: 0.310835
# [664]	valid_0's binary_logloss: 0.31085
# [665]	valid_0's binary_logloss: 0.310859
# [666]	valid_0's binary_logloss: 0.310829
# [667]	valid_0's binary_logloss: 0.310816
# [668]	valid_0's binary_logloss: 0.310784
# [669]	valid_0's binary_logloss: 0.310763
# [670]	valid_0's binary_logloss: 0.310753
# [671]	valid_0's binary_logloss: 0.310741
# [672]	valid_0's binary_logloss: 0.310729
# [673]	valid_0's binary_logloss: 0.310724
# [674]	valid_0's binary_logloss: 0.310738
# [675]	valid_0's binary_logloss: 0.310741
# [676]	valid_0's binary_logloss: 0.310733
# [677]	valid_0's binary_logloss: 0.310735
# [678]	valid_0's binary_logloss: 0.310725
# [679]	valid_0's binary_logloss: 0.310709
# [680]	valid_0's binary_logloss: 0.310709
# [681]	valid_0's binary_logloss: 0.310688
# [682]	valid_0's binary_logloss: 0.310665
# [683]	valid_0's binary_logloss: 0.310669
# [684]	valid_0's binary_logloss: 0.310674
# [685]	valid_0's binary_logloss: 0.310687
# [686]	valid_0's binary_logloss: 0.310649
# [687]	valid_0's binary_logloss: 0.310655
# [688]	valid_0's binary_logloss: 0.310632
# [689]	valid_0's binary_logloss: 0.310646
# [690]	valid_0's binary_logloss: 0.310629
# [691]	valid_0's binary_logloss: 0.31064
# [692]	valid_0's binary_logloss: 0.310642
# [693]	valid_0's binary_logloss: 0.31059
# [694]	valid_0's binary_logloss: 0.310578
# [695]	valid_0's binary_logloss: 0.310572
# [696]	valid_0's binary_logloss: 0.31056
# [697]	valid_0's binary_logloss: 0.310573
# [698]	valid_0's binary_logloss: 0.31057
# [699]	valid_0's binary_logloss: 0.310589
# [700]	valid_0's binary_logloss: 0.310595
# [701]	valid_0's binary_logloss: 0.310602
# [702]	valid_0's binary_logloss: 0.310597
# [703]	valid_0's binary_logloss: 0.310627
# [704]	valid_0's binary_logloss: 0.310649
# [705]	valid_0's binary_logloss: 0.310639
# [706]	valid_0's binary_logloss: 0.310676
# [707]	valid_0's binary_logloss: 0.310645
# [708]	valid_0's binary_logloss: 0.310639
# [709]	valid_0's binary_logloss: 0.310638
# [710]	valid_0's binary_logloss: 0.310658
# [711]	valid_0's binary_logloss: 0.310634
# [712]	valid_0's binary_logloss: 0.310651
# [713]	valid_0's binary_logloss: 0.31063
# [714]	valid_0's binary_logloss: 0.310635
# [715]	valid_0's binary_logloss: 0.310599
# [716]	valid_0's binary_logloss: 0.310602
# [717]	valid_0's binary_logloss: 0.310632
# [718]	valid_0's binary_logloss: 0.31064
# [719]	valid_0's binary_logloss: 0.310614
# [720]	valid_0's binary_logloss: 0.310582
# [721]	valid_0's binary_logloss: 0.310561
# [722]	valid_0's binary_logloss: 0.310558
# [723]	valid_0's binary_logloss: 0.310587
# [724]	valid_0's binary_logloss: 0.31059
# [725]	valid_0's binary_logloss: 0.310607
# [726]	valid_0's binary_logloss: 0.310615
# [727]	valid_0's binary_logloss: 0.310563
# [728]	valid_0's binary_logloss: 0.310543
# [729]	valid_0's binary_logloss: 0.310522
# [730]	valid_0's binary_logloss: 0.310566
# [731]	valid_0's binary_logloss: 0.310574
# [732]	valid_0's binary_logloss: 0.310542
# [733]	valid_0's binary_logloss: 0.310577
# [734]	valid_0's binary_logloss: 0.310589
# [735]	valid_0's binary_logloss: 0.310607
# [736]	valid_0's binary_logloss: 0.310626
# [737]	valid_0's binary_logloss: 0.310635
# [738]	valid_0's binary_logloss: 0.310704
# [739]	valid_0's binary_logloss: 0.310924
# [740]	valid_0's binary_logloss: 0.310615
# [741]	valid_0's binary_logloss: 0.310708
# [742]	valid_0's binary_logloss: 0.310667
# [743]	valid_0's binary_logloss: 0.310665
# [744]	valid_0's binary_logloss: 0.31086
# [745]	valid_0's binary_logloss: 0.310954
# [746]	valid_0's binary_logloss: 0.31058
# [747]	valid_0's binary_logloss: 0.310478
# [748]	valid_0's binary_logloss: 0.310465
# [749]	valid_0's binary_logloss: 0.310409
# [750]	valid_0's binary_logloss: 0.310401
# [751]	valid_0's binary_logloss: 0.310357
# [752]	valid_0's binary_logloss: 0.310358
# [753]	valid_0's binary_logloss: 0.310384
# [754]	valid_0's binary_logloss: 0.310385
# [755]	valid_0's binary_logloss: 0.310381
# [756]	valid_0's binary_logloss: 0.310381
# [757]	valid_0's binary_logloss: 0.310375
# [758]	valid_0's binary_logloss: 0.31041
# [759]	valid_0's binary_logloss: 0.310406
# [760]	valid_0's binary_logloss: 0.310405
# [761]	valid_0's binary_logloss: 0.310419
# [762]	valid_0's binary_logloss: 0.310388
# [763]	valid_0's binary_logloss: 0.310345
# [764]	valid_0's binary_logloss: 0.310356
# [765]	valid_0's binary_logloss: 0.310365
# [766]	valid_0's binary_logloss: 0.31038
# [767]	valid_0's binary_logloss: 0.310369
# [768]	valid_0's binary_logloss: 0.310411
# [769]	valid_0's binary_logloss: 0.310568
# [770]	valid_0's binary_logloss: 0.310739
# [771]	valid_0's binary_logloss: 0.310667
# [772]	valid_0's binary_logloss: 0.310705
# [773]	valid_0's binary_logloss: 0.310731
# [774]	valid_0's binary_logloss: 0.315343
# [775]	valid_0's binary_logloss: 0.31065
# [776]	valid_0's binary_logloss: 0.310502
# [777]	valid_0's binary_logloss: 0.31077
# [778]	valid_0's binary_logloss: 0.310595
# [779]	valid_0's binary_logloss: 0.310349
# [780]	valid_0's binary_logloss: 0.310355
# [781]	valid_0's binary_logloss: 0.310474
# [782]	valid_0's binary_logloss: 0.315285
# [783]	valid_0's binary_logloss: 0.310692
# [784]	valid_0's binary_logloss: 0.315269
# [785]	valid_0's binary_logloss: 0.315276
# [786]	valid_0's binary_logloss: 0.315263
# [787]	valid_0's binary_logloss: 0.315251
# [788]	valid_0's binary_logloss: 0.31524
# [789]	valid_0's binary_logloss: 0.315248
# [790]	valid_0's binary_logloss: 0.31524
# [791]	valid_0's binary_logloss: 0.31523
# [792]	valid_0's binary_logloss: 0.315226
# [793]	valid_0's binary_logloss: 0.315222
# [794]	valid_0's binary_logloss: 0.315212
# [795]	valid_0's binary_logloss: 0.315216
# [796]	valid_0's binary_logloss: 0.315211
# [797]	valid_0's binary_logloss: 0.315196
# [798]	valid_0's binary_logloss: 0.31519
# [799]	valid_0's binary_logloss: 0.31519
# [800]	valid_0's binary_logloss: 0.315193
# [801]	valid_0's binary_logloss: 0.315195
# [802]	valid_0's binary_logloss: 0.315192
# [803]	valid_0's binary_logloss: 0.315184
# [804]	valid_0's binary_logloss: 0.315188
# [805]	valid_0's binary_logloss: 0.315178
# [806]	valid_0's binary_logloss: 0.315158
# [807]	valid_0's binary_logloss: 0.315156
# [808]	valid_0's binary_logloss: 0.315152
# [809]	valid_0's binary_logloss: 0.315146
# [810]	valid_0's binary_logloss: 0.315144
# [811]	valid_0's binary_logloss: 0.315141
# [812]	valid_0's binary_logloss: 0.315129
# [813]	valid_0's binary_logloss: 0.315128
# [814]	valid_0's binary_logloss: 0.315116
# [815]	valid_0's binary_logloss: 0.315104
# [816]	valid_0's binary_logloss: 0.315113
# [817]	valid_0's binary_logloss: 0.31511
# [818]	valid_0's binary_logloss: 0.315105
# [819]	valid_0's binary_logloss: 0.315087
# [820]	valid_0's binary_logloss: 0.315075
# [821]	valid_0's binary_logloss: 0.315067
# [822]	valid_0's binary_logloss: 0.315054
# [823]	valid_0's binary_logloss: 0.315046
# [824]	valid_0's binary_logloss: 0.315039
# [825]	valid_0's binary_logloss: 0.315026
# [826]	valid_0's binary_logloss: 0.315007
# [827]	valid_0's binary_logloss: 0.315014
# [828]	valid_0's binary_logloss: 0.315013
# [829]	valid_0's binary_logloss: 0.315006
# [830]	valid_0's binary_logloss: 0.314993
# [831]	valid_0's binary_logloss: 0.314997
# [832]	valid_0's binary_logloss: 0.314995
# [833]	valid_0's binary_logloss: 0.314987
# [834]	valid_0's binary_logloss: 0.31498
# [835]	valid_0's binary_logloss: 0.314971
# [836]	valid_0's binary_logloss: 0.314959
# [837]	valid_0's binary_logloss: 0.314971
# [838]	valid_0's binary_logloss: 0.314954
# [839]	valid_0's binary_logloss: 0.314931
# [840]	valid_0's binary_logloss: 0.314929
# [841]	valid_0's binary_logloss: 0.314918
# [842]	valid_0's binary_logloss: 0.314919
# [843]	valid_0's binary_logloss: 0.314923
# [844]	valid_0's binary_logloss: 0.314911
# [845]	valid_0's binary_logloss: 0.314915
# [846]	valid_0's binary_logloss: 0.314912
# [847]	valid_0's binary_logloss: 0.314915
# [848]	valid_0's binary_logloss: 0.314917
# [849]	valid_0's binary_logloss: 0.3149
# [850]	valid_0's binary_logloss: 0.314899
# [851]	valid_0's binary_logloss: 0.314895
# [852]	valid_0's binary_logloss: 0.314896
# [853]	valid_0's binary_logloss: 0.314886
# [854]	valid_0's binary_logloss: 0.314887
# [855]	valid_0's binary_logloss: 0.314888
# [856]	valid_0's binary_logloss: 0.314881
# [857]	valid_0's binary_logloss: 0.314867
# [858]	valid_0's binary_logloss: 0.314856
# [859]	valid_0's binary_logloss: 0.314855
# [860]	valid_0's binary_logloss: 0.314849
# [861]	valid_0's binary_logloss: 0.314842
# [862]	valid_0's binary_logloss: 0.314829
# [863]	valid_0's binary_logloss: 0.314817
# [864]	valid_0's binary_logloss: 0.31481
# [865]	valid_0's binary_logloss: 0.3148
# [866]	valid_0's binary_logloss: 0.314784
# [867]	valid_0's binary_logloss: 0.314786
# [868]	valid_0's binary_logloss: 0.314772
# [869]	valid_0's binary_logloss: 0.314773
# [870]	valid_0's binary_logloss: 0.314764
# [871]	valid_0's binary_logloss: 0.314763
# [872]	valid_0's binary_logloss: 0.314748
# [873]	valid_0's binary_logloss: 0.314744
# [874]	valid_0's binary_logloss: 0.314755
# [875]	valid_0's binary_logloss: 0.314754
# [876]	valid_0's binary_logloss: 0.314741
# [877]	valid_0's binary_logloss: 0.314733
# [878]	valid_0's binary_logloss: 0.314735
# [879]	valid_0's binary_logloss: 0.314721
# [880]	valid_0's binary_logloss: 0.314703
# [881]	valid_0's binary_logloss: 0.314691
# [882]	valid_0's binary_logloss: 0.314696
# [883]	valid_0's binary_logloss: 0.310004
# [884]	valid_0's binary_logloss: 0.309806
# [885]	valid_0's binary_logloss: 0.309883
# [886]	valid_0's binary_logloss: 0.31467
# [887]	valid_0's binary_logloss: 0.309969
# [888]	valid_0's binary_logloss: 0.309793
# [889]	valid_0's binary_logloss: 0.30994
# [890]	valid_0's binary_logloss: 0.309964
# [891]	valid_0's binary_logloss: 0.310133
# [892]	valid_0's binary_logloss: 0.314657
# [893]	valid_0's binary_logloss: 0.314649
# [894]	valid_0's binary_logloss: 0.310089
# [895]	valid_0's binary_logloss: 0.314635
# [896]	valid_0's binary_logloss: 0.314633
# [897]	valid_0's binary_logloss: 0.314633
# [898]	valid_0's binary_logloss: 0.314639
# [899]	valid_0's binary_logloss: 0.314622
# [900]	valid_0's binary_logloss: 0.314617
# [901]	valid_0's binary_logloss: 0.314623
# [902]	valid_0's binary_logloss: 0.314616
# [903]	valid_0's binary_logloss: 0.314612
# [904]	valid_0's binary_logloss: 0.314604
# [905]	valid_0's binary_logloss: 0.314613
# [906]	valid_0's binary_logloss: 0.31461
# [907]	valid_0's binary_logloss: 0.314613
# [908]	valid_0's binary_logloss: 0.314609
# [909]	valid_0's binary_logloss: 0.314606
# [910]	valid_0's binary_logloss: 0.314604
# [911]	valid_0's binary_logloss: 0.31461
# [912]	valid_0's binary_logloss: 0.314596
# [913]	valid_0's binary_logloss: 0.314599
# [914]	valid_0's binary_logloss: 0.314592
# [915]	valid_0's binary_logloss: 0.314591
# [916]	valid_0's binary_logloss: 0.314587
# [917]	valid_0's binary_logloss: 0.314585
# [918]	valid_0's binary_logloss: 0.314584
# [919]	valid_0's binary_logloss: 0.314588
# [920]	valid_0's binary_logloss: 0.314586
# [921]	valid_0's binary_logloss: 0.314574
# [922]	valid_0's binary_logloss: 0.314563
# [923]	valid_0's binary_logloss: 0.314565
# [924]	valid_0's binary_logloss: 0.314554
# [925]	valid_0's binary_logloss: 0.314549
# [926]	valid_0's binary_logloss: 0.314551
# [927]	valid_0's binary_logloss: 0.314564
# [928]	valid_0's binary_logloss: 0.314558
# [929]	valid_0's binary_logloss: 0.31456
# [930]	valid_0's binary_logloss: 0.314552
# [931]	valid_0's binary_logloss: 0.314545
# [932]	valid_0's binary_logloss: 0.31454
# [933]	valid_0's binary_logloss: 0.314546
# [934]	valid_0's binary_logloss: 0.314545
# [935]	valid_0's binary_logloss: 0.31454
# [936]	valid_0's binary_logloss: 0.314535
# [937]	valid_0's binary_logloss: 0.314533
# [938]	valid_0's binary_logloss: 0.314536
# [939]	valid_0's binary_logloss: 0.314539
# [940]	valid_0's binary_logloss: 0.314533
# [941]	valid_0's binary_logloss: 0.314541
# [942]	valid_0's binary_logloss: 0.314531
# [943]	valid_0's binary_logloss: 0.314532
# [944]	valid_0's binary_logloss: 0.314523
# [945]	valid_0's binary_logloss: 0.314524
# [946]	valid_0's binary_logloss: 0.314522
# [947]	valid_0's binary_logloss: 0.31451
# [948]	valid_0's binary_logloss: 0.314509
# [949]	valid_0's binary_logloss: 0.314494
# [950]	valid_0's binary_logloss: 0.314483
# [951]	valid_0's binary_logloss: 0.31448
# [952]	valid_0's binary_logloss: 0.314469
# [953]	valid_0's binary_logloss: 0.314471
# [954]	valid_0's binary_logloss: 0.314462
# [955]	valid_0's binary_logloss: 0.31446
# [956]	valid_0's binary_logloss: 0.314458
# [957]	valid_0's binary_logloss: 0.314452
# [958]	valid_0's binary_logloss: 0.314448
# [959]	valid_0's binary_logloss: 0.314439
# [960]	valid_0's binary_logloss: 0.314448
# [961]	valid_0's binary_logloss: 0.314454
# [962]	valid_0's binary_logloss: 0.314446
# [963]	valid_0's binary_logloss: 0.314446
# [964]	valid_0's binary_logloss: 0.314447
# [965]	valid_0's binary_logloss: 0.314447
# [966]	valid_0's binary_logloss: 0.314445
# [967]	valid_0's binary_logloss: 0.314436
# [968]	valid_0's binary_logloss: 0.31444
# [969]	valid_0's binary_logloss: 0.314439
# [970]	valid_0's binary_logloss: 0.314416
# [971]	valid_0's binary_logloss: 0.314413
# [972]	valid_0's binary_logloss: 0.314404
# [973]	valid_0's binary_logloss: 0.314401
# [974]	valid_0's binary_logloss: 0.314392
# [975]	valid_0's binary_logloss: 0.314395
# [976]	valid_0's binary_logloss: 0.314387
# [977]	valid_0's binary_logloss: 0.314386
# [978]	valid_0's binary_logloss: 0.31438
# [979]	valid_0's binary_logloss: 0.31438
# [980]	valid_0's binary_logloss: 0.314388
# [981]	valid_0's binary_logloss: 0.314386
# [982]	valid_0's binary_logloss: 0.314387
# [983]	valid_0's binary_logloss: 0.314391
# [984]	valid_0's binary_logloss: 0.314385
# [985]	valid_0's binary_logloss: 0.314385
# [986]	valid_0's binary_logloss: 0.314388
# [987]	valid_0's binary_logloss: 0.314398
# [988]	valid_0's binary_logloss: 0.314401
# [989]	valid_0's binary_logloss: 0.314402
# [990]	valid_0's binary_logloss: 0.3144
# [991]	valid_0's binary_logloss: 0.314407
# [992]	valid_0's binary_logloss: 0.314405
# [993]	valid_0's binary_logloss: 0.314401
# [994]	valid_0's binary_logloss: 0.314401
# [995]	valid_0's binary_logloss: 0.314406
# [996]	valid_0's binary_logloss: 0.314404
# [997]	valid_0's binary_logloss: 0.314401
# [998]	valid_0's binary_logloss: 0.314394
# [999]	valid_0's binary_logloss: 0.314387
# [1000]	valid_0's binary_logloss: 0.314386
# [1001]	valid_0's binary_logloss: 0.314376
# [1002]	valid_0's binary_logloss: 0.314377
# [1003]	valid_0's binary_logloss: 0.314376
# [1004]	valid_0's binary_logloss: 0.314373
# [1005]	valid_0's binary_logloss: 0.314366
# [1006]	valid_0's binary_logloss: 0.314362
# [1007]	valid_0's binary_logloss: 0.314359
# [1008]	valid_0's binary_logloss: 0.314361
# [1009]	valid_0's binary_logloss: 0.314363
# [1010]	valid_0's binary_logloss: 0.314367
# [1011]	valid_0's binary_logloss: 0.31436
# [1012]	valid_0's binary_logloss: 0.314356
# [1013]	valid_0's binary_logloss: 0.314342
# [1014]	valid_0's binary_logloss: 0.31434
# [1015]	valid_0's binary_logloss: 0.314345
# [1016]	valid_0's binary_logloss: 0.314348
# [1017]	valid_0's binary_logloss: 0.314344
# [1018]	valid_0's binary_logloss: 0.314349
# [1019]	valid_0's binary_logloss: 0.314342
# [1020]	valid_0's binary_logloss: 0.314337
# [1021]	valid_0's binary_logloss: 0.314329
# [1022]	valid_0's binary_logloss: 0.314325
# [1023]	valid_0's binary_logloss: 0.314324
# [1024]	valid_0's binary_logloss: 0.314325
# [1025]	valid_0's binary_logloss: 0.314325
# [1026]	valid_0's binary_logloss: 0.31432
# [1027]	valid_0's binary_logloss: 0.314312
# [1028]	valid_0's binary_logloss: 0.314316
# [1029]	valid_0's binary_logloss: 0.314316
# [1030]	valid_0's binary_logloss: 0.314308
# [1031]	valid_0's binary_logloss: 0.314303
# [1032]	valid_0's binary_logloss: 0.314305
# [1033]	valid_0's binary_logloss: 0.3143
# [1034]	valid_0's binary_logloss: 0.3143
# [1035]	valid_0's binary_logloss: 0.314293
# [1036]	valid_0's binary_logloss: 0.314286
# [1037]	valid_0's binary_logloss: 0.314286
# [1038]	valid_0's binary_logloss: 0.314278
# [1039]	valid_0's binary_logloss: 0.314281
# [1040]	valid_0's binary_logloss: 0.314278
# [1041]	valid_0's binary_logloss: 0.314279
# [1042]	valid_0's binary_logloss: 0.314278
# [1043]	valid_0's binary_logloss: 0.314281
# [1044]	valid_0's binary_logloss: 0.314282
# [1045]	valid_0's binary_logloss: 0.31428
# [1046]	valid_0's binary_logloss: 0.314285
# [1047]	valid_0's binary_logloss: 0.314281
# [1048]	valid_0's binary_logloss: 0.314282
# [1049]	valid_0's binary_logloss: 0.314279
# [1050]	valid_0's binary_logloss: 0.314279
# [1051]	valid_0's binary_logloss: 0.314274
# [1052]	valid_0's binary_logloss: 0.314271
# [1053]	valid_0's binary_logloss: 0.314275
# [1054]	valid_0's binary_logloss: 0.314272
# [1055]	valid_0's binary_logloss: 0.314267
# [1056]	valid_0's binary_logloss: 0.31427
# [1057]	valid_0's binary_logloss: 0.314267
# [1058]	valid_0's binary_logloss: 0.31427
# [1059]	valid_0's binary_logloss: 0.314266
# [1060]	valid_0's binary_logloss: 0.314268
# [1061]	valid_0's binary_logloss: 0.31426
# [1062]	valid_0's binary_logloss: 0.314251
# [1063]	valid_0's binary_logloss: 0.314246
# [1064]	valid_0's binary_logloss: 0.314245
# [1065]	valid_0's binary_logloss: 0.314242
# [1066]	valid_0's binary_logloss: 0.314239
# [1067]	valid_0's binary_logloss: 0.314236
# [1068]	valid_0's binary_logloss: 0.314236
# [1069]	valid_0's binary_logloss: 0.314233
# [1070]	valid_0's binary_logloss: 0.314234
# [1071]	valid_0's binary_logloss: 0.314235
# [1072]	valid_0's binary_logloss: 0.314233
# [1073]	valid_0's binary_logloss: 0.314235
# [1074]	valid_0's binary_logloss: 0.31423
# [1075]	valid_0's binary_logloss: 0.314229
# [1076]	valid_0's binary_logloss: 0.314232
# [1077]	valid_0's binary_logloss: 0.314231
# [1078]	valid_0's binary_logloss: 0.314235
# [1079]	valid_0's binary_logloss: 0.314231
# [1080]	valid_0's binary_logloss: 0.314231
# [1081]	valid_0's binary_logloss: 0.314229
# [1082]	valid_0's binary_logloss: 0.314223
# [1083]	valid_0's binary_logloss: 0.31422
# [1084]	valid_0's binary_logloss: 0.31422
# [1085]	valid_0's binary_logloss: 0.314222
# [1086]	valid_0's binary_logloss: 0.314223
# [1087]	valid_0's binary_logloss: 0.314221
# [1088]	valid_0's binary_logloss: 0.314216
# [1089]	valid_0's binary_logloss: 0.314211
# [1090]	valid_0's binary_logloss: 0.314208
# [1091]	valid_0's binary_logloss: 0.314207
# [1092]	valid_0's binary_logloss: 0.314206
# [1093]	valid_0's binary_logloss: 0.314202
# [1094]	valid_0's binary_logloss: 0.314205
# [1095]	valid_0's binary_logloss: 0.310172
# [1096]	valid_0's binary_logloss: 0.314215
# [1097]	valid_0's binary_logloss: 0.314212
# [1098]	valid_0's binary_logloss: 0.314209
# [1099]	valid_0's binary_logloss: 0.314205
# [1100]	valid_0's binary_logloss: 0.314198
# [1101]	valid_0's binary_logloss: 0.314196
# [1102]	valid_0's binary_logloss: 0.314191
# [1103]	valid_0's binary_logloss: 0.31419
# [1104]	valid_0's binary_logloss: 0.31419
# [1105]	valid_0's binary_logloss: 0.309638
# [1106]	valid_0's binary_logloss: 0.30955
# [1107]	valid_0's binary_logloss: 0.30952
# [1108]	valid_0's binary_logloss: 0.309426
# [1109]	valid_0's binary_logloss: 0.309395
# [1110]	valid_0's binary_logloss: 0.309435
# [1111]	valid_0's binary_logloss: 0.30953
# [1112]	valid_0's binary_logloss: 0.309451
# [1113]	valid_0's binary_logloss: 0.309937
# [1114]	valid_0's binary_logloss: 0.309559
# [1115]	valid_0's binary_logloss: 0.309373
# [1116]	valid_0's binary_logloss: 0.30942
# [1117]	valid_0's binary_logloss: 0.309408
# [1118]	valid_0's binary_logloss: 0.309499
# [1119]	valid_0's binary_logloss: 0.309408
# [1120]	valid_0's binary_logloss: 0.309441
# [1121]	valid_0's binary_logloss: 0.30939
# [1122]	valid_0's binary_logloss: 0.309402
# [1123]	valid_0's binary_logloss: 0.309443
# [1124]	valid_0's binary_logloss: 0.309443
# [1125]	valid_0's binary_logloss: 0.309608
# [1126]	valid_0's binary_logloss: 0.309891
# [1127]	valid_0's binary_logloss: 0.309551
# [1128]	valid_0's binary_logloss: 0.309519
# [1129]	valid_0's binary_logloss: 0.309434
# [1130]	valid_0's binary_logloss: 0.309739
# [1131]	valid_0's binary_logloss: 0.30952
# [1132]	valid_0's binary_logloss: 0.309417
# [1133]	valid_0's binary_logloss: 0.3094
# [1134]	valid_0's binary_logloss: 0.309447
# [1135]	valid_0's binary_logloss: 0.309381
# [1136]	valid_0's binary_logloss: 0.309404
# [1137]	valid_0's binary_logloss: 0.309339
# [1138]	valid_0's binary_logloss: 0.309291
# [1139]	valid_0's binary_logloss: 0.309325
# [1140]	valid_0's binary_logloss: 0.309279
# [1141]	valid_0's binary_logloss: 0.30925
# [1142]	valid_0's binary_logloss: 0.309281
# [1143]	valid_0's binary_logloss: 0.309315
# [1144]	valid_0's binary_logloss: 0.309284
# [1145]	valid_0's binary_logloss: 0.309224
# [1146]	valid_0's binary_logloss: 0.309194
# [1147]	valid_0's binary_logloss: 0.309203
# [1148]	valid_0's binary_logloss: 0.309234
# [1149]	valid_0's binary_logloss: 0.309231
# [1150]	valid_0's binary_logloss: 0.309226
# [1151]	valid_0's binary_logloss: 0.309216
# ...
# [1170]	valid_0's binary_logloss: 0.302994
# [1171]	valid_0's binary_logloss: 0.303
# [1172]	valid_0's binary_logloss: 0.303014
# [1173]	valid_0's binary_logloss: 0.303042
# [1174]	valid_0's binary_logloss: 0.302987
# [1175]	valid_0's binary_logloss: 0.303022
# [1176]	valid_0's binary_logloss: 0.303004
# [1177]	valid_0's binary_logloss: 0.303043
# [1178]	valid_0's binary_logloss: 0.303039
# [1179]	valid_0's binary_logloss: 0.303035
# [1180]	valid_0's binary_logloss: 0.303029
# [1181]	valid_0's binary_logloss: 0.303032
# [1182]	valid_0's binary_logloss: 0.303031
# [1183]	valid_0's binary_logloss: 0.303051
# [1184]	valid_0's binary_logloss: 0.303077
# [1185]	valid_0's binary_logloss: 0.303056
# [1186]	valid_0's binary_logloss: 0.303053
# [1187]	valid_0's binary_logloss: 0.303108
# [1188]	valid_0's binary_logloss: 0.303059
# [1189]	valid_0's binary_logloss: 0.303049
# [1190]	valid_0's binary_logloss: 0.303037
# [1191]	valid_0's binary_logloss: 0.302995
# [1192]	valid_0's binary_logloss: 0.303032
# [1193]	valid_0's binary_logloss: 0.30307
# [1194]	valid_0's binary_logloss: 0.30308
# [1195]	valid_0's binary_logloss: 0.303081
# [1196]	valid_0's binary_logloss: 0.303118
# [1197]	valid_0's binary_logloss: 0.303127
# [1198]	valid_0's binary_logloss: 0.30309
# [1199]	valid_0's binary_logloss: 0.303241
# [1200]	valid_0's binary_logloss: 0.303214
# [1201]	valid_0's binary_logloss: 0.30347
# [1202]	valid_0's binary_logloss: 0.307886
# [1203]	valid_0's binary_logloss: 0.307892
# [1204]	valid_0's binary_logloss: 0.307894
# [1205]	valid_0's binary_logloss: 0.307893
# [1206]	valid_0's binary_logloss: 0.307893
# [1207]	valid_0's binary_logloss: 0.30789
# [1208]	valid_0's binary_logloss: 0.307886
# [1209]	valid_0's binary_logloss: 0.307884
# [1210]	valid_0's binary_logloss: 0.307884
# [1211]	valid_0's binary_logloss: 0.307882
# [1212]	valid_0's binary_logloss: 0.307886
# [1213]	valid_0's binary_logloss: 0.307887
# [1214]	valid_0's binary_logloss: 0.30788
# [1215]	valid_0's binary_logloss: 0.307879
# [1216]	valid_0's binary_logloss: 0.307872
# [1217]	valid_0's binary_logloss: 0.307873
# [1218]	valid_0's binary_logloss: 0.307872
# [1219]	valid_0's binary_logloss: 0.307871
# [1220]	valid_0's binary_logloss: 0.307869
# [1221]	valid_0's binary_logloss: 0.307869
# [1222]	valid_0's binary_logloss: 0.307872
# [1223]	valid_0's binary_logloss: 0.307871
# [1224]	valid_0's binary_logloss: 0.30787
# [1225]	valid_0's binary_logloss: 0.30787
# [1226]	valid_0's binary_logloss: 0.307867
# [1227]	valid_0's binary_logloss: 0.307872
# [1228]	valid_0's binary_logloss: 0.307868
# [1229]	valid_0's binary_logloss: 0.307866
# [1230]	valid_0's binary_logloss: 0.30786
# [1231]	valid_0's binary_logloss: 0.307862
# [1232]	valid_0's binary_logloss: 0.307858
# [1233]	valid_0's binary_logloss: 0.307857
# [1234]	valid_0's binary_logloss: 0.307855
# [1235]	valid_0's binary_logloss: 0.307857
# [1236]	valid_0's binary_logloss: 0.307851
# [1237]	valid_0's binary_logloss: 0.307855
# [1238]	valid_0's binary_logloss: 0.307851
# [1239]	valid_0's binary_logloss: 0.307849
# [1240]	valid_0's binary_logloss: 0.307854
# [1241]	valid_0's binary_logloss: 0.307858
# [1242]	valid_0's binary_logloss: 0.307851
# [1243]	valid_0's binary_logloss: 0.307844
# [1244]	valid_0's binary_logloss: 0.307849
# [1245]	valid_0's binary_logloss: 0.307852
# [1246]	valid_0's binary_logloss: 0.303338
# [1247]	valid_0's binary_logloss: 0.303314
# [1248]	valid_0's binary_logloss: 0.303266
# [1249]	valid_0's binary_logloss: 0.303317
# [1250]	valid_0's binary_logloss: 0.30349
# [1251]	valid_0's binary_logloss: 0.303607
# [1252]	valid_0's binary_logloss: 0.303426
# [1253]	valid_0's binary_logloss: 0.303455
# [1254]	valid_0's binary_logloss: 0.307838
# [1255]	valid_0's binary_logloss: 0.307836
# [1256]	valid_0's binary_logloss: 0.30784
# [1257]	valid_0's binary_logloss: 0.303228
# [1258]	valid_0's binary_logloss: 0.303161
# [1259]	valid_0's binary_logloss: 0.303297
# [1260]	valid_0's binary_logloss: 0.303224
# [1261]	valid_0's binary_logloss: 0.303114
# [1262]	valid_0's binary_logloss: 0.303058
# [1263]	valid_0's binary_logloss: 0.303067
# [1264]	valid_0's binary_logloss: 0.303145
# [1265]	valid_0's binary_logloss: 0.303156
# [1266]	valid_0's binary_logloss: 0.303275
# [1267]	valid_0's binary_logloss: 0.303795
# [1268]	valid_0's binary_logloss: 0.307847
# [1269]	valid_0's binary_logloss: 0.307849
# [1270]	valid_0's binary_logloss: 0.307848
# [1271]	valid_0's binary_logloss: 0.30785
# [1272]	valid_0's binary_logloss: 0.307852
# [1273]	valid_0's binary_logloss: 0.30785
# [1274]	valid_0's binary_logloss: 0.30785
# [1275]	valid_0's binary_logloss: 0.307849
# [1276]	valid_0's binary_logloss: 0.307848
# [1277]	valid_0's binary_logloss: 0.307851
# [1278]	valid_0's binary_logloss: 0.30785
# [1279]	valid_0's binary_logloss: 0.307845
# [1280]	valid_0's binary_logloss: 0.307841
# [1281]	valid_0's binary_logloss: 0.307843
# [1282]	valid_0's binary_logloss: 0.307841
# [1283]	valid_0's binary_logloss: 0.307843
# [1284]	valid_0's binary_logloss: 0.30784
# [1285]	valid_0's binary_logloss: 0.30784
# [1286]	valid_0's binary_logloss: 0.307841
# [1287]	valid_0's binary_logloss: 0.307837
# [1288]	valid_0's binary_logloss: 0.307831
# [1289]	valid_0's binary_logloss: 0.307827
# [1290]	valid_0's binary_logloss: 0.30783
# [1291]	valid_0's binary_logloss: 0.307828
# [1292]	valid_0's binary_logloss: 0.307827
# [1293]	valid_0's binary_logloss: 0.30783
# [1294]	valid_0's binary_logloss: 0.307827
# [1295]	valid_0's binary_logloss: 0.307832
# [1296]	valid_0's binary_logloss: 0.307834
# [1297]	valid_0's binary_logloss: 0.30783
# [1298]	valid_0's binary_logloss: 0.307831
# [1299]	valid_0's binary_logloss: 0.307832
# [1300]	valid_0's binary_logloss: 0.307832
# [1301]	valid_0's binary_logloss: 0.307835
# [1302]	valid_0's binary_logloss: 0.307833
# [1303]	valid_0's binary_logloss: 0.307831
# [1304]	valid_0's binary_logloss: 0.307834
# [1305]	valid_0's binary_logloss: 0.307835
# [1306]	valid_0's binary_logloss: 0.307833
# [1307]	valid_0's binary_logloss: 0.30783
# [1308]	valid_0's binary_logloss: 0.30783
# [1309]	valid_0's binary_logloss: 0.307829
# [1310]	valid_0's binary_logloss: 0.307832
# [1311]	valid_0's binary_logloss: 0.30783
# [1312]	valid_0's binary_logloss: 0.307827
# [1313]	valid_0's binary_logloss: 0.307827
# [1314]	valid_0's binary_logloss: 0.307829
# [1315]	valid_0's binary_logloss: 0.307829
# [1316]	valid_0's binary_logloss: 0.303325
# [1317]	valid_0's binary_logloss: 0.303203
# [1318]	valid_0's binary_logloss: 0.303218
# [1319]	valid_0's binary_logloss: 0.303191
# [1320]	valid_0's binary_logloss: 0.303216
# [1321]	valid_0's binary_logloss: 0.303178
# [1322]	valid_0's binary_logloss: 0.303226
# [1323]	valid_0's binary_logloss: 0.303214
# [1324]	valid_0's binary_logloss: 0.303128
# [1325]	valid_0's binary_logloss: 0.303064
# [1326]	valid_0's binary_logloss: 0.303086
# [1327]	valid_0's binary_logloss: 0.303042
# [1328]	valid_0's binary_logloss: 0.30307
# [1329]	valid_0's binary_logloss: 0.303148
# [1330]	valid_0's binary_logloss: 0.303057
# [1331]	valid_0's binary_logloss: 0.303004
# [1332]	valid_0's binary_logloss: 0.303044
# [1333]	valid_0's binary_logloss: 0.303033
# [1334]	valid_0's binary_logloss: 0.303053
# [1335]	valid_0's binary_logloss: 0.3031
# [1336]	valid_0's binary_logloss: 0.303113
# [1337]	valid_0's binary_logloss: 0.303137
# [1338]	valid_0's binary_logloss: 0.303144
# [1339]	valid_0's binary_logloss: 0.303173
# [1340]	valid_0's binary_logloss: 0.303249
# [1341]	valid_0's binary_logloss: 0.303271
# [1342]	valid_0's binary_logloss: 0.303301
# [1343]	valid_0's binary_logloss: 0.303297
# [1344]	valid_0's binary_logloss: 0.30316
# [1345]	valid_0's binary_logloss: 0.303094
# [1346]	valid_0's binary_logloss: 0.303093
# [1347]	valid_0's binary_logloss: 0.303099
# [1348]	valid_0's binary_logloss: 0.303274
# [1349]	valid_0's binary_logloss: 0.307815
# [1350]	valid_0's binary_logloss: 0.307813
# [1351]	valid_0's binary_logloss: 0.307812
# [1352]	valid_0's binary_logloss: 0.307807
# [1353]	valid_0's binary_logloss: 0.307807
# [1354]	valid_0's binary_logloss: 0.303656
# [1355]	valid_0's binary_logloss: 0.303605
# [1356]	valid_0's binary_logloss: 0.30355
# [1357]	valid_0's binary_logloss: 0.303302
# [1358]	valid_0's binary_logloss: 0.307804
# [1359]	valid_0's binary_logloss: 0.307804
# [1360]	valid_0's binary_logloss: 0.307808
# [1361]	valid_0's binary_logloss: 0.307805
# [1362]	valid_0's binary_logloss: 0.307805
# [1363]	valid_0's binary_logloss: 0.307805
# [1364]	valid_0's binary_logloss: 0.307805
# [1365]	valid_0's binary_logloss: 0.307806
# [1366]	valid_0's binary_logloss: 0.307806
# [1367]	valid_0's binary_logloss: 0.307799
# [1368]	valid_0's binary_logloss: 0.307799
# [1369]	valid_0's binary_logloss: 0.307801
# [1370]	valid_0's binary_logloss: 0.307803
# [1371]	valid_0's binary_logloss: 0.307802
# [1372]	valid_0's binary_logloss: 0.307805
# [1373]	valid_0's binary_logloss: 0.307805
# [1374]	valid_0's binary_logloss: 0.307804
# [1375]	valid_0's binary_logloss: 0.307806
# [1376]	valid_0's binary_logloss: 0.307808
# [1377]	valid_0's binary_logloss: 0.307805
# [1378]	valid_0's binary_logloss: 0.307807
# [1379]	valid_0's binary_logloss: 0.307805
# [1380]	valid_0's binary_logloss: 0.307806
# [1381]	valid_0's binary_logloss: 0.307801
# [1382]	valid_0's binary_logloss: 0.307796
# [1383]	valid_0's binary_logloss: 0.307795
# [1384]	valid_0's binary_logloss: 0.307792
# [1385]	valid_0's binary_logloss: 0.307788
# [1386]	valid_0's binary_logloss: 0.30779
# [1387]	valid_0's binary_logloss: 0.30779
# [1388]	valid_0's binary_logloss: 0.307792
# [1389]	valid_0's binary_logloss: 0.307789
# [1390]	valid_0's binary_logloss: 0.307791
# [1391]	valid_0's binary_logloss: 0.307789
# [1392]	valid_0's binary_logloss: 0.307788
# [1393]	valid_0's binary_logloss: 0.307786
# [1394]	valid_0's binary_logloss: 0.307785
# [1395]	valid_0's binary_logloss: 0.307786
# [1396]	valid_0's binary_logloss: 0.307785
# [1397]	valid_0's binary_logloss: 0.307785
# [1398]	valid_0's binary_logloss: 0.307788
# [1399]	valid_0's binary_logloss: 0.307785
# [1400]	valid_0's binary_logloss: 0.307785
# [1401]	valid_0's binary_logloss: 0.307784
# [1402]	valid_0's binary_logloss: 0.307784
# [1403]	valid_0's binary_logloss: 0.307788
# [1404]	valid_0's binary_logloss: 0.307787
# [1405]	valid_0's binary_logloss: 0.307786
# [1406]	valid_0's binary_logloss: 0.307787
# [1407]	valid_0's binary_logloss: 0.307789
# [1408]	valid_0's binary_logloss: 0.307787
# [1409]	valid_0's binary_logloss: 0.307792
# [1410]	valid_0's binary_logloss: 0.307791
# [1411]	valid_0's binary_logloss: 0.307791
# [1412]	valid_0's binary_logloss: 0.30779
# [1413]	valid_0's binary_logloss: 0.307787
# [1414]	valid_0's binary_logloss: 0.307788
# [1415]	valid_0's binary_logloss: 0.307789
# [1416]	valid_0's binary_logloss: 0.307788
# [1417]	valid_0's binary_logloss: 0.307785
# [1418]	valid_0's binary_logloss: 0.307785
# [1419]	valid_0's binary_logloss: 0.307782
# [1420]	valid_0's binary_logloss: 0.30778
# [1421]	valid_0's binary_logloss: 0.307781
# [1422]	valid_0's binary_logloss: 0.307778
# [1423]	valid_0's binary_logloss: 0.30778
# [1424]	valid_0's binary_logloss: 0.30778
# [1425]	valid_0's binary_logloss: 0.307781
# [1426]	valid_0's binary_logloss: 0.30778
# [1427]	valid_0's binary_logloss: 0.307777
# [1428]	valid_0's binary_logloss: 0.307775
# [1429]	valid_0's binary_logloss: 0.307774
# [1430]	valid_0's binary_logloss: 0.307772
# [1431]	valid_0's binary_logloss: 0.30777
# [1432]	valid_0's binary_logloss: 0.307772
# [1433]	valid_0's binary_logloss: 0.307772
# [1434]	valid_0's binary_logloss: 0.307772
# [1435]	valid_0's binary_logloss: 0.307769
# [1436]	valid_0's binary_logloss: 0.307768
# [1437]	valid_0's binary_logloss: 0.307768
# [1438]	valid_0's binary_logloss: 0.307769
# [1439]	valid_0's binary_logloss: 0.307769
# [1440]	valid_0's binary_logloss: 0.307767
# [1441]	valid_0's binary_logloss: 0.307766
# [1442]	valid_0's binary_logloss: 0.307764
# [1443]	valid_0's binary_logloss: 0.307765
# [1444]	valid_0's binary_logloss: 0.307762
# [1445]	valid_0's binary_logloss: 0.307764
# [1446]	valid_0's binary_logloss: 0.307763
# [1447]	valid_0's binary_logloss: 0.307762
# [1448]	valid_0's binary_logloss: 0.307761
# [1449]	valid_0's binary_logloss: 0.307762
# [1450]	valid_0's binary_logloss: 0.307765
# [1451]	valid_0's binary_logloss: 0.307764
# [1452]	valid_0's binary_logloss: 0.307765
# [1453]	valid_0's binary_logloss: 0.307768
# [1454]	valid_0's binary_logloss: 0.307769
# [1455]	valid_0's binary_logloss: 0.307767
# [1456]	valid_0's binary_logloss: 0.307769
# [1457]	valid_0's binary_logloss: 0.307765
# [1458]	valid_0's binary_logloss: 0.307763
# [1459]	valid_0's binary_logloss: 0.307763
# [1460]	valid_0's binary_logloss: 0.307764
# [1461]	valid_0's binary_logloss: 0.307766
# [1462]	valid_0's binary_logloss: 0.307767
# [1463]	valid_0's binary_logloss: 0.30777
# [1464]	valid_0's binary_logloss: 0.307772
# [1465]	valid_0's binary_logloss: 0.307772
# [1466]	valid_0's binary_logloss: 0.307775
# [1467]	valid_0's binary_logloss: 0.307776
# [1468]	valid_0's binary_logloss: 0.307775
# [1469]	valid_0's binary_logloss: 0.307777
# [1470]	valid_0's binary_logloss: 0.307776
# [1471]	valid_0's binary_logloss: 0.307776
# [1472]	valid_0's binary_logloss: 0.307775
# [1473]	valid_0's binary_logloss: 0.307778
# [1474]	valid_0's binary_logloss: 0.307777
# [1475]	valid_0's binary_logloss: 0.307778
# [1476]	valid_0's binary_logloss: 0.307777
# [1477]	valid_0's binary_logloss: 0.307777
# [1478]	valid_0's binary_logloss: 0.307779
# [1479]	valid_0's binary_logloss: 0.307778
# [1480]	valid_0's binary_logloss: 0.307775
# [1481]	valid_0's binary_logloss: 0.307776
# [1482]	valid_0's binary_logloss: 0.307773
# [1483]	valid_0's binary_logloss: 0.307772
# [1484]	valid_0's binary_logloss: 0.307769
# [1485]	valid_0's binary_logloss: 0.307771
# [1486]	valid_0's binary_logloss: 0.307772
# [1487]	valid_0's binary_logloss: 0.307774
# [1488]	valid_0's binary_logloss: 0.307775
# [1489]	valid_0's binary_logloss: 0.307779
# [1490]	valid_0's binary_logloss: 0.307779
# [1491]	valid_0's binary_logloss: 0.307775
# [1492]	valid_0's binary_logloss: 0.307772
# [1493]	valid_0's binary_logloss: 0.307768
# [1494]	valid_0's binary_logloss: 0.307769
# [1495]	valid_0's binary_logloss: 0.307769
# [1496]	valid_0's binary_logloss: 0.307771
# [1497]	valid_0's binary_logloss: 0.307769
# [1498]	valid_0's binary_logloss: 0.307772
# [1499]	valid_0's binary_logloss: 0.307773
# [1500]	valid_0's binary_logloss: 0.307774
# [1501]	valid_0's binary_logloss: 0.307772
# [1502]	valid_0's binary_logloss: 0.307773
# [1503]	valid_0's binary_logloss: 0.307772
# [1504]	valid_0's binary_logloss: 0.30777
# [1505]	valid_0's binary_logloss: 0.307768
# [1506]	valid_0's binary_logloss: 0.307769
# [1507]	valid_0's binary_logloss: 0.307771
# [1508]	valid_0's binary_logloss: 0.307773
# [1509]	valid_0's binary_logloss: 0.307771
# [1510]	valid_0's binary_logloss: 0.307772
# [1511]	valid_0's binary_logloss: 0.30777
# [1512]	valid_0's binary_logloss: 0.30777
# [1513]	valid_0's binary_logloss: 0.30777
# [1514]	valid_0's binary_logloss: 0.307771
# [1515]	valid_0's binary_logloss: 0.307769
# [1516]	valid_0's binary_logloss: 0.307771
# [1517]	valid_0's binary_logloss: 0.307772
# [1518]	valid_0's binary_logloss: 0.307772
# [1519]	valid_0's binary_logloss: 0.307774
# [1520]	valid_0's binary_logloss: 0.307773
# [1521]	valid_0's binary_logloss: 0.307772
# [1522]	valid_0's binary_logloss: 0.307774
# [1523]	valid_0's binary_logloss: 0.307774
# [1524]	valid_0's binary_logloss: 0.307776
# [1525]	valid_0's binary_logloss: 0.307773
# [1526]	valid_0's binary_logloss: 0.307773
# [1527]	valid_0's binary_logloss: 0.307774
# [1528]	valid_0's binary_logloss: 0.30777
# [1529]	valid_0's binary_logloss: 0.30777
# [1530]	valid_0's binary_logloss: 0.307769
# [1531]	valid_0's binary_logloss: 0.307768
# [1532]	valid_0's binary_logloss: 0.307769
# [1533]	valid_0's binary_logloss: 0.307769
# [1534]	valid_0's binary_logloss: 0.307769
# [1535]	valid_0's binary_logloss: 0.307769
# [1536]	valid_0's binary_logloss: 0.30777
# [1537]	valid_0's binary_logloss: 0.307769
# [1538]	valid_0's binary_logloss: 0.307769
# [1539]	valid_0's binary_logloss: 0.307766
# [1540]	valid_0's binary_logloss: 0.307767
# [1541]	valid_0's binary_logloss: 0.307771
# [1542]	valid_0's binary_logloss: 0.307771
# [1543]	valid_0's binary_logloss: 0.307773
# Early stopping, best iteration is:
# [543]	valid_0's binary_logloss: 0.297006
# 100%|████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 5/5 [02:29<00:00, 29.92s/it]
# fold4::0.4258707885792814::0.8668015024559375

# %%
from scipy import stats
mode_2, count_2 = stats.mode(np.stack(sub_prob), axis=0)
sub = pd.read_csv(DATA_DIR + "/sample_submit.csv", header = None)
sub.columns = ["id", "judgement"]
sub["judgement"] = mode_2[0]
#保存先のディレクトリ作成
save_dir = "./result/result9"
if not os.path.isdir(save_dir):
    os.makedirs(save_dir)
sub.to_csv(save_dir + '/submission.csv', header=None, index=None)
