# %% [markdown]
# 1. データの読み込み

# %%
import math
import random
import time
import warnings
import numpy as np
import pandas as pd
import torch
import torch.nn as nn
import os
import transformers as T
from random import shuffle
from pathlib import Path
from sklearn.metrics import fbeta_score
from sklearn.model_selection import StratifiedKFold
from torch.utils.data import DataLoader, Dataset
from sklearn.linear_model import LogisticRegression
from tqdm.notebook import tqdm
import matplotlib.pyplot as plt
import string
from nltk.corpus import stopwords
from sklearn.pipeline import Pipeline
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.feature_extraction.text import CountVectorizer
from sklearn.metrics import fbeta_score
from sklearn.preprocessing import MinMaxScaler,StandardScaler
from imblearn.under_sampling import RandomUnderSampler
from sklearn.decomposition import TruncatedSVD
from sklearn.pipeline import Pipeline
import tqdm
from sklearn.feature_selection import SelectKBest, chi2
from sklearn import naive_bayes
from scipy.optimize import minimize, minimize_scalar
import texthero as hero

# %%
warnings.filterwarnings("ignore")

# %%
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
print(device)
# Out:
# cuda

# %%
def seed_torch(seed=42):
    random.seed(seed)
    os.environ["PYTHONHASHSEED"] = str(seed)
    np.random.seed(seed)
    torch.manual_seed(seed)
    torch.cuda.manual_seed(seed)
    torch.cuda.manual_seed_all(seed)
    torch.backends.cudnn.deterministic = True

seed = 471
seed_torch(seed)

# %%
class config:
    DATA_DIR = './dataset/data1'
    OUTPUT_DIR ='./result/result9'
if not os.path.isdir(config.OUTPUT_DIR):
    os.makedirs(config.OUTPUT_DIR)

# %%
def opt_fbeta_threshold(y_true, y_pred):
    """fbeta score計算時のthresholdを最適化"""
    def opt_(x): 
        return -fbeta_score(y_true, y_pred >= x, beta=7)
    result = minimize(opt_, x0=np.array([0.1]), method='Powell')
    best_threshold = result['x'].item()
    return best_threshold


def metrics(y_true, y_pred):
    """fbeta(beta=7)の閾値最適化評価関数"""
    bt = opt_fbeta_threshold(y_true, y_pred)
    print(f"bt:{bt}")
    score = fbeta_score(y_true, y_pred >= bt, beta=7)
    return score, bt

# %%
#stop words list
stop_words = ['i', 'me', 'my', 'myself', 'we', 'our', 
			'ours', 'ourselves', 'you', 'your', 'yours', 
			'yourself', 'yourselves', 'he', 'him', 'his', 
			'himself', 'she', 'her', 'hers', 'herself', 
			'it', 'its', 'itself', 'they', 'them', 'their', 
			'theirs', 'themselves', 'what', 'which', 'who', 
			'whom', 'this', 'that', 'these', 'those', 'am', 
			'is', 'are', 'was', 'were', 'be', 'been', 'being', 
			'have', 'has', 'had', 'having', 'do', 'does', 'did',
			'doing', 'a', 'an', 'the', 'and', 'but', 'if', 'or',
			'because', 'as', 'until', 'while', 'of', 'at', 
			'by', 'for', 'with', 'about', 'against', 'between',
			'into', 'through', 'during', 'before', 'after', 
			'above', 'below', 'to', 'from', 'up', 'down', 'in',
			'out', 'on', 'off', 'over', 'under', 'again', 
			'further', 'then', 'once', 'here', 'there', 'when', 
			'where', 'why', 'how', 'all', 'any', 'both', 'each', 
			'few', 'more', 'most', 'other', 'some', 'such', 'no', 
			'nor', 'not', 'only', 'own', 'same', 'so', 'than', 'too', 
			'very', 's', 't', 'can', 'will', 'just', 'don', 
			'should', 'now', '']

#cleaning up text
import re
def get_only_chars(line):

    clean_line = ""

    line = line.replace("’", "")
    line = line.replace("'", "")
    line = line.replace("-", " ") #replace hyphens with spaces
    line = line.replace("\t", " ")
    line = line.replace("\n", " ")
    line = line.lower()

    for char in line:
        if char in 'qwertyuiopasdfghjklzxcvbnm ':
            clean_line += char
        else:
            clean_line += ' '

    clean_line = re.sub(' +',' ',clean_line) #delete extra spaces
    if clean_line[0] == ' ':
        clean_line = clean_line[1:]
    return clean_line

########################################################################
# Synonym replacement
# Replace n words in the sentence with synonyms from wordnet
########################################################################

#for the first time you use wordnet
#import nltk
#nltk.download('wordnet')
from nltk.corpus import wordnet 

def synonym_replacement(words, n):
	new_words = words.copy()
	random_word_list = list(set([word for word in words if word not in stop_words]))
	random.shuffle(random_word_list)
	num_replaced = 0
	for random_word in random_word_list:
		synonyms = get_synonyms(random_word)
		if len(synonyms) >= 1:
			synonym = random.choice(list(synonyms))
			new_words = [synonym if word == random_word else word for word in new_words]
			#print("replaced", random_word, "with", synonym)
			num_replaced += 1
		if num_replaced >= n: #only replace up to n words
			break

	#this is stupid but we need it, trust me
	sentence = ' '.join(new_words)
	new_words = sentence.split(' ')

	return new_words

def get_synonyms(word):
	synonyms = set()
	for syn in wordnet.synsets(word): 
		for l in syn.lemmas(): 
			synonym = l.name().replace("_", " ").replace("-", " ").lower()
			synonym = "".join([char for char in synonym if char in ' qwertyuiopasdfghjklzxcvbnm'])
			synonyms.add(synonym) 
	if word in synonyms:
		synonyms.remove(word)
	return list(synonyms)

########################################################################
# Random deletion
# Randomly delete words from the sentence with probability p
########################################################################

def random_deletion(words, p):

	#obviously, if there's only one word, don't delete it
	if len(words) == 1:
		return words

	#randomly delete words with probability p
	new_words = []
	for word in words:
		r = random.uniform(0, 1)
		if r > p:
			new_words.append(word)

	#if you end up deleting all words, just return a random word
	if len(new_words) == 0:
		rand_int = random.randint(0, len(words)-1)
		return [words[rand_int]]

	return new_words

########################################################################
# Random swap
# Randomly swap two words in the sentence n times
########################################################################

def random_swap(words, n):
	new_words = words.copy()
	for _ in range(n):
		new_words = swap_word(new_words)
	return new_words

def swap_word(new_words):
	random_idx_1 = random.randint(0, len(new_words)-1)
	random_idx_2 = random_idx_1
	counter = 0
	while random_idx_2 == random_idx_1:
		random_idx_2 = random.randint(0, len(new_words)-1)
		counter += 1
		if counter > 3:
			return new_words
	new_words[random_idx_1], new_words[random_idx_2] = new_words[random_idx_2], new_words[random_idx_1] 
	return new_words

########################################################################
# Random insertion
# Randomly insert n words into the sentence
########################################################################

def random_insertion(words, n):
	new_words = words.copy()
	for _ in range(n):
		add_word(new_words)
	return new_words

def add_word(new_words):
	synonyms = []
	counter = 0
	while len(synonyms) < 1:
		random_word = new_words[random.randint(0, len(new_words)-1)]
		synonyms = get_synonyms(random_word)
		counter += 1
		if counter >= 10:
			return
	random_synonym = synonyms[0]
	random_idx = random.randint(0, len(new_words)-1)
	new_words.insert(random_idx, random_synonym)

########################################################################
# main data augmentation function
########################################################################

def eda(sentence, alpha_sr=0.1, alpha_ri=0.1, alpha_rs=0.1, p_rd=0.1, num_aug=9):
	
	sentence = get_only_chars(sentence)
	words = sentence.split(' ')
	words = [word for word in words if word is not '']
	num_words = len(words)
	
	augmented_sentences = []
	num_new_per_technique = int(num_aug/4)+1

	#sr
	if (alpha_sr > 0):
		n_sr = max(1, int(alpha_sr*num_words))
		for _ in range(num_new_per_technique):
			a_words = synonym_replacement(words, n_sr)
			augmented_sentences.append(' '.join(a_words))

	#ri
	if (alpha_ri > 0):
		n_ri = max(1, int(alpha_ri*num_words))
		for _ in range(num_new_per_technique):
			a_words = random_insertion(words, n_ri)
			augmented_sentences.append(' '.join(a_words))

	#rs
	if (alpha_rs > 0):
		n_rs = max(1, int(alpha_rs*num_words))
		for _ in range(num_new_per_technique):
			a_words = random_swap(words, n_rs)
			augmented_sentences.append(' '.join(a_words))

	#rd
	if (p_rd > 0):
		for _ in range(num_new_per_technique):
			a_words = random_deletion(words, p_rd)
			augmented_sentences.append(' '.join(a_words))

	augmented_sentences = [get_only_chars(sentence) for sentence in augmented_sentences]
	shuffle(augmented_sentences)

	#trim so that we have the desired number of augmented sentences
	if num_aug >= 1:
		augmented_sentences = augmented_sentences[:num_aug]
	else:
		keep_prob = num_aug / len(augmented_sentences)
		augmented_sentences = [s for s in augmented_sentences if random.uniform(0, 1) < keep_prob]

	#append the original sentence
	augmented_sentences.append(sentence)

	return augmented_sentences
def set_eda(df_):
    df = df_[df_.judgement==1]
    new_lines = []
    eda_df = pd.DataFrame()
    for line, label in tqdm.tqdm(zip(df['text'].tolist(), df['judgement'].tolist()), total=len(df['judgement'].tolist())):
        new_line = eda(line, alpha_sr=0.05, alpha_ri=0.0, alpha_rs=0.0, p_rd=0.1, num_aug=16)
        for l in new_line:
            eda_df = eda_df.append({'text': l, 'judgement': label}, ignore_index=True)
    eda_df['judgement'] = eda_df['judgement'].astype(np.int64)
    new_df = pd.concat([df_, eda_df], axis=0)
    
    return new_df

# %%
def cleansing_hero_only_text(input_df, text_col):
    ## get text only 
    custom_pipeline = [
        hero.preprocessing.fillna,
        hero.preprocessing.lowercase,
        hero.preprocessing.remove_digits,
        hero.preprocessing.remove_punctuation,
        hero.preprocessing.remove_diacritics,
        hero.preprocessing.remove_stopwords,
        hero.preprocessing.remove_whitespace,
        hero.preprocessing.stem
    ]
    texts = hero.clean(input_df[text_col], custom_pipeline)
    return texts

def basic_text_features_transforme(input_df, text_columns, cleansing_hero=None, name=""):
    """basic な text 特徴量"""
    def _get_features(dataframe, column):
        _df = pd.DataFrame()
        _df[column + name + '_num_chars'] = dataframe[column].apply(len)
        _df[column + name + '_num_exclamation_marks'] = dataframe[column].apply(lambda x: x.count('!'))
        _df[column + name + '_num_question_marks'] = dataframe[column].apply(lambda x: x.count('?'))
        _df[column + name + '_num_punctuation'] = dataframe[column].apply(lambda x: sum(x.count(w) for w in '.,;:'))
        _df[column + name + '_num_symbols'] = dataframe[column].apply(lambda x: sum(x.count(w) for w in '*&$%'))
        _df[column + name + '_num_words'] = dataframe[column].apply(lambda x: len(x.split()))
        _df[column + name + '_num_unique_words'] = dataframe[column].apply(lambda x: len(set(w for w in x.split())))
        _df[column + name + '_words_vs_unique'] = _df[column + name + '_num_unique_words'] / _df[column + name + '_num_words']
        _df[column + name + '_words_vs_chars'] = _df[column + name + '_num_words'] / _df[column + name + '_num_chars']
        return _df
    
    # main の処理
    output_df_ = pd.DataFrame()
    output_df_[text_columns] = input_df[text_columns].fillna('missing').astype(str)
    output_lst = []
    for c in text_columns:
        if cleansing_hero is not None:
            output_df_[c] = cleansing_hero(output_df_, c)
        output_df = _get_features(output_df_, c)
        output_lst.append(output_df)
    output_df = pd.concat(output_lst, axis=1)
    return output_df

# %%
def text_process(mess):
    STOPWORDS = stopwords.words('english') + ['u', 'ü', 'ur', 'im', 'dont', 'doin', 'ure']
    nopunc = [char for char in mess if char not in string.punctuation]
    nopunc = ''.join(nopunc)
    return ' '.join([word.lower() for word in nopunc.split() if word.lower() not in STOPWORDS])
#データの読み込み
df_train = pd.read_csv(config.DATA_DIR  +"/train.csv", index_col=0).fillna(" ")
df_test = pd.read_csv(config.DATA_DIR + "/test.csv", index_col=0).fillna(" ")
sub = pd.read_csv(config.DATA_DIR + "/sample_submit.csv", index_col=0)
df_train["text"] = df_train["title"] + " " + df_train["abstract"].fillna("")
df_test["text"] = df_test["title"] + " " + df_test["abstract"].fillna("")
df_train.text = df_train.text.apply(text_process)
df_test.text = df_test.text.apply(text_process)

# %%
df = pd.concat([df_train, df_test]).reset_index(drop=True)
output_df = basic_text_features_transforme(df, text_columns=["text"], cleansing_hero=cleansing_hero_only_text)

# %%
df_ = pd.concat([df, output_df], axis=1)
df_train, df_test = df_.iloc[:len(df_train)], df_.iloc[len(df_train):].drop(columns=['judgement'])
df_train.judgement =df_train.judgement.astype(int)

# %%
def get_result(result_df):
    preds = result_df["preds"].values
    labels = result_df["judgement"].values
    score, border = metrics(labels, preds)
    return border, score

# %%
sub_prob = []
kf= StratifiedKFold(n_splits=5,random_state=42)
oof_df = pd.DataFrame()
for fold,(train_index, test_index) in enumerate(kf.split(df_train.loc[:, 'text'], df_train.loc[:, 'judgement'])):
    train = df_train.iloc[train_index].reset_index(drop=True)
    val = df_train.iloc[test_index].reset_index(drop=True)
    #edaを適用
    train = set_eda(train)
    X_train, y_train = train.loc[:, 'text'], train.loc[:, 'judgement']
    X_val, y_val = val.loc[:, 'text'], val.loc[:, 'judgement']
    X_test = df_test.loc[:, 'text']
    rus = RandomUnderSampler(random_state=71)
    pipline = Pipeline([('tfidf', TfidfVectorizer()), ('svd', TruncatedSVD(n_components=500, random_state=0)), 
            ('sc',MinMaxScaler())])
    X_train = pipline.fit_transform(X_train)
    X_val = pipline.transform(X_val)
    X_test = pipline.transform(X_test)
    X_train, y_train = rus.fit_resample(X_train,y_train)
    max_score = 0
    columns_num = X_train.shape[1]
    model = LogisticRegression()
    model.fit(X_train, y_train)
    prob = model.predict_proba(X_val)[:,1]
    score, border = metrics(y_val, prob)
    val['preds'] = prob
    if score < max_score:
        break
    else:
        max_score = score
        X_tes_fix = X_test
        model_fix = model
    prediction = model_fix.predict_proba(X_tes_fix)[:,1]
    sub_prob.append(prediction)
    oof_df_ = val
    oof_df = pd.concat([oof_df, oof_df_])
    print('fold{}::{}::{}'.format(fold, border, score))
border, score=get_result(oof_df)
print('CV::{}::{}'.format(border, score))
# Out:
# 100%|█████████████████████████████████████████| 506/506 [00:10<00:00, 49.58it/s]
# bt:0.10129415499221002
# fold0::0.10129415499221002::0.8717579250720462
# 100%|█████████████████████████████████████████| 506/506 [00:08<00:00, 60.93it/s]
# bt:0.10370603044699417
# fold1::0.10370603044699417::0.876938686766198
# 100%|█████████████████████████████████████████| 506/506 [00:08<00:00, 61.35it/s]
# bt:0.11342505630843458
# fold2::0.11342505630843458::0.8718395815170008
# 100%|█████████████████████████████████████████| 505/505 [00:08<00:00, 61.96it/s]
# bt:0.21930926553414098
# fold3::0.21930926553414098::0.8979776637488681
# 100%|█████████████████████████████████████████| 505/505 [00:08<00:00, 62.13it/s]
# bt:0.10986002711831909
# fold4::0.10986002711831909::0.8727639930755915
# bt:0.10986317562199474
# CV::0.10986317562199474::0.8696156298915879

# %%
from scipy import stats
test_prob = np.array(sub_prob).mean(axis=0)
predictions = np.where(test_prob < border, 0, 1)
sub = pd.read_csv(config.DATA_DIR + "/sample_submit.csv", header = None)
sub.columns = ["id", "judgement"]
sub["judgement"] = predictions
#保存先のディレクトリ作成
sub.to_csv(config.OUTPUT_DIR + '/submission.csv', header=None, index=None)

# %%
import oconcatna.integration.lightgbm as lgb_o
import lightgbm as lgb_o
params = dict(n_estimators=10000,
                        num_leaves=31,
                        objective="binary", 
                        learning_rate=0.01,
                        colsample_bytree=0.3, 
                        class_weight="balanced",
                        importance_type="gain")

sub_prob = []
kf= StratifiedKFold(n_splits=5,random_state=42)
oof_df = pd.DataFrame()
for fold,(train_index, test_index) in enumerate(kf.split(df_train.loc[:, 'text'], df_train.loc[:, 'judgement'])):
    train = df_train.iloc[train_index].reset_index(drop=True)
    val = df_train.iloc[test_index].reset_index(drop=True)
    #edaを適用
    train = set_eda(train)
    X_train, y_train = train.loc[:, 'text'], train.loc[:, 'judgement']
    X_val, y_val = val.loc[:, 'text'], val.loc[:, 'judgement']
    X_test = df_test.loc[:, 'text']
    pipline = Pipeline([('tfidf', TfidfVectorizer()), ('svd', TruncatedSVD(n_components=500, random_state=0))])
    X_train = pipline.fit_transform(X_train)
    X_val = pipline.transform(X_val)
    X_test = pipline.transform(X_test)
    rus = RandomUnderSampler(random_state=71)
    X_train, y_train = rus.fit_resample(X_train,y_train)
    lgb_train = lgb_o.Dataset(X_train, y_train)
    lgb_eval = lgb_o.Dataset(X_val, y_val)
    evals_result = {}
                         
    model = lgb_o.train(params,train_set=lgb_train,
                 # 評価データ
                 valid_sets = lgb_eval,
                evals_result=evals_result, early_stopping_rounds=100)
    prob = model.predict(X_val)
    score, border = metrics(y_val, prob)
    val['preds'] = prob
    prediction = model.predict(X_test)
    sub_prob.append(prediction)
    oof_df_ = val
    oof_df = pd.concat([oof_df, oof_df_])
    print('fold{}::{}::{}'.format(fold, border, score))
border, score=get_result(oof_df)
print('CV::{}::{}'.format(border, score))
# Out:
# 100%|█████████████████████████████████████████| 506/506 [00:08<00:00, 61.52it/s]
# [LightGBM] [Warning] Unknown parameter: importance_type
# [LightGBM] [Warning] Unknown parameter: class_weight
# [LightGBM] [Warning] Unknown parameter: importance_type
# [LightGBM] [Warning] Unknown parameter: class_weight
# [LightGBM] [Info] Number of positive: 6072, number of negative: 21210
# [LightGBM] [Warning] Auto-choosing col-wise multi-threading, the overhead of testing was 0.042789 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 127500
# [LightGBM] [Info] Number of data points in the train set: 27282, number of used features: 500
# [LightGBM] [Warning] Unknown parameter: importance_type
# [LightGBM] [Warning] Unknown parameter: class_weight
# [LightGBM] [Info] [binary:BoostFromScore]: pavg=0.222564 -> initscore=-1.250785
# [LightGBM] [Info] Start training from score -1.250785
# [1]	valid_0's binary_logloss: 0.278987
# Training until validation scores don't improve for 100 rounds
# [2]	valid_0's binary_logloss: 0.277595
# [3]	valid_0's binary_logloss: 0.275717
# [4]	valid_0's binary_logloss: 0.274187
# [5]	valid_0's binary_logloss: 0.272544
# [6]	valid_0's binary_logloss: 0.270319
# [7]	valid_0's binary_logloss: 0.268718
# [8]	valid_0's binary_logloss: 0.266839
# [9]	valid_0's binary_logloss: 0.264631
# [10]	valid_0's binary_logloss: 0.262701
# [11]	valid_0's binary_logloss: 0.261132
# [12]	valid_0's binary_logloss: 0.259241
# [13]	valid_0's binary_logloss: 0.257192
# [14]	valid_0's binary_logloss: 0.25523
# [15]	valid_0's binary_logloss: 0.25344
# [16]	valid_0's binary_logloss: 0.251501
# [17]	valid_0's binary_logloss: 0.249634
# [18]	valid_0's binary_logloss: 0.247817
# [19]	valid_0's binary_logloss: 0.245961
# [20]	valid_0's binary_logloss: 0.243997
# [21]	valid_0's binary_logloss: 0.24256
# [22]	valid_0's binary_logloss: 0.240842
# [23]	valid_0's binary_logloss: 0.23913
# [24]	valid_0's binary_logloss: 0.237637
# [25]	valid_0's binary_logloss: 0.236508
# [26]	valid_0's binary_logloss: 0.234638
# [27]	valid_0's binary_logloss: 0.233254
# [28]	valid_0's binary_logloss: 0.231724
# [29]	valid_0's binary_logloss: 0.22989
# [30]	valid_0's binary_logloss: 0.228337
# [31]	valid_0's binary_logloss: 0.227254
# [32]	valid_0's binary_logloss: 0.225667
# [33]	valid_0's binary_logloss: 0.224001
# [34]	valid_0's binary_logloss: 0.222457
# [35]	valid_0's binary_logloss: 0.220959
# [36]	valid_0's binary_logloss: 0.219623
# [37]	valid_0's binary_logloss: 0.218426
# [38]	valid_0's binary_logloss: 0.216852
# [39]	valid_0's binary_logloss: 0.215607
# [40]	valid_0's binary_logloss: 0.214184
# [41]	valid_0's binary_logloss: 0.212801
# [42]	valid_0's binary_logloss: 0.21131
# [43]	valid_0's binary_logloss: 0.210213
# [44]	valid_0's binary_logloss: 0.209105
# [45]	valid_0's binary_logloss: 0.207585
# [46]	valid_0's binary_logloss: 0.20642
# [47]	valid_0's binary_logloss: 0.205298
# [48]	valid_0's binary_logloss: 0.203928
# [49]	valid_0's binary_logloss: 0.202541
# [50]	valid_0's binary_logloss: 0.201565
# [51]	valid_0's binary_logloss: 0.200427
# [52]	valid_0's binary_logloss: 0.199414
# [53]	valid_0's binary_logloss: 0.198155
# [54]	valid_0's binary_logloss: 0.19688
# [55]	valid_0's binary_logloss: 0.195602
# [56]	valid_0's binary_logloss: 0.194346
# [57]	valid_0's binary_logloss: 0.193055
# [58]	valid_0's binary_logloss: 0.192033
# [59]	valid_0's binary_logloss: 0.191219
# [60]	valid_0's binary_logloss: 0.189871
# [61]	valid_0's binary_logloss: 0.188885
# [62]	valid_0's binary_logloss: 0.187627
# [63]	valid_0's binary_logloss: 0.186432
# [64]	valid_0's binary_logloss: 0.185442
# [65]	valid_0's binary_logloss: 0.184469
# [66]	valid_0's binary_logloss: 0.183483
# [67]	valid_0's binary_logloss: 0.182151
# [68]	valid_0's binary_logloss: 0.181327
# [69]	valid_0's binary_logloss: 0.180078
# [70]	valid_0's binary_logloss: 0.179346
# [71]	valid_0's binary_logloss: 0.178553
# [72]	valid_0's binary_logloss: 0.177688
# [73]	valid_0's binary_logloss: 0.176525
# [74]	valid_0's binary_logloss: 0.175672
# [75]	valid_0's binary_logloss: 0.174618
# [76]	valid_0's binary_logloss: 0.173546
# [77]	valid_0's binary_logloss: 0.172388
# [78]	valid_0's binary_logloss: 0.171275
# [79]	valid_0's binary_logloss: 0.170509
# [80]	valid_0's binary_logloss: 0.169648
# [81]	valid_0's binary_logloss: 0.168803
# [82]	valid_0's binary_logloss: 0.167697
# [83]	valid_0's binary_logloss: 0.16655
# [84]	valid_0's binary_logloss: 0.16551
# [85]	valid_0's binary_logloss: 0.164465
# [86]	valid_0's binary_logloss: 0.163522
# [87]	valid_0's binary_logloss: 0.162585
# [88]	valid_0's binary_logloss: 0.161521
# [89]	valid_0's binary_logloss: 0.160467
# [90]	valid_0's binary_logloss: 0.159471
# [91]	valid_0's binary_logloss: 0.158591
# [92]	valid_0's binary_logloss: 0.157849
# [93]	valid_0's binary_logloss: 0.157144
# [94]	valid_0's binary_logloss: 0.156327
# [95]	valid_0's binary_logloss: 0.155495
# [96]	valid_0's binary_logloss: 0.154693
# [97]	valid_0's binary_logloss: 0.153983
# [98]	valid_0's binary_logloss: 0.153104
# [99]	valid_0's binary_logloss: 0.152414
# [100]	valid_0's binary_logloss: 0.151575
# [101]	valid_0's binary_logloss: 0.150666
# [102]	valid_0's binary_logloss: 0.149888
# [103]	valid_0's binary_logloss: 0.149277
# [104]	valid_0's binary_logloss: 0.148626
# [105]	valid_0's binary_logloss: 0.147892
# [106]	valid_0's binary_logloss: 0.147101
# [107]	valid_0's binary_logloss: 0.146277
# [108]	valid_0's binary_logloss: 0.145527
# [109]	valid_0's binary_logloss: 0.144691
# [110]	valid_0's binary_logloss: 0.144065
# [111]	valid_0's binary_logloss: 0.143287
# [112]	valid_0's binary_logloss: 0.142491
# [113]	valid_0's binary_logloss: 0.141764
# [114]	valid_0's binary_logloss: 0.141023
# [115]	valid_0's binary_logloss: 0.140262
# [116]	valid_0's binary_logloss: 0.139672
# [117]	valid_0's binary_logloss: 0.139132
# [118]	valid_0's binary_logloss: 0.138366
# [119]	valid_0's binary_logloss: 0.137857
# [120]	valid_0's binary_logloss: 0.137237
# [121]	valid_0's binary_logloss: 0.13678
# [122]	valid_0's binary_logloss: 0.136259
# [123]	valid_0's binary_logloss: 0.135721
# [124]	valid_0's binary_logloss: 0.135052
# [125]	valid_0's binary_logloss: 0.134451
# [126]	valid_0's binary_logloss: 0.134028
# [127]	valid_0's binary_logloss: 0.133588
# [128]	valid_0's binary_logloss: 0.133046
# [129]	valid_0's binary_logloss: 0.132611
# [130]	valid_0's binary_logloss: 0.132178
# [131]	valid_0's binary_logloss: 0.131476
# [132]	valid_0's binary_logloss: 0.130776
# [133]	valid_0's binary_logloss: 0.130106
# [134]	valid_0's binary_logloss: 0.129579
# [135]	valid_0's binary_logloss: 0.12896
# [136]	valid_0's binary_logloss: 0.128488
# [137]	valid_0's binary_logloss: 0.128068
# [138]	valid_0's binary_logloss: 0.127617
# [139]	valid_0's binary_logloss: 0.126941
# [140]	valid_0's binary_logloss: 0.126464
# [141]	valid_0's binary_logloss: 0.125917
# [142]	valid_0's binary_logloss: 0.125447
# [143]	valid_0's binary_logloss: 0.124818
# [144]	valid_0's binary_logloss: 0.124346
# [145]	valid_0's binary_logloss: 0.123723
# [146]	valid_0's binary_logloss: 0.123307
# [147]	valid_0's binary_logloss: 0.122692
# [148]	valid_0's binary_logloss: 0.122206
# [149]	valid_0's binary_logloss: 0.121679
# [150]	valid_0's binary_logloss: 0.121126
# [151]	valid_0's binary_logloss: 0.12057
# [152]	valid_0's binary_logloss: 0.120049
# [153]	valid_0's binary_logloss: 0.119524
# [154]	valid_0's binary_logloss: 0.118922
# [155]	valid_0's binary_logloss: 0.118394
# [156]	valid_0's binary_logloss: 0.117919
# [157]	valid_0's binary_logloss: 0.117533
# [158]	valid_0's binary_logloss: 0.116955
# [159]	valid_0's binary_logloss: 0.11642
# [160]	valid_0's binary_logloss: 0.115986
# [161]	valid_0's binary_logloss: 0.11554
# [162]	valid_0's binary_logloss: 0.115007
# [163]	valid_0's binary_logloss: 0.114457
# [164]	valid_0's binary_logloss: 0.114072
# [165]	valid_0's binary_logloss: 0.113522
# [166]	valid_0's binary_logloss: 0.113108
# [167]	valid_0's binary_logloss: 0.112587
# [168]	valid_0's binary_logloss: 0.112039
# [169]	valid_0's binary_logloss: 0.111608
# [170]	valid_0's binary_logloss: 0.111146
# [171]	valid_0's binary_logloss: 0.110654
# [172]	valid_0's binary_logloss: 0.110335
# [173]	valid_0's binary_logloss: 0.110007
# [174]	valid_0's binary_logloss: 0.109662
# [175]	valid_0's binary_logloss: 0.109115
# [176]	valid_0's binary_logloss: 0.108746
# [177]	valid_0's binary_logloss: 0.108332
# [178]	valid_0's binary_logloss: 0.107968
# [179]	valid_0's binary_logloss: 0.107487
# [180]	valid_0's binary_logloss: 0.107077
# [181]	valid_0's binary_logloss: 0.10672
# [182]	valid_0's binary_logloss: 0.106317
# [183]	valid_0's binary_logloss: 0.105975
# [184]	valid_0's binary_logloss: 0.105509
# [185]	valid_0's binary_logloss: 0.105034
# [186]	valid_0's binary_logloss: 0.104758
# [187]	valid_0's binary_logloss: 0.104357
# [188]	valid_0's binary_logloss: 0.103858
# [189]	valid_0's binary_logloss: 0.103535
# [190]	valid_0's binary_logloss: 0.103187
# [191]	valid_0's binary_logloss: 0.102739
# [192]	valid_0's binary_logloss: 0.102445
# [193]	valid_0's binary_logloss: 0.10213
# [194]	valid_0's binary_logloss: 0.101749
# [195]	valid_0's binary_logloss: 0.101312
# [196]	valid_0's binary_logloss: 0.100904
# [197]	valid_0's binary_logloss: 0.100638
# [198]	valid_0's binary_logloss: 0.10036
# [199]	valid_0's binary_logloss: 0.0999752
# [200]	valid_0's binary_logloss: 0.0995991
# [201]	valid_0's binary_logloss: 0.0993002
# [202]	valid_0's binary_logloss: 0.098935
# [203]	valid_0's binary_logloss: 0.0986474
# [204]	valid_0's binary_logloss: 0.098387
# [205]	valid_0's binary_logloss: 0.09805
# [206]	valid_0's binary_logloss: 0.0977747
# [207]	valid_0's binary_logloss: 0.0974764
# [208]	valid_0's binary_logloss: 0.0971111
# [209]	valid_0's binary_logloss: 0.0968577
# [210]	valid_0's binary_logloss: 0.0964792
# [211]	valid_0's binary_logloss: 0.0961171
# [212]	valid_0's binary_logloss: 0.0958403
# [213]	valid_0's binary_logloss: 0.0955168
# [214]	valid_0's binary_logloss: 0.0952691
# [215]	valid_0's binary_logloss: 0.0949027
# [216]	valid_0's binary_logloss: 0.0945426
# [217]	valid_0's binary_logloss: 0.0942773
# [218]	valid_0's binary_logloss: 0.093963
# [219]	valid_0's binary_logloss: 0.0936883
# [220]	valid_0's binary_logloss: 0.0933834
# [221]	valid_0's binary_logloss: 0.0930928
# [222]	valid_0's binary_logloss: 0.0928459
# [223]	valid_0's binary_logloss: 0.0926083
# [224]	valid_0's binary_logloss: 0.0923303
# [225]	valid_0's binary_logloss: 0.0920799
# [226]	valid_0's binary_logloss: 0.0917379
# [227]	valid_0's binary_logloss: 0.0915092
# [228]	valid_0's binary_logloss: 0.0912888
# [229]	valid_0's binary_logloss: 0.0910363
# [230]	valid_0's binary_logloss: 0.0907486
# [231]	valid_0's binary_logloss: 0.0904696
# [232]	valid_0's binary_logloss: 0.0902405
# [233]	valid_0's binary_logloss: 0.0900593
# [234]	valid_0's binary_logloss: 0.0898309
# [235]	valid_0's binary_logloss: 0.0894788
# [236]	valid_0's binary_logloss: 0.0892093
# [237]	valid_0's binary_logloss: 0.0889521
# [238]	valid_0's binary_logloss: 0.0887448
# [239]	valid_0's binary_logloss: 0.0884232
# [240]	valid_0's binary_logloss: 0.0881165
# [241]	valid_0's binary_logloss: 0.0879526
# [242]	valid_0's binary_logloss: 0.0876669
# [243]	valid_0's binary_logloss: 0.0873895
# [244]	valid_0's binary_logloss: 0.0871171
# [245]	valid_0's binary_logloss: 0.0868222
# [246]	valid_0's binary_logloss: 0.0865147
# [247]	valid_0's binary_logloss: 0.0863035
# [248]	valid_0's binary_logloss: 0.0861431
# [249]	valid_0's binary_logloss: 0.085918
# [250]	valid_0's binary_logloss: 0.0856713
# [251]	valid_0's binary_logloss: 0.0854047
# [252]	valid_0's binary_logloss: 0.0852036
# [253]	valid_0's binary_logloss: 0.0850004
# [254]	valid_0's binary_logloss: 0.084736
# [255]	valid_0's binary_logloss: 0.0845502
# [256]	valid_0's binary_logloss: 0.0843538
# [257]	valid_0's binary_logloss: 0.0841314
# [258]	valid_0's binary_logloss: 0.0838735
# [259]	valid_0's binary_logloss: 0.083653
# [260]	valid_0's binary_logloss: 0.0834185
# [261]	valid_0's binary_logloss: 0.0832406
# [262]	valid_0's binary_logloss: 0.0830406
# [263]	valid_0's binary_logloss: 0.0828601
# [264]	valid_0's binary_logloss: 0.0826323
# [265]	valid_0's binary_logloss: 0.0824671
# [266]	valid_0's binary_logloss: 0.0823003
# [267]	valid_0's binary_logloss: 0.0821746
# [268]	valid_0's binary_logloss: 0.081973
# [269]	valid_0's binary_logloss: 0.0818298
# [270]	valid_0's binary_logloss: 0.081591
# [271]	valid_0's binary_logloss: 0.0814027
# [272]	valid_0's binary_logloss: 0.0812102
# [273]	valid_0's binary_logloss: 0.0810297
# [274]	valid_0's binary_logloss: 0.080852
# [275]	valid_0's binary_logloss: 0.0806294
# [276]	valid_0's binary_logloss: 0.0804665
# [277]	valid_0's binary_logloss: 0.0803592
# [278]	valid_0's binary_logloss: 0.0801943
# [279]	valid_0's binary_logloss: 0.0800813
# [280]	valid_0's binary_logloss: 0.0799445
# [281]	valid_0's binary_logloss: 0.0797239
# [282]	valid_0's binary_logloss: 0.0794818
# [283]	valid_0's binary_logloss: 0.079311
# [284]	valid_0's binary_logloss: 0.0791717
# [285]	valid_0's binary_logloss: 0.078987
# [286]	valid_0's binary_logloss: 0.0788225
# [287]	valid_0's binary_logloss: 0.0786921
# [288]	valid_0's binary_logloss: 0.0785369
# [289]	valid_0's binary_logloss: 0.0783705
# [290]	valid_0's binary_logloss: 0.0781839
# [291]	valid_0's binary_logloss: 0.078052
# [292]	valid_0's binary_logloss: 0.0779412
# [293]	valid_0's binary_logloss: 0.0777624
# [294]	valid_0's binary_logloss: 0.0776142
# [295]	valid_0's binary_logloss: 0.0774619
# [296]	valid_0's binary_logloss: 0.0772617
# [297]	valid_0's binary_logloss: 0.0771251
# [298]	valid_0's binary_logloss: 0.0769703
# [299]	valid_0's binary_logloss: 0.0767751
# [300]	valid_0's binary_logloss: 0.076655
# [301]	valid_0's binary_logloss: 0.0765497
# [302]	valid_0's binary_logloss: 0.0764288
# [303]	valid_0's binary_logloss: 0.0763013
# [304]	valid_0's binary_logloss: 0.0761816
# [305]	valid_0's binary_logloss: 0.0760301
# [306]	valid_0's binary_logloss: 0.0759349
# [307]	valid_0's binary_logloss: 0.0758133
# [308]	valid_0's binary_logloss: 0.0756745
# [309]	valid_0's binary_logloss: 0.0755545
# [310]	valid_0's binary_logloss: 0.0754094
# [311]	valid_0's binary_logloss: 0.0752618
# [312]	valid_0's binary_logloss: 0.0751261
# [313]	valid_0's binary_logloss: 0.0750336
# [314]	valid_0's binary_logloss: 0.074902
# [315]	valid_0's binary_logloss: 0.0747802
# [316]	valid_0's binary_logloss: 0.0746969
# [317]	valid_0's binary_logloss: 0.074581
# [318]	valid_0's binary_logloss: 0.0744704
# [319]	valid_0's binary_logloss: 0.0743582
# [320]	valid_0's binary_logloss: 0.0742481
# [321]	valid_0's binary_logloss: 0.0741305
# [322]	valid_0's binary_logloss: 0.0740521
# [323]	valid_0's binary_logloss: 0.0739586
# [324]	valid_0's binary_logloss: 0.0738054
# [325]	valid_0's binary_logloss: 0.0736619
# [326]	valid_0's binary_logloss: 0.073528
# [327]	valid_0's binary_logloss: 0.0734462
# [328]	valid_0's binary_logloss: 0.0733528
# [329]	valid_0's binary_logloss: 0.0732004
# [330]	valid_0's binary_logloss: 0.0730785
# [331]	valid_0's binary_logloss: 0.0729981
# [332]	valid_0's binary_logloss: 0.0729607
# [333]	valid_0's binary_logloss: 0.0728634
# [334]	valid_0's binary_logloss: 0.0727147
# [335]	valid_0's binary_logloss: 0.0726125
# [336]	valid_0's binary_logloss: 0.0725245
# [337]	valid_0's binary_logloss: 0.0723941
# [338]	valid_0's binary_logloss: 0.0722919
# [339]	valid_0's binary_logloss: 0.0721937
# [340]	valid_0's binary_logloss: 0.0720807
# [341]	valid_0's binary_logloss: 0.0719919
# [342]	valid_0's binary_logloss: 0.0718974
# [343]	valid_0's binary_logloss: 0.0717979
# [344]	valid_0's binary_logloss: 0.0716968
# [345]	valid_0's binary_logloss: 0.0716467
# [346]	valid_0's binary_logloss: 0.0715586
# [347]	valid_0's binary_logloss: 0.0714724
# [348]	valid_0's binary_logloss: 0.0713749
# [349]	valid_0's binary_logloss: 0.0712837
# [350]	valid_0's binary_logloss: 0.0711552
# [351]	valid_0's binary_logloss: 0.0710862
# [352]	valid_0's binary_logloss: 0.0709672
# [353]	valid_0's binary_logloss: 0.0708782
# [354]	valid_0's binary_logloss: 0.0707793
# [355]	valid_0's binary_logloss: 0.0706576
# [356]	valid_0's binary_logloss: 0.0705793
# [357]	valid_0's binary_logloss: 0.0704856
# [358]	valid_0's binary_logloss: 0.0704121
# [359]	valid_0's binary_logloss: 0.0703152
# [360]	valid_0's binary_logloss: 0.07021
# [361]	valid_0's binary_logloss: 0.0700847
# [362]	valid_0's binary_logloss: 0.0700054
# [363]	valid_0's binary_logloss: 0.0699299
# [364]	valid_0's binary_logloss: 0.0698482
# [365]	valid_0's binary_logloss: 0.0697719
# [366]	valid_0's binary_logloss: 0.0697129
# [367]	valid_0's binary_logloss: 0.0696085
# [368]	valid_0's binary_logloss: 0.0695429
# [369]	valid_0's binary_logloss: 0.0694832
# [370]	valid_0's binary_logloss: 0.0693738
# [371]	valid_0's binary_logloss: 0.0693041
# [372]	valid_0's binary_logloss: 0.0692651
# [373]	valid_0's binary_logloss: 0.0691899
# [374]	valid_0's binary_logloss: 0.069157
# [375]	valid_0's binary_logloss: 0.0691197
# [376]	valid_0's binary_logloss: 0.0690114
# [377]	valid_0's binary_logloss: 0.0689631
# [378]	valid_0's binary_logloss: 0.0688949
# [379]	valid_0's binary_logloss: 0.0688429
# [380]	valid_0's binary_logloss: 0.0687702
# [381]	valid_0's binary_logloss: 0.0687079
# [382]	valid_0's binary_logloss: 0.068644
# [383]	valid_0's binary_logloss: 0.0685633
# [384]	valid_0's binary_logloss: 0.0685212
# [385]	valid_0's binary_logloss: 0.0684909
# [386]	valid_0's binary_logloss: 0.0684216
# [387]	valid_0's binary_logloss: 0.0683201
# [388]	valid_0's binary_logloss: 0.0682614
# [389]	valid_0's binary_logloss: 0.0682188
# [390]	valid_0's binary_logloss: 0.0681589
# [391]	valid_0's binary_logloss: 0.0680741
# [392]	valid_0's binary_logloss: 0.0680245
# [393]	valid_0's binary_logloss: 0.0679421
# [394]	valid_0's binary_logloss: 0.0678812
# [395]	valid_0's binary_logloss: 0.0678244
# [396]	valid_0's binary_logloss: 0.067735
# [397]	valid_0's binary_logloss: 0.0676863
# [398]	valid_0's binary_logloss: 0.067619
# [399]	valid_0's binary_logloss: 0.0674997
# [400]	valid_0's binary_logloss: 0.0674451
# [401]	valid_0's binary_logloss: 0.0673659
# [402]	valid_0's binary_logloss: 0.0672884
# [403]	valid_0's binary_logloss: 0.0671906
# [404]	valid_0's binary_logloss: 0.067108
# [405]	valid_0's binary_logloss: 0.0670697
# [406]	valid_0's binary_logloss: 0.067002
# [407]	valid_0's binary_logloss: 0.0669468
# [408]	valid_0's binary_logloss: 0.0669053
# [409]	valid_0's binary_logloss: 0.0668306
# [410]	valid_0's binary_logloss: 0.066777
# [411]	valid_0's binary_logloss: 0.0666833
# [412]	valid_0's binary_logloss: 0.0666412
# [413]	valid_0's binary_logloss: 0.0665715
# [414]	valid_0's binary_logloss: 0.0664877
# [415]	valid_0's binary_logloss: 0.0664475
# [416]	valid_0's binary_logloss: 0.0663923
# [417]	valid_0's binary_logloss: 0.0663233
# [418]	valid_0's binary_logloss: 0.0662913
# [419]	valid_0's binary_logloss: 0.066217
# [420]	valid_0's binary_logloss: 0.0661951
# [421]	valid_0's binary_logloss: 0.0661415
# [422]	valid_0's binary_logloss: 0.0661093
# [423]	valid_0's binary_logloss: 0.0660729
# [424]	valid_0's binary_logloss: 0.0660353
# [425]	valid_0's binary_logloss: 0.0660166
# [426]	valid_0's binary_logloss: 0.0659615
# [427]	valid_0's binary_logloss: 0.0658983
# [428]	valid_0's binary_logloss: 0.0658115
# [429]	valid_0's binary_logloss: 0.0657482
# [430]	valid_0's binary_logloss: 0.0656759
# [431]	valid_0's binary_logloss: 0.0656388
# [432]	valid_0's binary_logloss: 0.0655985
# [433]	valid_0's binary_logloss: 0.065534
# [434]	valid_0's binary_logloss: 0.0654861
# [435]	valid_0's binary_logloss: 0.0654542
# [436]	valid_0's binary_logloss: 0.0654116
# [437]	valid_0's binary_logloss: 0.0653784
# [438]	valid_0's binary_logloss: 0.0653507
# [439]	valid_0's binary_logloss: 0.0652627
# [440]	valid_0's binary_logloss: 0.065234
# [441]	valid_0's binary_logloss: 0.0651682
# [442]	valid_0's binary_logloss: 0.0651107
# [443]	valid_0's binary_logloss: 0.0650603
# [444]	valid_0's binary_logloss: 0.0650186
# [445]	valid_0's binary_logloss: 0.0649952
# [446]	valid_0's binary_logloss: 0.0649522
# [447]	valid_0's binary_logloss: 0.0649141
# [448]	valid_0's binary_logloss: 0.0648518
# [449]	valid_0's binary_logloss: 0.0648161
# [450]	valid_0's binary_logloss: 0.0648135
# [451]	valid_0's binary_logloss: 0.0647877
# [452]	valid_0's binary_logloss: 0.0647784
# [453]	valid_0's binary_logloss: 0.0647532
# [454]	valid_0's binary_logloss: 0.0647437
# [455]	valid_0's binary_logloss: 0.0647013
# [456]	valid_0's binary_logloss: 0.0646562
# [457]	valid_0's binary_logloss: 0.0646139
# [458]	valid_0's binary_logloss: 0.0646044
# [459]	valid_0's binary_logloss: 0.0645518
# [460]	valid_0's binary_logloss: 0.0644913
# [461]	valid_0's binary_logloss: 0.0644759
# [462]	valid_0's binary_logloss: 0.064425
# [463]	valid_0's binary_logloss: 0.0644089
# [464]	valid_0's binary_logloss: 0.0643427
# [465]	valid_0's binary_logloss: 0.0643037
# [466]	valid_0's binary_logloss: 0.0642717
# [467]	valid_0's binary_logloss: 0.0642543
# [468]	valid_0's binary_logloss: 0.0642469
# [469]	valid_0's binary_logloss: 0.064225
# [470]	valid_0's binary_logloss: 0.0641966
# [471]	valid_0's binary_logloss: 0.0641634
# [472]	valid_0's binary_logloss: 0.0641552
# [473]	valid_0's binary_logloss: 0.0641352
# [474]	valid_0's binary_logloss: 0.0641275
# [475]	valid_0's binary_logloss: 0.0640931
# [476]	valid_0's binary_logloss: 0.0640869
# [477]	valid_0's binary_logloss: 0.0640366
# [478]	valid_0's binary_logloss: 0.0640084
# [479]	valid_0's binary_logloss: 0.0639899
# [480]	valid_0's binary_logloss: 0.0639553
# [481]	valid_0's binary_logloss: 0.0639363
# [482]	valid_0's binary_logloss: 0.0639342
# [483]	valid_0's binary_logloss: 0.0639272
# [484]	valid_0's binary_logloss: 0.0639252
# [485]	valid_0's binary_logloss: 0.0639242
# [486]	valid_0's binary_logloss: 0.0639082
# [487]	valid_0's binary_logloss: 0.0639062
# [488]	valid_0's binary_logloss: 0.0638956
# [489]	valid_0's binary_logloss: 0.0638849
# [490]	valid_0's binary_logloss: 0.0638673
# [491]	valid_0's binary_logloss: 0.0638558
# [492]	valid_0's binary_logloss: 0.0638219
# [493]	valid_0's binary_logloss: 0.0638036
# [494]	valid_0's binary_logloss: 0.0637971
# [495]	valid_0's binary_logloss: 0.06378
# [496]	valid_0's binary_logloss: 0.0637853
# [497]	valid_0's binary_logloss: 0.0637799
# [498]	valid_0's binary_logloss: 0.0637671
# [499]	valid_0's binary_logloss: 0.0637428
# [500]	valid_0's binary_logloss: 0.0637173
# [501]	valid_0's binary_logloss: 0.0636836
# [502]	valid_0's binary_logloss: 0.0636474
# [503]	valid_0's binary_logloss: 0.0636052
# [504]	valid_0's binary_logloss: 0.0635974
# [505]	valid_0's binary_logloss: 0.0635961
# [506]	valid_0's binary_logloss: 0.0635634
# [507]	valid_0's binary_logloss: 0.0635536
# [508]	valid_0's binary_logloss: 0.0635295
# [509]	valid_0's binary_logloss: 0.0634933
# [510]	valid_0's binary_logloss: 0.0634707
# [511]	valid_0's binary_logloss: 0.06347
# [512]	valid_0's binary_logloss: 0.0634683
# [513]	valid_0's binary_logloss: 0.0634477
# [514]	valid_0's binary_logloss: 0.0634475
# [515]	valid_0's binary_logloss: 0.0634609
# [516]	valid_0's binary_logloss: 0.0634401
# [517]	valid_0's binary_logloss: 0.0634359
# [518]	valid_0's binary_logloss: 0.0634438
# [519]	valid_0's binary_logloss: 0.0634441
# [520]	valid_0's binary_logloss: 0.063431
# [521]	valid_0's binary_logloss: 0.0634366
# [522]	valid_0's binary_logloss: 0.0634436
# [523]	valid_0's binary_logloss: 0.0634616
# [524]	valid_0's binary_logloss: 0.0634612
# [525]	valid_0's binary_logloss: 0.063464
# [526]	valid_0's binary_logloss: 0.0634222
# [527]	valid_0's binary_logloss: 0.0633986
# [528]	valid_0's binary_logloss: 0.063389
# [529]	valid_0's binary_logloss: 0.0633901
# [530]	valid_0's binary_logloss: 0.063403
# [531]	valid_0's binary_logloss: 0.0633965
# [532]	valid_0's binary_logloss: 0.0633903
# [533]	valid_0's binary_logloss: 0.0633974
# [534]	valid_0's binary_logloss: 0.0634071
# [535]	valid_0's binary_logloss: 0.0634024
# [536]	valid_0's binary_logloss: 0.0634035
# [537]	valid_0's binary_logloss: 0.0633759
# [538]	valid_0's binary_logloss: 0.0633935
# [539]	valid_0's binary_logloss: 0.0633806
# [540]	valid_0's binary_logloss: 0.0633644
# [541]	valid_0's binary_logloss: 0.0633098
# [542]	valid_0's binary_logloss: 0.0633224
# [543]	valid_0's binary_logloss: 0.0633314
# [544]	valid_0's binary_logloss: 0.0633291
# [545]	valid_0's binary_logloss: 0.0633275
# [546]	valid_0's binary_logloss: 0.0633129
# [547]	valid_0's binary_logloss: 0.0633326
# [548]	valid_0's binary_logloss: 0.0633417
# [549]	valid_0's binary_logloss: 0.0633768
# [550]	valid_0's binary_logloss: 0.0633965
# [551]	valid_0's binary_logloss: 0.0633857
# [552]	valid_0's binary_logloss: 0.0633858
# [553]	valid_0's binary_logloss: 0.0634036
# [554]	valid_0's binary_logloss: 0.0634251
# [555]	valid_0's binary_logloss: 0.0634474
# [556]	valid_0's binary_logloss: 0.0634509
# [557]	valid_0's binary_logloss: 0.0634505
# [558]	valid_0's binary_logloss: 0.0634551
# [559]	valid_0's binary_logloss: 0.0634429
# [560]	valid_0's binary_logloss: 0.0634338
# [561]	valid_0's binary_logloss: 0.0634322
# [562]	valid_0's binary_logloss: 0.0634501
# [563]	valid_0's binary_logloss: 0.0634589
# [564]	valid_0's binary_logloss: 0.0634687
# [565]	valid_0's binary_logloss: 0.0634849
# [566]	valid_0's binary_logloss: 0.063488
# [567]	valid_0's binary_logloss: 0.0634657
# [568]	valid_0's binary_logloss: 0.0634789
# [569]	valid_0's binary_logloss: 0.0634867
# [570]	valid_0's binary_logloss: 0.0634735
# [571]	valid_0's binary_logloss: 0.063461
# [572]	valid_0's binary_logloss: 0.0634413
# [573]	valid_0's binary_logloss: 0.0634289
# [574]	valid_0's binary_logloss: 0.0634425
# [575]	valid_0's binary_logloss: 0.0634513
# [576]	valid_0's binary_logloss: 0.0634355
# [577]	valid_0's binary_logloss: 0.0634645
# [578]	valid_0's binary_logloss: 0.0634774
# [579]	valid_0's binary_logloss: 0.0634837
# [580]	valid_0's binary_logloss: 0.0634924
# [581]	valid_0's binary_logloss: 0.063498
# [582]	valid_0's binary_logloss: 0.0635156
# [583]	valid_0's binary_logloss: 0.0635362
# [584]	valid_0's binary_logloss: 0.0635265
# [585]	valid_0's binary_logloss: 0.0634946
# [586]	valid_0's binary_logloss: 0.0634944
# [587]	valid_0's binary_logloss: 0.0634946
# [588]	valid_0's binary_logloss: 0.0635279
# [589]	valid_0's binary_logloss: 0.0635338
# [590]	valid_0's binary_logloss: 0.0635436
# [591]	valid_0's binary_logloss: 0.0635664
# [592]	valid_0's binary_logloss: 0.0635664
# [593]	valid_0's binary_logloss: 0.0635769
# [594]	valid_0's binary_logloss: 0.0635689
# [595]	valid_0's binary_logloss: 0.0635518
# [596]	valid_0's binary_logloss: 0.0635549
# [597]	valid_0's binary_logloss: 0.0635602
# [598]	valid_0's binary_logloss: 0.0635609
# [599]	valid_0's binary_logloss: 0.0635747
# [600]	valid_0's binary_logloss: 0.0636066
# [601]	valid_0's binary_logloss: 0.0635963
# [602]	valid_0's binary_logloss: 0.0636092
# [603]	valid_0's binary_logloss: 0.0636017
# [604]	valid_0's binary_logloss: 0.0636313
# [605]	valid_0's binary_logloss: 0.0636307
# [606]	valid_0's binary_logloss: 0.0636615
# [607]	valid_0's binary_logloss: 0.0636794
# [608]	valid_0's binary_logloss: 0.0636998
# [609]	valid_0's binary_logloss: 0.0637102
# [610]	valid_0's binary_logloss: 0.0636986
# [611]	valid_0's binary_logloss: 0.0637039
# [612]	valid_0's binary_logloss: 0.0636982
# [613]	valid_0's binary_logloss: 0.0637087
# [614]	valid_0's binary_logloss: 0.063706
# [615]	valid_0's binary_logloss: 0.0637209
# [616]	valid_0's binary_logloss: 0.0637285
# [617]	valid_0's binary_logloss: 0.0637528
# [618]	valid_0's binary_logloss: 0.0637268
# [619]	valid_0's binary_logloss: 0.0637364
# [620]	valid_0's binary_logloss: 0.0637434
# [621]	valid_0's binary_logloss: 0.0637335
# [622]	valid_0's binary_logloss: 0.0637584
# [623]	valid_0's binary_logloss: 0.0637634
# [624]	valid_0's binary_logloss: 0.0637929
# [625]	valid_0's binary_logloss: 0.0637727
# [626]	valid_0's binary_logloss: 0.0637865
# [627]	valid_0's binary_logloss: 0.0637982
# [628]	valid_0's binary_logloss: 0.0638095
# [629]	valid_0's binary_logloss: 0.0638272
# [630]	valid_0's binary_logloss: 0.0638182
# [631]	valid_0's binary_logloss: 0.0638436
# [632]	valid_0's binary_logloss: 0.063845
# [633]	valid_0's binary_logloss: 0.0638298
# [634]	valid_0's binary_logloss: 0.0638368
# [635]	valid_0's binary_logloss: 0.0638648
# [636]	valid_0's binary_logloss: 0.0638846
# [637]	valid_0's binary_logloss: 0.0638995
# [638]	valid_0's binary_logloss: 0.0639078
# [639]	valid_0's binary_logloss: 0.0639107
# [640]	valid_0's binary_logloss: 0.0639209
# [641]	valid_0's binary_logloss: 0.0639428
# Early stopping, best iteration is:
# [541]	valid_0's binary_logloss: 0.0633098
# bt:0.017166416049360558
# fold0::0.017166416049360558::0.7785103100014028
# 100%|█████████████████████████████████████████| 506/506 [00:08<00:00, 63.11it/s]
# [LightGBM] [Warning] Unknown parameter: importance_type
# [LightGBM] [Warning] Unknown parameter: class_weight
# [LightGBM] [Warning] Unknown parameter: importance_type
# [LightGBM] [Warning] Unknown parameter: class_weight
# [LightGBM] [Info] Number of positive: 6072, number of negative: 21210
# [LightGBM] [Warning] Auto-choosing col-wise multi-threading, the overhead of testing was 0.046522 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 127500
# [LightGBM] [Info] Number of data points in the train set: 27282, number of used features: 500
# [LightGBM] [Warning] Unknown parameter: importance_type
# [LightGBM] [Warning] Unknown parameter: class_weight
# [LightGBM] [Info] [binary:BoostFromScore]: pavg=0.222564 -> initscore=-1.250785
# [LightGBM] [Info] Start training from score -1.250785
# [1]	valid_0's binary_logloss: 0.279266
# Training until validation scores don't improve for 100 rounds
# [2]	valid_0's binary_logloss: 0.277957
# [3]	valid_0's binary_logloss: 0.275891
# [4]	valid_0's binary_logloss: 0.274471
# [5]	valid_0's binary_logloss: 0.272813
# [6]	valid_0's binary_logloss: 0.270559
# [7]	valid_0's binary_logloss: 0.269061
# [8]	valid_0's binary_logloss: 0.267587
# [9]	valid_0's binary_logloss: 0.265436
# [10]	valid_0's binary_logloss: 0.26354
# [11]	valid_0's binary_logloss: 0.261764
# [12]	valid_0's binary_logloss: 0.259934
# [13]	valid_0's binary_logloss: 0.257948
# [14]	valid_0's binary_logloss: 0.255936
# [15]	valid_0's binary_logloss: 0.254043
# [16]	valid_0's binary_logloss: 0.252089
# [17]	valid_0's binary_logloss: 0.250428
# [18]	valid_0's binary_logloss: 0.248746
# [19]	valid_0's binary_logloss: 0.246858
# [20]	valid_0's binary_logloss: 0.244981
# [21]	valid_0's binary_logloss: 0.243631
# [22]	valid_0's binary_logloss: 0.241826
# [23]	valid_0's binary_logloss: 0.240017
# [24]	valid_0's binary_logloss: 0.238599
# [25]	valid_0's binary_logloss: 0.237427
# [26]	valid_0's binary_logloss: 0.235629
# [27]	valid_0's binary_logloss: 0.23428
# [28]	valid_0's binary_logloss: 0.232918
# [29]	valid_0's binary_logloss: 0.231181
# [30]	valid_0's binary_logloss: 0.229863
# [31]	valid_0's binary_logloss: 0.228857
# [32]	valid_0's binary_logloss: 0.227266
# [33]	valid_0's binary_logloss: 0.22559
# [34]	valid_0's binary_logloss: 0.224117
# [35]	valid_0's binary_logloss: 0.222552
# [36]	valid_0's binary_logloss: 0.221257
# [37]	valid_0's binary_logloss: 0.220114
# [38]	valid_0's binary_logloss: 0.218527
# [39]	valid_0's binary_logloss: 0.217302
# [40]	valid_0's binary_logloss: 0.215721
# [41]	valid_0's binary_logloss: 0.21447
# [42]	valid_0's binary_logloss: 0.212976
# [43]	valid_0's binary_logloss: 0.211914
# [44]	valid_0's binary_logloss: 0.210813
# [45]	valid_0's binary_logloss: 0.209169
# [46]	valid_0's binary_logloss: 0.208033
# [47]	valid_0's binary_logloss: 0.206902
# [48]	valid_0's binary_logloss: 0.205458
# [49]	valid_0's binary_logloss: 0.204088
# [50]	valid_0's binary_logloss: 0.203164
# [51]	valid_0's binary_logloss: 0.202022
# [52]	valid_0's binary_logloss: 0.201112
# [53]	valid_0's binary_logloss: 0.199947
# [54]	valid_0's binary_logloss: 0.198594
# [55]	valid_0's binary_logloss: 0.197294
# [56]	valid_0's binary_logloss: 0.196016
# [57]	valid_0's binary_logloss: 0.194693
# [58]	valid_0's binary_logloss: 0.193864
# [59]	valid_0's binary_logloss: 0.193083
# [60]	valid_0's binary_logloss: 0.191735
# [61]	valid_0's binary_logloss: 0.190815
# [62]	valid_0's binary_logloss: 0.189588
# [63]	valid_0's binary_logloss: 0.188325
# [64]	valid_0's binary_logloss: 0.187446
# [65]	valid_0's binary_logloss: 0.186327
# [66]	valid_0's binary_logloss: 0.185387
# [67]	valid_0's binary_logloss: 0.184144
# [68]	valid_0's binary_logloss: 0.183339
# [69]	valid_0's binary_logloss: 0.182104
# [70]	valid_0's binary_logloss: 0.181143
# [71]	valid_0's binary_logloss: 0.180239
# [72]	valid_0's binary_logloss: 0.179422
# [73]	valid_0's binary_logloss: 0.178242
# [74]	valid_0's binary_logloss: 0.177385
# [75]	valid_0's binary_logloss: 0.176271
# [76]	valid_0's binary_logloss: 0.175227
# [77]	valid_0's binary_logloss: 0.174075
# [78]	valid_0's binary_logloss: 0.172987
# [79]	valid_0's binary_logloss: 0.172295
# [80]	valid_0's binary_logloss: 0.171598
# [81]	valid_0's binary_logloss: 0.170796
# [82]	valid_0's binary_logloss: 0.169649
# [83]	valid_0's binary_logloss: 0.168587
# [84]	valid_0's binary_logloss: 0.167528
# [85]	valid_0's binary_logloss: 0.166448
# [86]	valid_0's binary_logloss: 0.165499
# [87]	valid_0's binary_logloss: 0.164632
# [88]	valid_0's binary_logloss: 0.163628
# [89]	valid_0's binary_logloss: 0.162615
# [90]	valid_0's binary_logloss: 0.161625
# [91]	valid_0's binary_logloss: 0.160734
# [92]	valid_0's binary_logloss: 0.160072
# [93]	valid_0's binary_logloss: 0.15941
# [94]	valid_0's binary_logloss: 0.158533
# [95]	valid_0's binary_logloss: 0.157774
# [96]	valid_0's binary_logloss: 0.156973
# [97]	valid_0's binary_logloss: 0.156338
# [98]	valid_0's binary_logloss: 0.155476
# [99]	valid_0's binary_logloss: 0.154855
# [100]	valid_0's binary_logloss: 0.153999
# [101]	valid_0's binary_logloss: 0.153071
# [102]	valid_0's binary_logloss: 0.152371
# [103]	valid_0's binary_logloss: 0.151646
# [104]	valid_0's binary_logloss: 0.151055
# [105]	valid_0's binary_logloss: 0.15035
# [106]	valid_0's binary_logloss: 0.149522
# [107]	valid_0's binary_logloss: 0.148662
# [108]	valid_0's binary_logloss: 0.147876
# [109]	valid_0's binary_logloss: 0.147048
# [110]	valid_0's binary_logloss: 0.146498
# [111]	valid_0's binary_logloss: 0.145749
# [112]	valid_0's binary_logloss: 0.144963
# [113]	valid_0's binary_logloss: 0.14417
# [114]	valid_0's binary_logloss: 0.143359
# [115]	valid_0's binary_logloss: 0.142575
# [116]	valid_0's binary_logloss: 0.142052
# [117]	valid_0's binary_logloss: 0.141414
# [118]	valid_0's binary_logloss: 0.140681
# [119]	valid_0's binary_logloss: 0.140164
# [120]	valid_0's binary_logloss: 0.139609
# [121]	valid_0's binary_logloss: 0.139148
# [122]	valid_0's binary_logloss: 0.138613
# [123]	valid_0's binary_logloss: 0.138063
# [124]	valid_0's binary_logloss: 0.137354
# [125]	valid_0's binary_logloss: 0.136848
# [126]	valid_0's binary_logloss: 0.13629
# [127]	valid_0's binary_logloss: 0.135875
# [128]	valid_0's binary_logloss: 0.135314
# [129]	valid_0's binary_logloss: 0.134869
# [130]	valid_0's binary_logloss: 0.134322
# [131]	valid_0's binary_logloss: 0.133632
# [132]	valid_0's binary_logloss: 0.132966
# [133]	valid_0's binary_logloss: 0.132306
# [134]	valid_0's binary_logloss: 0.131805
# [135]	valid_0's binary_logloss: 0.131156
# [136]	valid_0's binary_logloss: 0.130774
# [137]	valid_0's binary_logloss: 0.130274
# [138]	valid_0's binary_logloss: 0.129857
# [139]	valid_0's binary_logloss: 0.129129
# [140]	valid_0's binary_logloss: 0.128687
# [141]	valid_0's binary_logloss: 0.128155
# [142]	valid_0's binary_logloss: 0.127703
# [143]	valid_0's binary_logloss: 0.127062
# [144]	valid_0's binary_logloss: 0.126606
# [145]	valid_0's binary_logloss: 0.125998
# [146]	valid_0's binary_logloss: 0.12561
# [147]	valid_0's binary_logloss: 0.124987
# [148]	valid_0's binary_logloss: 0.124565
# [149]	valid_0's binary_logloss: 0.124105
# [150]	valid_0's binary_logloss: 0.123503
# [151]	valid_0's binary_logloss: 0.122965
# [152]	valid_0's binary_logloss: 0.122413
# [153]	valid_0's binary_logloss: 0.12188
# [154]	valid_0's binary_logloss: 0.121352
# [155]	valid_0's binary_logloss: 0.120806
# [156]	valid_0's binary_logloss: 0.120389
# [157]	valid_0's binary_logloss: 0.120009
# [158]	valid_0's binary_logloss: 0.119442
# [159]	valid_0's binary_logloss: 0.118889
# [160]	valid_0's binary_logloss: 0.118526
# [161]	valid_0's binary_logloss: 0.118076
# [162]	valid_0's binary_logloss: 0.117528
# [163]	valid_0's binary_logloss: 0.116928
# [164]	valid_0's binary_logloss: 0.116529
# [165]	valid_0's binary_logloss: 0.116013
# [166]	valid_0's binary_logloss: 0.11561
# [167]	valid_0's binary_logloss: 0.115059
# [168]	valid_0's binary_logloss: 0.11449
# [169]	valid_0's binary_logloss: 0.114128
# [170]	valid_0's binary_logloss: 0.11362
# [171]	valid_0's binary_logloss: 0.113123
# [172]	valid_0's binary_logloss: 0.112795
# [173]	valid_0's binary_logloss: 0.112507
# [174]	valid_0's binary_logloss: 0.112225
# [175]	valid_0's binary_logloss: 0.111676
# [176]	valid_0's binary_logloss: 0.111343
# [177]	valid_0's binary_logloss: 0.110903
# [178]	valid_0's binary_logloss: 0.110582
# [179]	valid_0's binary_logloss: 0.110156
# [180]	valid_0's binary_logloss: 0.109747
# [181]	valid_0's binary_logloss: 0.109439
# [182]	valid_0's binary_logloss: 0.109075
# [183]	valid_0's binary_logloss: 0.10874
# [184]	valid_0's binary_logloss: 0.108256
# [185]	valid_0's binary_logloss: 0.107777
# [186]	valid_0's binary_logloss: 0.107445
# [187]	valid_0's binary_logloss: 0.107074
# [188]	valid_0's binary_logloss: 0.106586
# [189]	valid_0's binary_logloss: 0.106279
# [190]	valid_0's binary_logloss: 0.105994
# [191]	valid_0's binary_logloss: 0.105572
# [192]	valid_0's binary_logloss: 0.105293
# [193]	valid_0's binary_logloss: 0.104978
# [194]	valid_0's binary_logloss: 0.104564
# [195]	valid_0's binary_logloss: 0.104145
# [196]	valid_0's binary_logloss: 0.103734
# [197]	valid_0's binary_logloss: 0.103499
# [198]	valid_0's binary_logloss: 0.103238
# [199]	valid_0's binary_logloss: 0.10286
# [200]	valid_0's binary_logloss: 0.102516
# [201]	valid_0's binary_logloss: 0.102224
# [202]	valid_0's binary_logloss: 0.101848
# [203]	valid_0's binary_logloss: 0.101572
# [204]	valid_0's binary_logloss: 0.101356
# [205]	valid_0's binary_logloss: 0.100967
# [206]	valid_0's binary_logloss: 0.100697
# [207]	valid_0's binary_logloss: 0.100328
# [208]	valid_0's binary_logloss: 0.0999289
# [209]	valid_0's binary_logloss: 0.0996362
# [210]	valid_0's binary_logloss: 0.0992513
# [211]	valid_0's binary_logloss: 0.0989
# [212]	valid_0's binary_logloss: 0.0986537
# [213]	valid_0's binary_logloss: 0.0983037
# [214]	valid_0's binary_logloss: 0.0980715
# [215]	valid_0's binary_logloss: 0.0977065
# [216]	valid_0's binary_logloss: 0.097349
# [217]	valid_0's binary_logloss: 0.097085
# [218]	valid_0's binary_logloss: 0.0967736
# [219]	valid_0's binary_logloss: 0.0965316
# [220]	valid_0's binary_logloss: 0.0962268
# [221]	valid_0's binary_logloss: 0.0959331
# [222]	valid_0's binary_logloss: 0.095688
# [223]	valid_0's binary_logloss: 0.0954782
# [224]	valid_0's binary_logloss: 0.0952019
# [225]	valid_0's binary_logloss: 0.0949501
# [226]	valid_0's binary_logloss: 0.0945891
# [227]	valid_0's binary_logloss: 0.0943346
# [228]	valid_0's binary_logloss: 0.0941112
# [229]	valid_0's binary_logloss: 0.0938777
# [230]	valid_0's binary_logloss: 0.0935784
# [231]	valid_0's binary_logloss: 0.0933244
# [232]	valid_0's binary_logloss: 0.0931275
# [233]	valid_0's binary_logloss: 0.0929261
# [234]	valid_0's binary_logloss: 0.0927254
# [235]	valid_0's binary_logloss: 0.092409
# [236]	valid_0's binary_logloss: 0.0921342
# [237]	valid_0's binary_logloss: 0.0918579
# [238]	valid_0's binary_logloss: 0.0916778
# [239]	valid_0's binary_logloss: 0.0913869
# [240]	valid_0's binary_logloss: 0.0910634
# [241]	valid_0's binary_logloss: 0.0908462
# [242]	valid_0's binary_logloss: 0.0905067
# [243]	valid_0's binary_logloss: 0.090213
# [244]	valid_0's binary_logloss: 0.0899002
# [245]	valid_0's binary_logloss: 0.0896528
# [246]	valid_0's binary_logloss: 0.0893874
# [247]	valid_0's binary_logloss: 0.0891639
# [248]	valid_0's binary_logloss: 0.0890189
# [249]	valid_0's binary_logloss: 0.0887616
# [250]	valid_0's binary_logloss: 0.0885041
# [251]	valid_0's binary_logloss: 0.0882576
# [252]	valid_0's binary_logloss: 0.0880164
# [253]	valid_0's binary_logloss: 0.0878009
# [254]	valid_0's binary_logloss: 0.0875001
# [255]	valid_0's binary_logloss: 0.0872969
# [256]	valid_0's binary_logloss: 0.0871014
# [257]	valid_0's binary_logloss: 0.0868846
# [258]	valid_0's binary_logloss: 0.0866489
# [259]	valid_0's binary_logloss: 0.0864435
# [260]	valid_0's binary_logloss: 0.0861871
# [261]	valid_0's binary_logloss: 0.0860646
# [262]	valid_0's binary_logloss: 0.0858728
# [263]	valid_0's binary_logloss: 0.0857002
# [264]	valid_0's binary_logloss: 0.0854455
# [265]	valid_0's binary_logloss: 0.0853004
# [266]	valid_0's binary_logloss: 0.0851571
# [267]	valid_0's binary_logloss: 0.0850343
# [268]	valid_0's binary_logloss: 0.0848096
# [269]	valid_0's binary_logloss: 0.0846692
# [270]	valid_0's binary_logloss: 0.0844195
# [271]	valid_0's binary_logloss: 0.084222
# [272]	valid_0's binary_logloss: 0.0840043
# [273]	valid_0's binary_logloss: 0.0837783
# [274]	valid_0's binary_logloss: 0.0836071
# [275]	valid_0's binary_logloss: 0.0833899
# [276]	valid_0's binary_logloss: 0.0832139
# [277]	valid_0's binary_logloss: 0.0830561
# [278]	valid_0's binary_logloss: 0.082873
# [279]	valid_0's binary_logloss: 0.0827256
# [280]	valid_0's binary_logloss: 0.082555
# [281]	valid_0's binary_logloss: 0.0823303
# [282]	valid_0's binary_logloss: 0.0821117
# [283]	valid_0's binary_logloss: 0.0818999
# [284]	valid_0's binary_logloss: 0.0817551
# [285]	valid_0's binary_logloss: 0.0815632
# [286]	valid_0's binary_logloss: 0.0814235
# [287]	valid_0's binary_logloss: 0.0813052
# [288]	valid_0's binary_logloss: 0.0811441
# [289]	valid_0's binary_logloss: 0.0809731
# [290]	valid_0's binary_logloss: 0.0807553
# [291]	valid_0's binary_logloss: 0.0806393
# [292]	valid_0's binary_logloss: 0.0805288
# [293]	valid_0's binary_logloss: 0.0803602
# [294]	valid_0's binary_logloss: 0.0802182
# [295]	valid_0's binary_logloss: 0.0801209
# [296]	valid_0's binary_logloss: 0.0799271
# [297]	valid_0's binary_logloss: 0.0798121
# [298]	valid_0's binary_logloss: 0.0796748
# [299]	valid_0's binary_logloss: 0.0794943
# [300]	valid_0's binary_logloss: 0.0793616
# [301]	valid_0's binary_logloss: 0.0792674
# [302]	valid_0's binary_logloss: 0.0791304
# [303]	valid_0's binary_logloss: 0.0790087
# [304]	valid_0's binary_logloss: 0.0789062
# [305]	valid_0's binary_logloss: 0.0787402
# [306]	valid_0's binary_logloss: 0.0786217
# [307]	valid_0's binary_logloss: 0.0785251
# [308]	valid_0's binary_logloss: 0.0783847
# [309]	valid_0's binary_logloss: 0.078291
# [310]	valid_0's binary_logloss: 0.0781329
# [311]	valid_0's binary_logloss: 0.0780044
# [312]	valid_0's binary_logloss: 0.0778698
# [313]	valid_0's binary_logloss: 0.0777591
# [314]	valid_0's binary_logloss: 0.0776508
# [315]	valid_0's binary_logloss: 0.0775217
# [316]	valid_0's binary_logloss: 0.0774188
# [317]	valid_0's binary_logloss: 0.0773076
# [318]	valid_0's binary_logloss: 0.0771733
# [319]	valid_0's binary_logloss: 0.0770419
# [320]	valid_0's binary_logloss: 0.0769348
# [321]	valid_0's binary_logloss: 0.0768362
# [322]	valid_0's binary_logloss: 0.0767432
# [323]	valid_0's binary_logloss: 0.076652
# [324]	valid_0's binary_logloss: 0.0764887
# [325]	valid_0's binary_logloss: 0.076322
# [326]	valid_0's binary_logloss: 0.0762038
# [327]	valid_0's binary_logloss: 0.0761208
# [328]	valid_0's binary_logloss: 0.0759783
# [329]	valid_0's binary_logloss: 0.0758379
# [330]	valid_0's binary_logloss: 0.0757397
# [331]	valid_0's binary_logloss: 0.0756309
# [332]	valid_0's binary_logloss: 0.0755646
# [333]	valid_0's binary_logloss: 0.07549
# [334]	valid_0's binary_logloss: 0.075383
# [335]	valid_0's binary_logloss: 0.0752806
# [336]	valid_0's binary_logloss: 0.0751715
# [337]	valid_0's binary_logloss: 0.0750295
# [338]	valid_0's binary_logloss: 0.074922
# [339]	valid_0's binary_logloss: 0.0748479
# [340]	valid_0's binary_logloss: 0.0747533
# [341]	valid_0's binary_logloss: 0.0746606
# [342]	valid_0's binary_logloss: 0.0745476
# [343]	valid_0's binary_logloss: 0.0744536
# [344]	valid_0's binary_logloss: 0.0743634
# [345]	valid_0's binary_logloss: 0.0742829
# [346]	valid_0's binary_logloss: 0.0741956
# [347]	valid_0's binary_logloss: 0.0741206
# [348]	valid_0's binary_logloss: 0.0740175
# [349]	valid_0's binary_logloss: 0.0739618
# [350]	valid_0's binary_logloss: 0.0738687
# [351]	valid_0's binary_logloss: 0.0737871
# [352]	valid_0's binary_logloss: 0.0736657
# [353]	valid_0's binary_logloss: 0.0735571
# [354]	valid_0's binary_logloss: 0.0734621
# [355]	valid_0's binary_logloss: 0.073343
# [356]	valid_0's binary_logloss: 0.0732662
# [357]	valid_0's binary_logloss: 0.0731565
# [358]	valid_0's binary_logloss: 0.0731023
# [359]	valid_0's binary_logloss: 0.0729882
# [360]	valid_0's binary_logloss: 0.0729001
# [361]	valid_0's binary_logloss: 0.0728232
# [362]	valid_0's binary_logloss: 0.0727501
# [363]	valid_0's binary_logloss: 0.0726607
# [364]	valid_0's binary_logloss: 0.0725632
# [365]	valid_0's binary_logloss: 0.0724605
# [366]	valid_0's binary_logloss: 0.0723981
# [367]	valid_0's binary_logloss: 0.0723426
# [368]	valid_0's binary_logloss: 0.072257
# [369]	valid_0's binary_logloss: 0.0721587
# [370]	valid_0's binary_logloss: 0.0720563
# [371]	valid_0's binary_logloss: 0.0719557
# [372]	valid_0's binary_logloss: 0.0718804
# [373]	valid_0's binary_logloss: 0.0717877
# [374]	valid_0's binary_logloss: 0.0717489
# [375]	valid_0's binary_logloss: 0.0717122
# [376]	valid_0's binary_logloss: 0.0716052
# [377]	valid_0's binary_logloss: 0.0715496
# [378]	valid_0's binary_logloss: 0.0714539
# [379]	valid_0's binary_logloss: 0.0713682
# [380]	valid_0's binary_logloss: 0.0713109
# [381]	valid_0's binary_logloss: 0.0712496
# [382]	valid_0's binary_logloss: 0.071164
# [383]	valid_0's binary_logloss: 0.0710485
# [384]	valid_0's binary_logloss: 0.0709935
# [385]	valid_0's binary_logloss: 0.0709229
# [386]	valid_0's binary_logloss: 0.0708603
# [387]	valid_0's binary_logloss: 0.0707945
# [388]	valid_0's binary_logloss: 0.0707418
# [389]	valid_0's binary_logloss: 0.0706993
# [390]	valid_0's binary_logloss: 0.070646
# [391]	valid_0's binary_logloss: 0.0705553
# [392]	valid_0's binary_logloss: 0.0705256
# [393]	valid_0's binary_logloss: 0.0704817
# [394]	valid_0's binary_logloss: 0.0704363
# [395]	valid_0's binary_logloss: 0.0703855
# [396]	valid_0's binary_logloss: 0.0702944
# [397]	valid_0's binary_logloss: 0.0702455
# [398]	valid_0's binary_logloss: 0.0701852
# [399]	valid_0's binary_logloss: 0.0700836
# [400]	valid_0's binary_logloss: 0.0700147
# [401]	valid_0's binary_logloss: 0.0699311
# [402]	valid_0's binary_logloss: 0.069849
# [403]	valid_0's binary_logloss: 0.0697695
# [404]	valid_0's binary_logloss: 0.0697071
# [405]	valid_0's binary_logloss: 0.0696778
# [406]	valid_0's binary_logloss: 0.0696616
# [407]	valid_0's binary_logloss: 0.0695977
# [408]	valid_0's binary_logloss: 0.0695141
# [409]	valid_0's binary_logloss: 0.0694391
# [410]	valid_0's binary_logloss: 0.0694077
# [411]	valid_0's binary_logloss: 0.0693612
# [412]	valid_0's binary_logloss: 0.0693204
# [413]	valid_0's binary_logloss: 0.069271
# [414]	valid_0's binary_logloss: 0.0692181
# [415]	valid_0's binary_logloss: 0.0691627
# [416]	valid_0's binary_logloss: 0.0691184
# [417]	valid_0's binary_logloss: 0.0690374
# [418]	valid_0's binary_logloss: 0.0689737
# [419]	valid_0's binary_logloss: 0.0689006
# [420]	valid_0's binary_logloss: 0.0688776
# [421]	valid_0's binary_logloss: 0.0688122
# [422]	valid_0's binary_logloss: 0.068783
# [423]	valid_0's binary_logloss: 0.0687201
# [424]	valid_0's binary_logloss: 0.0686804
# [425]	valid_0's binary_logloss: 0.0686396
# [426]	valid_0's binary_logloss: 0.068603
# [427]	valid_0's binary_logloss: 0.0685227
# [428]	valid_0's binary_logloss: 0.0684452
# [429]	valid_0's binary_logloss: 0.0683997
# [430]	valid_0's binary_logloss: 0.0683385
# [431]	valid_0's binary_logloss: 0.0683036
# [432]	valid_0's binary_logloss: 0.0682707
# [433]	valid_0's binary_logloss: 0.0682124
# [434]	valid_0's binary_logloss: 0.0681466
# [435]	valid_0's binary_logloss: 0.0680907
# [436]	valid_0's binary_logloss: 0.0680491
# [437]	valid_0's binary_logloss: 0.0680189
# [438]	valid_0's binary_logloss: 0.0680165
# [439]	valid_0's binary_logloss: 0.0679595
# [440]	valid_0's binary_logloss: 0.067937
# [441]	valid_0's binary_logloss: 0.0679038
# [442]	valid_0's binary_logloss: 0.067861
# [443]	valid_0's binary_logloss: 0.0678243
# [444]	valid_0's binary_logloss: 0.0677921
# [445]	valid_0's binary_logloss: 0.0677404
# [446]	valid_0's binary_logloss: 0.0676935
# [447]	valid_0's binary_logloss: 0.0676661
# [448]	valid_0's binary_logloss: 0.0676146
# [449]	valid_0's binary_logloss: 0.0675518
# [450]	valid_0's binary_logloss: 0.0675354
# [451]	valid_0's binary_logloss: 0.067514
# [452]	valid_0's binary_logloss: 0.0675008
# [453]	valid_0's binary_logloss: 0.0674233
# [454]	valid_0's binary_logloss: 0.0673833
# [455]	valid_0's binary_logloss: 0.0673644
# [456]	valid_0's binary_logloss: 0.0673522
# [457]	valid_0's binary_logloss: 0.067295
# [458]	valid_0's binary_logloss: 0.0672802
# [459]	valid_0's binary_logloss: 0.0672379
# [460]	valid_0's binary_logloss: 0.0672155
# [461]	valid_0's binary_logloss: 0.0671973
# [462]	valid_0's binary_logloss: 0.06717
# [463]	valid_0's binary_logloss: 0.0671466
# [464]	valid_0's binary_logloss: 0.0671324
# [465]	valid_0's binary_logloss: 0.0671192
# [466]	valid_0's binary_logloss: 0.0671121
# [467]	valid_0's binary_logloss: 0.0670899
# [468]	valid_0's binary_logloss: 0.0670759
# [469]	valid_0's binary_logloss: 0.0670284
# ...
# [387]	valid_0's binary_logloss: 0.0659976
# [388]	valid_0's binary_logloss: 0.0659564
# [389]	valid_0's binary_logloss: 0.0659021
# [390]	valid_0's binary_logloss: 0.0658461
# [391]	valid_0's binary_logloss: 0.0657436
# [392]	valid_0's binary_logloss: 0.0656925
# [393]	valid_0's binary_logloss: 0.0656421
# [394]	valid_0's binary_logloss: 0.0655531
# [395]	valid_0's binary_logloss: 0.0654844
# [396]	valid_0's binary_logloss: 0.0653907
# [397]	valid_0's binary_logloss: 0.0653272
# [398]	valid_0's binary_logloss: 0.0652359
# [399]	valid_0's binary_logloss: 0.0651014
# [400]	valid_0's binary_logloss: 0.0650517
# [401]	valid_0's binary_logloss: 0.0649579
# [402]	valid_0's binary_logloss: 0.0648671
# [403]	valid_0's binary_logloss: 0.0647388
# [404]	valid_0's binary_logloss: 0.064654
# [405]	valid_0's binary_logloss: 0.0645881
# [406]	valid_0's binary_logloss: 0.0645518
# [407]	valid_0's binary_logloss: 0.0644687
# [408]	valid_0's binary_logloss: 0.0643692
# [409]	valid_0's binary_logloss: 0.064279
# [410]	valid_0's binary_logloss: 0.0641863
# [411]	valid_0's binary_logloss: 0.0641097
# [412]	valid_0's binary_logloss: 0.0640668
# [413]	valid_0's binary_logloss: 0.0640265
# [414]	valid_0's binary_logloss: 0.0639542
# [415]	valid_0's binary_logloss: 0.0639181
# [416]	valid_0's binary_logloss: 0.0638743
# [417]	valid_0's binary_logloss: 0.063793
# [418]	valid_0's binary_logloss: 0.0637563
# [419]	valid_0's binary_logloss: 0.0637079
# [420]	valid_0's binary_logloss: 0.063665
# [421]	valid_0's binary_logloss: 0.0636236
# [422]	valid_0's binary_logloss: 0.0635891
# [423]	valid_0's binary_logloss: 0.0635681
# [424]	valid_0's binary_logloss: 0.0635331
# [425]	valid_0's binary_logloss: 0.0634952
# [426]	valid_0's binary_logloss: 0.0634711
# [427]	valid_0's binary_logloss: 0.0633959
# [428]	valid_0's binary_logloss: 0.0633229
# [429]	valid_0's binary_logloss: 0.0632513
# [430]	valid_0's binary_logloss: 0.063168
# [431]	valid_0's binary_logloss: 0.0631461
# [432]	valid_0's binary_logloss: 0.0630851
# [433]	valid_0's binary_logloss: 0.0630338
# [434]	valid_0's binary_logloss: 0.0629899
# [435]	valid_0's binary_logloss: 0.0629643
# [436]	valid_0's binary_logloss: 0.0628886
# [437]	valid_0's binary_logloss: 0.0628686
# [438]	valid_0's binary_logloss: 0.0628562
# [439]	valid_0's binary_logloss: 0.062801
# [440]	valid_0's binary_logloss: 0.0627958
# [441]	valid_0's binary_logloss: 0.0627203
# [442]	valid_0's binary_logloss: 0.0626692
# [443]	valid_0's binary_logloss: 0.0626294
# [444]	valid_0's binary_logloss: 0.0625661
# [445]	valid_0's binary_logloss: 0.0625524
# [446]	valid_0's binary_logloss: 0.0625048
# [447]	valid_0's binary_logloss: 0.0624687
# [448]	valid_0's binary_logloss: 0.0624101
# [449]	valid_0's binary_logloss: 0.0623437
# [450]	valid_0's binary_logloss: 0.0623355
# [451]	valid_0's binary_logloss: 0.0623016
# [452]	valid_0's binary_logloss: 0.0622889
# [453]	valid_0's binary_logloss: 0.0622111
# [454]	valid_0's binary_logloss: 0.062137
# [455]	valid_0's binary_logloss: 0.062083
# [456]	valid_0's binary_logloss: 0.0620606
# [457]	valid_0's binary_logloss: 0.0620041
# [458]	valid_0's binary_logloss: 0.0619711
# [459]	valid_0's binary_logloss: 0.0619432
# [460]	valid_0's binary_logloss: 0.0618841
# [461]	valid_0's binary_logloss: 0.0618616
# [462]	valid_0's binary_logloss: 0.0618439
# [463]	valid_0's binary_logloss: 0.0618178
# [464]	valid_0's binary_logloss: 0.0617677
# [465]	valid_0's binary_logloss: 0.0617351
# [466]	valid_0's binary_logloss: 0.0617026
# [467]	valid_0's binary_logloss: 0.0616929
# [468]	valid_0's binary_logloss: 0.0616639
# [469]	valid_0's binary_logloss: 0.061615
# [470]	valid_0's binary_logloss: 0.0616024
# [471]	valid_0's binary_logloss: 0.0615882
# [472]	valid_0's binary_logloss: 0.061556
# [473]	valid_0's binary_logloss: 0.0615418
# [474]	valid_0's binary_logloss: 0.0615445
# [475]	valid_0's binary_logloss: 0.0615069
# [476]	valid_0's binary_logloss: 0.0614808
# [477]	valid_0's binary_logloss: 0.0614223
# [478]	valid_0's binary_logloss: 0.0613928
# [479]	valid_0's binary_logloss: 0.0613712
# [480]	valid_0's binary_logloss: 0.0613436
# [481]	valid_0's binary_logloss: 0.0612801
# [482]	valid_0's binary_logloss: 0.0612428
# [483]	valid_0's binary_logloss: 0.06122
# [484]	valid_0's binary_logloss: 0.0612136
# [485]	valid_0's binary_logloss: 0.061207
# [486]	valid_0's binary_logloss: 0.0611924
# [487]	valid_0's binary_logloss: 0.0611652
# [488]	valid_0's binary_logloss: 0.0611397
# [489]	valid_0's binary_logloss: 0.0611307
# [490]	valid_0's binary_logloss: 0.0611134
# [491]	valid_0's binary_logloss: 0.0610959
# [492]	valid_0's binary_logloss: 0.0610764
# [493]	valid_0's binary_logloss: 0.0610583
# [494]	valid_0's binary_logloss: 0.0610252
# [495]	valid_0's binary_logloss: 0.0609986
# [496]	valid_0's binary_logloss: 0.0609925
# [497]	valid_0's binary_logloss: 0.0609766
# [498]	valid_0's binary_logloss: 0.0609596
# [499]	valid_0's binary_logloss: 0.060962
# [500]	valid_0's binary_logloss: 0.06095
# [501]	valid_0's binary_logloss: 0.0609026
# [502]	valid_0's binary_logloss: 0.0608674
# [503]	valid_0's binary_logloss: 0.0608308
# [504]	valid_0's binary_logloss: 0.0608254
# [505]	valid_0's binary_logloss: 0.06081
# [506]	valid_0's binary_logloss: 0.0607771
# [507]	valid_0's binary_logloss: 0.0607716
# [508]	valid_0's binary_logloss: 0.0607712
# [509]	valid_0's binary_logloss: 0.0607292
# [510]	valid_0's binary_logloss: 0.0607109
# [511]	valid_0's binary_logloss: 0.0607056
# [512]	valid_0's binary_logloss: 0.0606928
# [513]	valid_0's binary_logloss: 0.0606314
# [514]	valid_0's binary_logloss: 0.060633
# [515]	valid_0's binary_logloss: 0.0606295
# [516]	valid_0's binary_logloss: 0.060593
# [517]	valid_0's binary_logloss: 0.0605748
# [518]	valid_0's binary_logloss: 0.0605614
# [519]	valid_0's binary_logloss: 0.0605552
# [520]	valid_0's binary_logloss: 0.0605323
# [521]	valid_0's binary_logloss: 0.0605108
# [522]	valid_0's binary_logloss: 0.0605076
# [523]	valid_0's binary_logloss: 0.0605042
# [524]	valid_0's binary_logloss: 0.0605097
# [525]	valid_0's binary_logloss: 0.0605242
# [526]	valid_0's binary_logloss: 0.0604975
# [527]	valid_0's binary_logloss: 0.0604852
# [528]	valid_0's binary_logloss: 0.0604916
# [529]	valid_0's binary_logloss: 0.0604833
# [530]	valid_0's binary_logloss: 0.0604819
# [531]	valid_0's binary_logloss: 0.0604592
# [532]	valid_0's binary_logloss: 0.060441
# [533]	valid_0's binary_logloss: 0.0604679
# [534]	valid_0's binary_logloss: 0.0604805
# [535]	valid_0's binary_logloss: 0.0605042
# [536]	valid_0's binary_logloss: 0.0604977
# [537]	valid_0's binary_logloss: 0.0604701
# [538]	valid_0's binary_logloss: 0.0604847
# [539]	valid_0's binary_logloss: 0.0604787
# [540]	valid_0's binary_logloss: 0.0604885
# [541]	valid_0's binary_logloss: 0.060478
# [542]	valid_0's binary_logloss: 0.0604753
# [543]	valid_0's binary_logloss: 0.0604439
# [544]	valid_0's binary_logloss: 0.0604653
# [545]	valid_0's binary_logloss: 0.0604615
# [546]	valid_0's binary_logloss: 0.0604322
# [547]	valid_0's binary_logloss: 0.0604338
# [548]	valid_0's binary_logloss: 0.0604237
# [549]	valid_0's binary_logloss: 0.0604227
# [550]	valid_0's binary_logloss: 0.0604181
# [551]	valid_0's binary_logloss: 0.0604011
# [552]	valid_0's binary_logloss: 0.0604263
# [553]	valid_0's binary_logloss: 0.0604189
# [554]	valid_0's binary_logloss: 0.0604139
# [555]	valid_0's binary_logloss: 0.0604391
# [556]	valid_0's binary_logloss: 0.0604237
# [557]	valid_0's binary_logloss: 0.0604218
# [558]	valid_0's binary_logloss: 0.0604125
# [559]	valid_0's binary_logloss: 0.0604175
# [560]	valid_0's binary_logloss: 0.060428
# [561]	valid_0's binary_logloss: 0.0604405
# [562]	valid_0's binary_logloss: 0.0604689
# [563]	valid_0's binary_logloss: 0.0604859
# [564]	valid_0's binary_logloss: 0.0605035
# [565]	valid_0's binary_logloss: 0.0605078
# [566]	valid_0's binary_logloss: 0.060523
# [567]	valid_0's binary_logloss: 0.0605019
# [568]	valid_0's binary_logloss: 0.0605367
# [569]	valid_0's binary_logloss: 0.0605124
# [570]	valid_0's binary_logloss: 0.0604957
# [571]	valid_0's binary_logloss: 0.0604937
# [572]	valid_0's binary_logloss: 0.0604694
# [573]	valid_0's binary_logloss: 0.060449
# [574]	valid_0's binary_logloss: 0.0604203
# [575]	valid_0's binary_logloss: 0.0604357
# [576]	valid_0's binary_logloss: 0.0604312
# [577]	valid_0's binary_logloss: 0.0604374
# [578]	valid_0's binary_logloss: 0.0604414
# [579]	valid_0's binary_logloss: 0.0604497
# [580]	valid_0's binary_logloss: 0.0604476
# [581]	valid_0's binary_logloss: 0.0604287
# [582]	valid_0's binary_logloss: 0.0604466
# [583]	valid_0's binary_logloss: 0.0604594
# [584]	valid_0's binary_logloss: 0.0604542
# [585]	valid_0's binary_logloss: 0.0604369
# [586]	valid_0's binary_logloss: 0.0603941
# [587]	valid_0's binary_logloss: 0.0603796
# [588]	valid_0's binary_logloss: 0.0603872
# [589]	valid_0's binary_logloss: 0.060382
# [590]	valid_0's binary_logloss: 0.0603911
# [591]	valid_0's binary_logloss: 0.0603946
# [592]	valid_0's binary_logloss: 0.0603858
# [593]	valid_0's binary_logloss: 0.0604082
# [594]	valid_0's binary_logloss: 0.0604025
# [595]	valid_0's binary_logloss: 0.0603838
# [596]	valid_0's binary_logloss: 0.0603574
# [597]	valid_0's binary_logloss: 0.0603875
# [598]	valid_0's binary_logloss: 0.060398
# [599]	valid_0's binary_logloss: 0.0604116
# [600]	valid_0's binary_logloss: 0.0604181
# [601]	valid_0's binary_logloss: 0.0604135
# [602]	valid_0's binary_logloss: 0.0604169
# [603]	valid_0's binary_logloss: 0.0604195
# [604]	valid_0's binary_logloss: 0.0604208
# [605]	valid_0's binary_logloss: 0.0604328
# [606]	valid_0's binary_logloss: 0.0604402
# [607]	valid_0's binary_logloss: 0.0604623
# [608]	valid_0's binary_logloss: 0.0604916
# [609]	valid_0's binary_logloss: 0.0605158
# [610]	valid_0's binary_logloss: 0.0605214
# [611]	valid_0's binary_logloss: 0.0605299
# [612]	valid_0's binary_logloss: 0.0604976
# [613]	valid_0's binary_logloss: 0.0604916
# [614]	valid_0's binary_logloss: 0.0604747
# [615]	valid_0's binary_logloss: 0.0604576
# [616]	valid_0's binary_logloss: 0.0604674
# [617]	valid_0's binary_logloss: 0.0604845
# [618]	valid_0's binary_logloss: 0.0604888
# [619]	valid_0's binary_logloss: 0.0604723
# [620]	valid_0's binary_logloss: 0.0604784
# [621]	valid_0's binary_logloss: 0.0604934
# [622]	valid_0's binary_logloss: 0.0604627
# [623]	valid_0's binary_logloss: 0.0604759
# [624]	valid_0's binary_logloss: 0.0604714
# [625]	valid_0's binary_logloss: 0.060463
# [626]	valid_0's binary_logloss: 0.0604692
# [627]	valid_0's binary_logloss: 0.0604635
# [628]	valid_0's binary_logloss: 0.0604677
# [629]	valid_0's binary_logloss: 0.060484
# [630]	valid_0's binary_logloss: 0.0605109
# [631]	valid_0's binary_logloss: 0.0605277
# [632]	valid_0's binary_logloss: 0.0605213
# [633]	valid_0's binary_logloss: 0.0605151
# [634]	valid_0's binary_logloss: 0.0605033
# [635]	valid_0's binary_logloss: 0.0605253
# [636]	valid_0's binary_logloss: 0.0605586
# [637]	valid_0's binary_logloss: 0.0605896
# [638]	valid_0's binary_logloss: 0.0606124
# [639]	valid_0's binary_logloss: 0.0606249
# [640]	valid_0's binary_logloss: 0.0606634
# [641]	valid_0's binary_logloss: 0.0606617
# [642]	valid_0's binary_logloss: 0.0606859
# [643]	valid_0's binary_logloss: 0.0606904
# [644]	valid_0's binary_logloss: 0.0606806
# [645]	valid_0's binary_logloss: 0.0606593
# [646]	valid_0's binary_logloss: 0.0606576
# [647]	valid_0's binary_logloss: 0.060673
# [648]	valid_0's binary_logloss: 0.0606796
# [649]	valid_0's binary_logloss: 0.0607084
# [650]	valid_0's binary_logloss: 0.060732
# [651]	valid_0's binary_logloss: 0.0607312
# [652]	valid_0's binary_logloss: 0.0607368
# [653]	valid_0's binary_logloss: 0.0607144
# [654]	valid_0's binary_logloss: 0.0607427
# [655]	valid_0's binary_logloss: 0.0607547
# [656]	valid_0's binary_logloss: 0.0607515
# [657]	valid_0's binary_logloss: 0.0607492
# [658]	valid_0's binary_logloss: 0.060742
# [659]	valid_0's binary_logloss: 0.0607493
# [660]	valid_0's binary_logloss: 0.0607666
# [661]	valid_0's binary_logloss: 0.0607923
# [662]	valid_0's binary_logloss: 0.0608076
# [663]	valid_0's binary_logloss: 0.0608055
# [664]	valid_0's binary_logloss: 0.0608155
# [665]	valid_0's binary_logloss: 0.0608341
# [666]	valid_0's binary_logloss: 0.06086
# [667]	valid_0's binary_logloss: 0.0608763
# [668]	valid_0's binary_logloss: 0.0608935
# [669]	valid_0's binary_logloss: 0.060924
# [670]	valid_0's binary_logloss: 0.0609243
# [671]	valid_0's binary_logloss: 0.0609387
# [672]	valid_0's binary_logloss: 0.0609348
# [673]	valid_0's binary_logloss: 0.0609578
# [674]	valid_0's binary_logloss: 0.0609418
# [675]	valid_0's binary_logloss: 0.060935
# [676]	valid_0's binary_logloss: 0.0609587
# [677]	valid_0's binary_logloss: 0.0609894
# [678]	valid_0's binary_logloss: 0.060999
# [679]	valid_0's binary_logloss: 0.0610078
# [680]	valid_0's binary_logloss: 0.0610161
# [681]	valid_0's binary_logloss: 0.0610249
# [682]	valid_0's binary_logloss: 0.0610362
# [683]	valid_0's binary_logloss: 0.0610507
# [684]	valid_0's binary_logloss: 0.0610704
# [685]	valid_0's binary_logloss: 0.0610804
# [686]	valid_0's binary_logloss: 0.0610941
# [687]	valid_0's binary_logloss: 0.0610936
# [688]	valid_0's binary_logloss: 0.0611016
# [689]	valid_0's binary_logloss: 0.0611351
# [690]	valid_0's binary_logloss: 0.0611345
# [691]	valid_0's binary_logloss: 0.0611754
# [692]	valid_0's binary_logloss: 0.0612131
# [693]	valid_0's binary_logloss: 0.0612274
# [694]	valid_0's binary_logloss: 0.0612366
# [695]	valid_0's binary_logloss: 0.0612636
# [696]	valid_0's binary_logloss: 0.0612808
# Early stopping, best iteration is:
# [596]	valid_0's binary_logloss: 0.0603574
# bt:0.016294113510553276
# fold2::0.016294113510553276::0.7799205899035735
# 100%|█████████████████████████████████████████| 505/505 [00:08<00:00, 62.82it/s]
# [LightGBM] [Warning] Unknown parameter: importance_type
# [LightGBM] [Warning] Unknown parameter: class_weight
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# /tmp/ipykernel_135491/1562699249.py in <module>
#      30     evals_result = {}
#      31
# ---> 32     model = lgb_o.train(params,train_set=lgb_train,
#      33                  # 評価データ
#      34                  valid_sets = lgb_eval,
#
# ~/デスクトップ/Signate/signate_env/lib/python3.9/site-packages/lightgbm/engine.py in train(params, train_set, num_boost_round, valid_sets, valid_names, fobj, feval, init_model, feature_name, categorical_feature, early_stopping_rounds, evals_result, verbose_eval, learning_rates, keep_training_booster, callbacks)
#     226     # construct booster
#     227     try:
# --> 228         booster = Booster(params=params, train_set=train_set)
#     229         if is_valid_contain_train:
#     230             booster.set_train_data_name(train_data_name)
#
# ~/デスクトップ/Signate/signate_env/lib/python3.9/site-packages/lightgbm/basic.py in __init__(self, params, train_set, model_file, model_str, silent)
#    2227                 )
#    2228             # construct booster object
# -> 2229             train_set.construct()
#    2230             # copy the parameters from train_set
#    2231             params.update(train_set.get_params())
#
# ~/デスクトップ/Signate/signate_env/lib/python3.9/site-packages/lightgbm/basic.py in construct(self)
#    1466             else:
#    1467                 # create train
# -> 1468                 self._lazy_init(self.data, label=self.label,
#    1469                                 weight=self.weight, group=self.group,
#    1470                                 init_score=self.init_score, predictor=self._predictor,
#
# ~/デスクトップ/Signate/signate_env/lib/python3.9/site-packages/lightgbm/basic.py in _lazy_init(self, data, label, reference, weight, group, init_score, predictor, silent, feature_name, categorical_feature, params)
#    1268             self.__init_from_csc(data, params_str, ref_dataset)
#    1269         elif isinstance(data, np.ndarray):
# -> 1270             self.__init_from_np2d(data, params_str, ref_dataset)
#    1271         elif isinstance(data, list) and len(data) > 0 and all(isinstance(x, np.ndarray) for x in data):
#    1272             self.__init_from_list_np2d(data, params_str, ref_dataset)
#
# ~/デスクトップ/Signate/signate_env/lib/python3.9/site-packages/lightgbm/basic.py in __init_from_np2d(self, mat, params_str, ref_dataset)
#    1310
#    1311         ptr_data, type_ptr_data, _ = c_float_array(data)
# -> 1312         _safe_call(_LIB.LGBM_DatasetCreateFromMat(
#    1313             ptr_data,
#    1314             ctypes.c_int(type_ptr_data),
#
# KeyboardInterrupt:
